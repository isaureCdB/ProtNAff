# %%
import numpy as np
import json, sys
from scipy.stats import fisher_exact

# %%
from query import *
from requests import *

# %%
fragments_all = np.load("fragments_clust.npy")

# %%
chaindata = json.load(open("structures.json"))

# %%
chainschema = json.load(open("chainschema.json"))

# %%
parts = ['ph', 'sug', 'base', 'any', 'nonspecif']
states = ['ss', 'ds']
s = ['A', 'G', 'U', 'C']
seqs = [a+b+c for a in s for b in s for c in s]
m = ['A', 'C']
motifs = [a+b+c for a in m for b in m for c in m]

# %%
mask_redun =  np.load("redundancy-masks/1.0-seqclust-50.npy")
mask_redun[0]
fragments = fragments_all[mask_redun]

# %% [markdown]
# Always do query on all fragments.
# Store as many masks as possible.
# To answer questions, combine the masks

# %% [markdown]
# Define masks

# %%
mask_seq = {}
for seq in seqs:
    mask_seq[seq] = (fragments["seq"] == seq.encode())

# %%
mask_state = {}
secstruc = query(chaindata, chainschema, fragments, [], "ss", part=None)
mask_state["ds"] = np.array(list(map(is_ds, secstruc)))
mask_state["ss"] = np.array(list(map(is_ss, secstruc)))

# %%
mask_close = {}
mask_veryclose = {}
for part in ["ph","sug", "base"]:    
    all_part = query(chaindata, chainschema, fragments, 99.9, "interface_protein", part=part)[:,1]
    mask_close[part] = (all_part < 99.9)
    mask_veryclose[part] = (all_part < 3.5)
mask_close["any"] = mask_close["ph"] | mask_close["sug"] | mask_close["base"]
mask_veryclose["any"] = mask_veryclose["ph"] | mask_veryclose["sug"] | mask_veryclose["base"]
mask_close["nonspecif"] = (mask_close["ph"] | mask_close["sug"]) & ( ~ mask_close["base"] )
mask_veryclose["nonspecif"] = (mask_veryclose["ph"] | mask_veryclose["sug"]) & ( ~ mask_veryclose["base"] )

# %%
mask_motif = {}
for motif in motifs:
    mask_motif[motif] = (fragments["motif"] == motif.encode())

# %% [markdown]
# # Question 1a
# Do single-stranded and double-stranded trinucleotides bind protein via preferential nucleotidic parts?

# %%
def count_seqs(counts, seqs):
    counts_filtered = dict([(k,v) for k,v in counts.items() if k[0] in seqs])
    d = {}
    t = []
    for part in parts:
        N = {}
        percent = {}
        crosstable = []
        for state in states:
            state_any = sum([v for k,v in counts_filtered.items() if k[1] == state and k[2] == "any"])
            assert state_any > 0
            state_part = sum([v for k,v in counts_filtered.items() if k[1] == state and k[2] == part])
            state_others = state_any - state_part
            crosstable.append((state_part, state_others))
            percent[state] = 100 * state_part / state_any
            N[state] = sum([counts[m, state, part] for m in seqs])
        f = fisher_exact(crosstable)
        tt = N["ss"], N["ds"], part, percent["ss"], percent["ds"], f[0], f[1]
        t.append(tt)
        d[part] = { "N_ss": N["ss"], "N_ds": N["ds"], "ss": percent["ss"], "ds": percent["ds"], "ratio": f[0], "p-value": f[1] }
    return d, t

# %%
def count_mask(new_mask):
    new_count = {}
    for part in parts:
        if new_mask is None:
            mask0 = mask_close[part]
        else:
            mask0 = new_mask & mask_close[part]
        for state in states:
            mask1 = mask0 & mask_state[state]
            for seq in seqs:
                mask2 = mask1 & mask_seq[seq]
                new_count[seq, state, part] = mask2.sum()
    return new_count

# %%
def fisher_counts(count1, count2, part):
    N_ss1 = count1['any']["N_ss"]
    N_ss2 = count2['any']["N_ss"]
    N_ss1_part = N_ss1 * count1[part]["ss"] / 100
    N_ss2_part = N_ss2 * count2[part]["ss"] / 100
    t_ss = [ [N_ss1_part, N_ss1-N_ss1_part], [N_ss2_part, N_ss2-N_ss2_part] ]
    print(("percent_ss", count1[part]["ss"], count2[part]["ss"] ))
    print("pvalue_ss", fisher_exact(t_ss)[1])
    #
    N_ds1 = count1['any']["N_ds"]
    N_ds2 = count2['any']["N_ds"]
    N_ds1_part = N_ds1 * count1[part]["ds"] / 100
    N_ds2_part = N_ds2 * count2[part]["ds"]  / 100   
    t_ds = [ [N_ds1_part, N_ds1 - N_ds1_part], [N_ds2_part, N_ds2 - N_ds2_part] ]
    print(("percent_ds", count1[part]["ds"], count2[part]["ds"] ))
    print("pvalue_ds", fisher_exact(t_ds)[1])

# %%
counts = count_mask(None)

# %%
dd, tt = count_seqs(counts, seqs)

# %%
dd
# Out:
# {'any': {'N_ds': 2990,
#   'N_ss': 7035,
#   'ds': 100.0,
#   'p-value': 1.0,
#   'ratio': nan,
#   'ss': 100.0},
#  'base': {'N_ds': 1949,
#   'N_ss': 5699,
#   'ds': 65.18394648829431,
#   'p-value': 2.4902137341051205e-62,
#   'ratio': 2.2784058614428404,
#   'ss': 81.00923951670221},
#  'nonspecif': {'N_ds': 1041,
#   'N_ss': 1336,
#   'ds': 34.81605351170568,
#   'p-value': 2.490213734105121e-62,
#   'ratio': 0.43890336525325324,
#   'ss': 18.990760483297798},
#  'ph': {'N_ds': 2409,
#   'N_ss': 5967,
#   'ds': 80.5685618729097,
#   'p-value': 2.1372516661500813e-07,
#   'ratio': 1.3474855527726084,
#   'ss': 84.81876332622602},
#  'sug': {'N_ds': 2111,
#   'N_ss': 5751,
#   'ds': 70.60200668896321,
#   'p-value': 5.157561242540897e-34,
#   'ratio': 1.865000641942296,
#   'ss': 81.74840085287846}}

# %%
import pandas as pd
columns = ["sequence", "N_ss", "N_ds", "part", "ss", "ds", "ratio", "pvalue"]
def table_seq(count, seqs):
    table = []
    for seq in seqs:
        _, t = count_seqs(count,[seq])
        for tt in t:
            table.append((seq,) + tt)
    df = pd.DataFrame(table, columns=columns)
    return df

# %%
df_all = table_seq(counts, seqs)

# %%
df_significant = df_all[df_all.eval('part=="base" and pvalue < 0.01')]
df_non_significant = df_all[df_all.eval('part=="base" and pvalue > 0.01')]
df_ss_base = df_all[df_all.eval('part=="base" and ss < ds')]

# %%
df_significant
# Out:
#     sequence  N_ss  N_ds  part         ss         ds      ratio        pvalue
# 27       AGG    84    49  base  87.500000  56.976744   5.285714  4.271624e-06
# 42       AUA   160     9  base  93.567251  60.000000   9.696970  7.146906e-04
# 52       AUU   134    13  base  88.157895  61.904762   4.581197  4.833290e-03
# 57       AUC    61     4  base  73.493976  26.666667   7.625000  8.088027e-04
# 67       ACG    32    51  base  96.969697  62.962963  18.823529  1.202880e-04
# 77       ACC   110    29  base  84.615385  63.043478   3.224138  3.177368e-03
# 87       GAG    61    46  base  81.333333  58.974359   3.031056  2.837559e-03
# 97       GAC    69    34  base  88.461538  56.666667   5.862745  2.662385e-05
# 107      GGG    73    53  base  92.405063  58.241758   8.723270  1.965936e-07
# 112      GGU    80    37  base  94.117647  68.518519   7.351351  8.764599e-05
# 127      GUG    92    32  base  94.845361  58.181818  13.225000  4.530618e-08
# 157      GCC    47    52  base  83.928571  59.090909   3.615385  1.736158e-03
# 167      UAG    39    19  base  78.000000  43.181818   4.665072  6.742435e-04
# 177      UAC    51    17  base  94.444444  62.962963  10.000000  6.096964e-04
# 192      UGU    93    16  base  93.000000  51.612903  12.455357  9.942420e-07
# 197      UGC    81    26  base  87.096774  54.166667   5.711538  4.608113e-05
# 207      UUG    93    13  base  84.545455  56.521739   4.208145  7.753952e-03
# 222      UCA   120    14  base  92.307692  51.851852  11.142857  2.554140e-06
# 237      UCC    52    37  base  83.870968  60.655738   3.372973  4.813457e-03
# 252      CAU    55    89  base  79.710145  94.680851   0.220706  5.422030e-03

# %%
len(df_significant)
# Out:
# 20

# %%
df_ss_base
# Out:
#     sequence  N_ss  N_ds  part         ss          ds     ratio    pvalue
# 32       AGU    65    18  base  76.470588   81.818182  0.722222  0.776392
# 37       AGC    20    28  base  38.461538   50.000000  0.625000  0.250219
# 62       ACA   132   106  base  89.795918   89.830508  0.996226  1.000000
# 82       GAA   167    43  base  69.583333   79.629630  0.585218  0.181917
# 152      GCU    31    54  base  72.093023   75.000000  0.861111  0.826971
# 162      UAA   167    20  base  83.500000   95.238095  0.253030  0.212085
# 202      UUA   135     7  base  87.096774  100.000000  0.000000  0.598358
# 252      CAU    55    89  base  79.710145   94.680851  0.220706  0.005422
# 272      CGU    22    16  base  62.857143   66.666667  0.846154  0.789775
# 277      CGC     8    52  base  61.538462   65.822785  0.830769  0.761911
# 297      CUC    53    47  base  57.608696   67.142857  0.665030  0.254538

# %% [markdown]
# # Question 1b
# Are those preferences motif (purine/pyrimidine) - dependant?

# %%
R = ['A', 'G']
Y = ['U', 'C']
d_YYY = count_seqs(counts, [a+b+c for a in Y for b in Y for c in Y])[0]
d_RRR = count_seqs(counts, [a+b+c for a in R for b in R for c in R])[0]

# %%
d_YRY = count_seqs(counts,[a+b+c for a in Y for b in R for c in Y])[0]
d_RYR = count_seqs(counts,[a+b+c for a in R for b in Y for c in R])[0]

# %%
d_YRY['base']
# Out:
# {'N_ds': 246,
#  'N_ss': 563,
#  'ds': 71.09826589595376,
#  'p-value': 1.0399211638315497e-09,
#  'ratio': 2.7909974221693434,
#  'ss': 87.28682170542636}

# %%
fisher_counts(d_YYY, d_RRR, "nonspecif")
# Out:
# ('percent_ss', 17.99844840961986, 20.195930670685758)
# pvalue_ss 0.1637791883149834
# ('percent_ds', 37.724550898203596, 35.69794050343249)
# pvalue_ds 0.5463915710001818

# %%
fisher_counts(d_RYR, d_YRY, "nonspecif")
# Out:
# ('percent_ss', 14.361001317523057, 12.713178294573643)
# pvalue_ss 0.39074181612883946
# ('percent_ds', 31.196581196581196, 28.90173410404624)
# pvalue_ds 0.4883289695740797

# %% [markdown]
# # Question 1c
# Are those preferences sequence - dependant?

# %%
d_AAA = count_seqs(counts,["AAA"])[0]
print(d_AAA["base"])
print(d_AAA["nonspecif"])
# Out:
# {'ds': 77.77777777777777, 'ratio': 1.4155844155844155, 'ss': 83.20610687022901, 'N_ss': 327, 'N_ds': 7, 'p-value': 0.6523243788644034}
# {'ds': 22.22222222222222, 'ratio': 0.7064220183486238, 'ss': 16.793893129770993, 'N_ss': 66, 'N_ds': 2, 'p-value': 0.6523243788644034}

# %%
d_GGG = count_seqs(counts,["GGG"])[0]
print("Nb_bound")
print("N_ds", d_GGG["any"]["ds"],  "N_ss", d_GGG["any"]["ss"])
print("specific")
print( "ds", d_GGG["base"]["ds"], "ss", d_GGG["base"]["ss"])
print("non-specific")
print( "ds", d_GGG["nonspecif"]["ds"], "ss", d_GGG["nonspecif"]["ss"])
# Out:
# Nb_bound
# N_ds 100.0 N_ss 100.0
# specific
# ds 58.24175824175824 ss 92.40506329113924
# non-specific
# ds 41.75824175824176 ss 7.594936708860759

# %%
d_AAA
# Out:
# {'any': {'N_ds': 9,
#   'N_ss': 393,
#   'ds': 100.0,
#   'p-value': 1.0,
#   'ratio': nan,
#   'ss': 100.0},
#  'base': {'N_ds': 7,
#   'N_ss': 327,
#   'ds': 77.77777777777777,
#   'p-value': 0.6523243788644034,
#   'ratio': 1.4155844155844155,
#   'ss': 83.20610687022901},
#  'nonspecif': {'N_ds': 2,
#   'N_ss': 66,
#   'ds': 22.22222222222222,
#   'p-value': 0.6523243788644034,
#   'ratio': 0.7064220183486238,
#   'ss': 16.793893129770993},
#  'ph': {'N_ds': 9,
#   'N_ss': 358,
#   'ds': 100.0,
#   'p-value': 1.0,
#   'ratio': 0.0,
#   'ss': 91.0941475826972},
#  'sug': {'N_ds': 7,
#   'N_ss': 351,
#   'ds': 77.77777777777777,
#   'p-value': 0.2574413291935603,
#   'ratio': 2.3877551020408165,
#   'ss': 89.31297709923665}}

# %%
print(counts["AAA", "ds", "base"], counts["AAA", "ds", "any"] )
print(counts["GGG", "ds", "base"], counts["GGG", "ds", "any"] )
print(sum(mask_seq["AAA"]), sum(mask_seq["GGG"]))
sum(mask_seq["AAA"] & ds), sum(mask_seq["GGG"] & ds)
# Out:
# 7 9
# 53 91
# 1356 1043
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-ea497359c342> in <module>
#       2 print(counts["GGG", "ds", "base"], counts["GGG", "ds", "any"] )
#       3 print(sum(mask_seq["AAA"]), sum(mask_seq["GGG"]))
# ----> 4 sum(mask_seq["AAA"] & ds), sum(mask_seq["GGG"] & ds)
#
# NameError: name 'ds' is not defined

# %%
fisher_counts(d_AAA, d_GGG, "nonspecif")
# Out:
# ('percent_ss', 16.793893129770993, 7.594936708860759)
# pvalue_ss 0.039452799249061296
# ('percent_ds', 22.22222222222222, 41.75824175824176)
# pvalue_ds 0.308903234739957

# %%
fisher_counts(d_AAA, d_GGG, "base")
# Out:
# ('percent_ss', 83.20610687022901, 92.40506329113924)
# pvalue_ss 0.039452799249061296
# ('percent_ds', 77.77777777777777, 58.24175824175824)
# pvalue_ds 0.30890323473995707

# %% [markdown]
# Check where are the dsRNA AAA frag than bind via base

# %%
AAA_ds_base_vc = fragments[mask_seq["AAA"] & ds & mask_veryclose["base"]]
AAA_ds_base = fragments[mask_seq["AAA"] & ds & mask_close["base"]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-04fa65d006cb> in <module>
# ----> 1 AAA_ds_base_vc = fragments[mask_seq["AAA"] & ds & mask_veryclose["base"]]
#       2 AAA_ds_base = fragments[mask_seq["AAA"] & ds & mask_close["base"]]
#
# NameError: name 'ds' is not defined

# %%
m = AAA_ds_base_vc['structure']==b'6AEG'
AAA_ds_base_vc[m]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-0a0955a59566> in <module>
# ----> 1 m = AAA_ds_base_vc['structure']==b'6AEG'
#       2 AAA_ds_base_vc[m]
#
# NameError: name 'AAA_ds_base_vc' is not defined

# %%
m = AAA_ds_base['structure']==b'6AEG'
AAA_ds_base[m]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-265a3754206f> in <module>
# ----> 1 m = AAA_ds_base['structure']==b'6AEG'
#       2 AAA_ds_base[m]
#
# NameError: name 'AAA_ds_base' is not defined

# %%
count_AAA_ds_base_per_pdb = dict(zip(*np.unique(AAA_ds_base["structure"], return_counts = True)))
count_AAA_ds_base_per_pdb
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-f481ec247893> in <module>
# ----> 1 count_AAA_ds_base_per_pdb = dict(zip(*np.unique(AAA_ds_base["structure"], return_counts = True)))
#       2 count_AAA_ds_base_per_pdb
#
# NameError: name 'AAA_ds_base' is not defined

# %% [markdown]
# # Question 1d
# Are those differences due to protein-family properties ?
#
# get enzyme families at:
# https://enzyme.expasy.org/enzyme-byclass.html
#
# get pdbmap from ftp://ftp.ebi.ac.uk/pub/databases/Pfam/current_release

# %%
pdb_pfam = json.load(open("pfam.json"))
pdb_fam = json.load(open("fam.json"))

# %%
def inv_dict(d):
    inv_d = {}
    for k, val in d.items():
        if not isinstance(val, list):
            values = [val]
        else:
            values = val
        if len(values) == 0: continue
        for v in values:
            if v not in inv_d:
                inv_d[v] = []
            inv_d[v].append(k)
    return inv_d

# %%
fam_pdb = inv_dict(pdb_fam)
pfam_pdb = inv_dict(pdb_pfam)

# %%
# %run group_fam.py
group_fam = json.load(open("group_fam.json"))
fam_group = inv_dict(group_fam)

# %%
a =[k for k, i in group_fam.items() if len(i) == 1]
a.sort()
[str(i) for i in a]
# Out:
# ['1D-14L',
#  'ATP-synt_ab',
#  'Alba',
#  'Amino_oxidase',
#  'Ank',
#  'Anticodon_1',
#  'Btz',
#  'CAT_RBD',
#  'CLP1_P',
#  'CPE',
#  'CsrA',
#  'DKCLD',
#  'DNA_primase_lrg',
#  'Dicer_dimer',
#  'Dus',
#  'FXMRP1_C_core',
#  'GIIM',
#  'Glu-tRNAGln',
#  'HEAT_PBS',
#  'Hfq',
#  'HutP',
#  'IPPT',
#  'IgG_binding_B',
#  'KOW',
#  'KTI12',
#  'LSM',
#  'Macro',
#  'MafB19-deam',
#  'Myb_DNA-binding',
#  'N36',
#  'NHL',
#  'NUDIX_2',
#  'NusB',
#  'OAS1_C',
#  'PIN_4',
#  'PUA',
#  'PUF',
#  'Pept_tRNA_hydro',
#  'Phosphoprotein',
#  'Pkinase',
#  'Qua1',
#  'RHD_DNA_bind',
#  'RNA_GG_bind',
#  'ROQ_II',
#  'RRF',
#  'ResIII',
#  'RrnaAD',
#  'SAP',
#  'SBP_bac_1',
#  'SHS2_Rpb7-N',
#  'SLBP_RNA_bind',
#  'SPOC',
#  'SSB',
#  'STAR_dimer',
#  'SWIRM',
#  'She2p',
#  'SmpB',
#  'Staufen_C',
#  'TAL_effector',
#  'TGS',
#  'THUMP',
#  'TRAM',
#  'TROVE',
#  'Tap-RNA_bind',
#  'Telomerase_RBD',
#  'ThiI',
#  'Thrombin_light',
#  'Thx',
#  'Translin',
#  'TrpBP',
#  'Trypsin',
#  'V-set',
#  'Xpo1',
#  'YTH',
#  'dsrm',
#  'tRNA_SAD']

# %%
print(fam_pdb["GAD"])
print(pdb_fam['3DD2'])
# Out:
# ['4WJ4', '2D6F', '1C0A', '1EFW', '1IL2']
# ['1D-14L', 'Trypsin']

# %%
if "GFP" in fam_pdb:
    del fam_pdb['GFP']
pdb_fam['6B0B'] = [u'NAD1']

# %%
def count_fam_to_group(count_per_fam):
    count_per_group = {}
    for fam, n in count_per_fam.items():
        group = fam_group[fam]
        if len(group) > 0:
            for g in group:
                if g not in count_per_group:
                    count_per_group[g] = 0
                count_per_group[g] += n
    return count_per_group

# %%
def map_fam_to_group(group_fam, fam_group, fam_pdb):
    group_pdb = {}
    for fam, pdb in fam_pdb.items():
        if fam in fam_group:
            group = fam_group[fam]
            if len(group) > 0:
                for g in group:
                    if g not in group_pdb:
                        group_pdb[g] = []
                    group_pdb[g].append(pdb)
        else:
            print(fam)
    return group_pdb

# %%
def count_pdb_to_fam(count_per_pdb, pdb_pfam):  
    count_per_pfam = {}
    for pdb, n in count_per_pdb.items():
        pfams = pdb_pfam[pdb.decode()]
        if len(pfams) > 0:
            for pfam in pfams:
                if pfam not in count_per_pfam:
                    count_per_pfam[pfam] = 0
                count_per_pfam[pfam] += n
    return count_per_pfam

# %%
group_pdb = {}
for fam, pdbs in fam_pdb.items():
    groups = fam_group[fam]
    for group in groups:
        if group not in group_pdb:
            group_pdb[group] = []
        for pdb in pdbs:
            group_pdb[group].append(pdb)
group_pdb
# Out:
# {'1D-14L': ['3DD2'],
#  'AAA': ['4QM6B', '4QM6A', '2XZL', '4B3G', '2XZO', '2XZL', '4B3G', '2XZO'],
#  'ATP-synt_ab': ['3ICE', '5JJI', '5JJK', '5JJL'],
#  'Ago': ['2HYI',
#   '2XB2',
#   '2J0S',
#   '2J0Q',
#   '3EX7',
#   '4F1N',
#   '5VM9',
#   '4OLA',
#   '4W5O',
#   '4Z4D',
#   '5W6V',
#   '4Z4E',
#   '5JS2',
#   '4Z4C',
#   '4KRE',
#   '5T7B',
#   '4W5R',
#   '4Z4I',
#   '6CBD',
#   '4W5Q',
#   '4KRF',
#   '5JS1',
#   '4W5T',
#   '5WEA',
#   '4F3T',
#   '4W5N',
#   '4Z4F',
#   '4KXT',
#   '4Z4G',
#   '5KI6',
#   '4Z4H',
#   '4OLB',
#   '5VM9',
#   '4OLA',
#   '4W5O',
#   '4Z4D',
#   '5W6V',
#   '4Z4E',
#   '5JS2',
#   '4Z4C',
#   '4KRE',
#   '5T7B',
#   '4W5R',
#   '4Z4I',
#   '6CBD',
#   '4W5Q',
#   '4KRF',
#   '5JS1',
#   '4W5T',
#   '5WEA',
#   '4F3T',
#   '4W5N',
#   '4Z4F',
#   '4KXT',
#   '4Z4G',
#   '5KI6',
#   '4Z4H',
#   '4OLB',
#   '5VM9',
#   '4OLA',
#   '4W5O',
#   '4Z4D',
#   '5W6V',
#   '4Z4E',
#   '5JS2',
#   '4Z4C',
#   '4KRE',
#   '5T7B',
#   '4W5R',
#   '4Z4I',
#   '6CBD',
#   '4W5Q',
#   '4KRF',
#   '5JS1',
#   '4W5T',
#   '5WEA',
#   '4F3T',
#   '4W5N',
#   '4Z4F',
#   '4KXT',
#   '4Z4G',
#   '5KI6',
#   '4Z4H',
#   '4OLB',
#   '4F1N',
#   '5GUH',
#   '5VM9',
#   '2F8S',
#   '4OLA',
#   '4W5O',
#   '4Z4D',
#   '5W6V',
#   '3HM9',
#   '4Z4E',
#   '5JS2',
#   '3HK2',
#   '4Z4C',
#   '4KRE',
#   '5T7B',
#   '3HXM',
#   '4W5R',
#   '4F1N',
#   '4Z4I',
#   '2BGG',
#   '6CBD',
#   '4W5Q',
#   '4KRF',
#   '5JS1',
#   '3F73',
#   '1YTU',
#   '4W5T',
#   '5WEA',
#   '4F3T',
#   '2F8T',
#   '4W5N',
#   '4Z4F',
#   '4KXT',
#   '3HO1',
#   '3HJF',
#   '4Z4G',
#   '5XOW',
#   '5KI6',
#   '4Z4H',
#   '3HVR',
#   '5AWH',
#   '4OLB',
#   '3HM9',
#   '3HK2',
#   '3HXM',
#   '3F73',
#   '3HO1',
#   '3HJF',
#   '5XOW',
#   '3HVR',
#   '2F8S',
#   '2F8T',
#   '5VM9',
#   '4OLA',
#   '4W5O',
#   '4Z4D',
#   '5W6V',
#   '4Z4E',
#   '5JS2',
#   '2L5D',
#   '4Z4C',
#   '4KRE',
#   '5T7B',
#   '4W5R',
#   '4Z4I',
#   '6CBD',
#   '4W5Q',
#   '4KRF',
#   '5JS1',
#   '4W5T',
#   '5WEA',
#   '4F3T',
#   '4W5N',
#   '4Z4F',
#   '4KXT',
#   '4Z4G',
#   '5KI6',
#   '4Z4H',
#   '2XFM',
#   '4OLB',
#   '5W6V',
#   '5GUH',
#   '5VM9',
#   '4OLA',
#   '4NGC',
#   '1SI3',
#   '4W5O',
#   '4Z4D',
#   '5W6V',
#   '3O7V',
#   '4Z4E',
#   '5JS2',
#   '2L5D',
#   '4Z4C',
#   '4KRE',
#   '5ZAM',
#   '5T7B',
#   '4NHA',
#   '4W5R',
#   '5ZAL',
#   '4Z4I',
#   '4NGD',
#   '4NH6',
#   '4NGG',
#   '6CBD',
#   '4W5Q',
#   '4NGF',
#   '4KRF',
#   '5JS1',
#   '4W5T',
#   '5WEA',
#   '4F3T',
#   '4W5N',
#   '4Z4F',
#   '4KXT',
#   '4NGB',
#   '4Z4G',
#   '5KI6',
#   '3O3I',
#   '4NH3',
#   '4Z4H',
#   '2XFM',
#   '3O6E',
#   '4NH5',
#   '3MJ0',
#   '4OLB'],
#  'Alba': ['3WBM', '3IAB'],
#  'Amino_oxidase': ['4XBF'],
#  'Ank': ['4OAU', '4OAV'],
#  'Anticodon_1': ['4AQ7',
#   '2CSX',
#   '2BTE',
#   '1IVS',
#   '4ARI',
#   '1FFY',
#   '5OMW',
#   '2CT8',
#   '1WZ2',
#   '5AH5',
#   '3ZJV',
#   '4ARC',
#   '3ZJU',
#   '5ONH',
#   '2BYT',
#   '5ON2',
#   '1QU2',
#   '1QU3',
#   '3ZGZ',
#   '1GAX',
#   '4CQN',
#   '4AS1',
#   '2V0G',
#   '5ON3',
#   '3ZJT'],
#  'Btz': ['2HYI', '2XB2', '2J0S', '2J0Q', '3EX7'],
#  'CAT_RBD': ['1L1C'],
#  'CEBP': ['2MKI', '2MKK', '2MKK'],
#  'CLP1': ['4OHZ', '4OHZ', '4OHZ'],
#  'CLP1_P': ['4OHZ'],
#  'CPSF': ['6FUW'],
#  'CRISPR': ['5XBL',
#   '4ZT0',
#   '4ZT9',
#   '5FW2',
#   '5AXW',
#   '4OO8',
#   '5B2R',
#   '5B2S',
#   '5B2T',
#   '4UN5',
#   '5VW1',
#   '5FW3',
#   '5F9R',
#   '5CZZ',
#   '4UN4',
#   '4UN3',
#   '5FQ5',
#   '5FW1',
#   '5XBL',
#   '4ZT0',
#   '4ZT9',
#   '5FW2',
#   '5AXW',
#   '4OO8',
#   '5B2R',
#   '5B2S',
#   '5B2T',
#   '4UN5',
#   '5VW1',
#   '5FW3',
#   '5F9R',
#   '5CZZ',
#   '4UN4',
#   '4UN3',
#   '5FQ5',
#   '5FW1',
#   '4ILM',
#   '4C8Z',
#   '4C9D',
#   '4C8Y',
#   '4ILL',
#   '4U7U',
#   '4QYZ',
#   '5H9E',
#   '5H9F',
#   '5CD4',
#   '5XUT',
#   '5XH7',
#   '5XH6',
#   '5XUS',
#   '5B43',
#   '5ID6',
#   '5XUU',
#   '5KK5',
#   '5XUZ',
#   '5NG6',
#   '5XUT',
#   '5XH7',
#   '5XH6',
#   '5XUS',
#   '5B43',
#   '5ID6',
#   '5XUU',
#   '5KK5',
#   '5XUZ',
#   '5NG6',
#   '4U7U',
#   '4QYZ',
#   '5H9E',
#   '2Y8W',
#   '3QRP',
#   '2Y9H',
#   '3QRR',
#   '5H9F',
#   '2Y8Y',
#   '5CD4',
#   '5AXW',
#   '5CZZ',
#   '4U7U',
#   '4QYZ',
#   '5H9E',
#   '5H9F',
#   '5CD4'],
#  'CSD': ['3TS2',
#   '3PF4B',
#   '3PF4A',
#   '3TRZ',
#   '4ALP',
#   '5UDZ',
#   '3PF5A',
#   '3TS0',
#   '4QQB',
#   '3PF5B',
#   '2VNU',
#   '5JEA',
#   '4IFD',
#   '5K36',
#   '4PMW',
#   '5VZJ',
#   '2IX1',
#   '2VNU',
#   '5JEA',
#   '4IFD',
#   '5K36',
#   '4PMW',
#   '5VZJ'],
#  'Cas': ['4U7U',
#   '4QYZ',
#   '5H9E',
#   '5H9F',
#   '5CD4',
#   '4Z7L',
#   '3WZI',
#   '5XBL',
#   '4ZT0',
#   '4ZT9',
#   '5FW2',
#   '5AXW',
#   '4OO8',
#   '5B2R',
#   '5B2S',
#   '5B2T',
#   '4UN5',
#   '5VW1',
#   '5FW3',
#   '5F9R',
#   '5CZZ',
#   '4UN4',
#   '4UN3',
#   '5FQ5',
#   '5FW1',
#   '4ILM',
#   '4C8Z',
#   '4C9D',
#   '4C8Y',
#   '4ILL',
#   '5XBL',
#   '4ZT0',
#   '4ZT9',
#   '5FW2',
#   '4OO8',
#   '5B2R',
#   '5B2S',
#   '5B2T',
#   '4UN5',
#   '5VW1',
#   '5FW3',
#   '5F9R',
#   '4UN4',
#   '4UN3',
#   '5FQ5',
#   '5FW1',
#   '3IE1',
#   '3AF6',
#   '3IEM',
#   '5XBL',
#   '4ZT0',
#   '4ZT9',
#   '5FW2',
#   '4OO8',
#   '5B2R',
#   '5B2S',
#   '5B2T',
#   '4UN5',
#   '5VW1',
#   '5FW3',
#   '5F9R',
#   '4UN4',
#   '4UN3',
#   '5FQ5',
#   '5FW1',
#   '4FWT',
#   '3AVV',
#   '3AVT',
#   '3AVW',
#   '3AVY',
#   '3VNV',
#   '3AVU',
#   '3AVX',
#   '3VNU',
#   '5AXW',
#   '5CZZ',
#   '4ILM',
#   '4ILL',
#   '3QJJ',
#   '3PKM',
#   '3QJL',
#   '3QJP',
#   '3X1L',
#   '5X2H',
#   '5AXW',
#   '5X2G',
#   '5CZZ',
#   '3I5X',
#   '2HYI',
#   '2XB2',
#   '4TZ0',
#   '5JCF',
#   '5JC3',
#   '4TYY',
#   '5E3H',
#   '3FHT',
#   '4D26',
#   '3PEW',
#   '3I61',
#   '4TZ6',
#   '5F9F',
#   '5LTAB',
#   '3SQX',
#   '3SQW',
#   '4TYW',
#   '2J0S',
#   '2DB3',
#   '3G0H',
#   '5ZAM',
#   '5AOR',
#   '5JAJB',
#   '4AY2',
#   '5JB2',
#   '5ZAL',
#   '5LTAA',
#   '5SUP',
#   '4D25',
#   '3ZD6',
#   '2J0Q',
#   '5ELX',
#   '4BPB',
#   '5JC7',
#   '2XGJ',
#   '3I62',
#   '5F9H',
#   '3EX7',
#   '3ZD7',
#   '2YKG',
#   '5JCH',
#   '3RC8',
#   '4DB2',
#   '3I5Y',
#   '5JAJA',
#   '5JBG',
#   '3PEY',
#   '5F98',
#   '4U7U',
#   '4QYZ',
#   '5H9E',
#   '5H9F',
#   '5CD4',
#   '5AXW',
#   '5CZZ',
#   '4Z7L',
#   '4AL6',
#   '5O6U',
#   '4AL7',
#   '4AL5',
#   '2XLI',
#   '5O7H',
#   '2XLJ',
#   '2XLK',
#   '3X1L'],
#  'CsrA': ['2MFC',
#   '2MFG',
#   '2MFH',
#   '2JPP',
#   '2MF0',
#   '4KJI',
#   '2MFF',
#   '2MFE',
#   '2MF1'],
#  'Cyclin': ['2W2H'],
#  'DKCLD': ['2HVY',
#   '2RFK',
#   '3MQK',
#   '3LWP',
#   '3HAX',
#   '3LWO',
#   '3LWV',
#   '3HJW',
#   '3LWQ',
#   '3LWR'],
#  'DNA_pol': ['4FXD',
#   '4Q5V',
#   '4A93',
#   '2VUM',
#   '5XOG',
#   '4A3D',
#   '4A3K',
#   '4BY7',
#   '4Y52',
#   '3S2H',
#   '3RZD',
#   '3S17',
#   '3S2D',
#   '3S1Q',
#   '3HOV',
#   '3S1R',
#   '1I6H',
#   '4A3C',
#   '3HOU',
#   '5OT2',
#   '3GTJ',
#   '3S1M',
#   '3M3Y',
#   '4A3F',
#   '3PO3',
#   '4A3B',
#   '2NVT',
#   '2E2I',
#   '4BXX',
#   '3HOY',
#   '2YU9',
#   '1R9T',
#   '4Y7N',
#   '3PO2',
#   '2NVQ',
#   '3S16',
#   '3S14',
#   '3S15',
#   '3RZO',
#   '3S1N',
#   '3GTL',
#   '4A3E',
#   '2E2J',
#   '4FXD',
#   '4Q5V',
#   '4BWM',
#   '5C0Y',
#   '5K36',
#   '4OO1',
#   '5VZJ'],
#  'DNA_primase_lrg': ['5F0S', '5F0Q'],
#  'Dicer_dimer': ['5ZAM', '5ZAL'],
#  'Dus': ['3B0U', '4YCO', '4YCP'],
#  'EC_3_5_1': ['2D6F', '3KFU', '3AL0', '2D6F'],
#  'EC_3_5_4': ['5W3V', '2B3J', '6B0B', '2GXB', '5ED1', '5HP3', '5HP2', '5ED2'],
#  'EC_4_2_1': ['3SNP', '3SN2', '3SNP', '3SN2'],
#  'EF': ['3QSY',
#   '4FWT',
#   '1TTT',
#   '3AVV',
#   '3AVT',
#   '1OB5',
#   '3AVW',
#   '3AVY',
#   '3VNV',
#   '3AVU',
#   '3AVX',
#   '1B23',
#   '1OB2',
#   '3VNU',
#   '2PJP',
#   '2UWM',
#   '1WSU',
#   '2PLY',
#   '4GG4',
#   '2UWM',
#   '2PLY',
#   '4FWT',
#   '1TTT',
#   '3AVV',
#   '3AVT',
#   '1OB5',
#   '3AVW',
#   '3AVY',
#   '3VNV',
#   '3AVU',
#   '3AVX',
#   '1B23',
#   '1OB2',
#   '3VNU',
#   '2UWM',
#   '2PLY',
#   '5XOG',
#   '4FWT',
#   '3AVV',
#   '3AVT',
#   '3AVW',
#   '3AVY',
#   '3VNV',
#   '3AVU',
#   '3AVX',
#   '3VNU',
#   '3QSY',
#   '4FWT',
#   '1TTT',
#   '3AVV',
#   '3AVT',
#   '1OB5',
#   '3AVW',
#   '3AVY',
#   '3VNV',
#   '3AVU',
#   '3AVX',
#   '1B23',
#   '1OB2',
#   '3VNU'],
#  'FXMRP1_C_core': ['2LA5', '5DE8', '5DE5', '5DEA'],
#  'Formyl_trans': ['2FMT', '2FMT'],
#  'GIIM': ['6AR3', '6AR1'],
#  'GTPase': ['3R9X', '3IEVB', '3R9W', '3IEVA'],
#  'Gat': ['2D6F', '3KFU', '2D6F', '3AL0', '3KFU', '2D6F', '3AL0'],
#  'Glu-tRNAGln': ['3KFU', '3AL0'],
#  'HD': ['1OOA', '3WFRB', '3WFS', '3WFRA', '1OOA'],
#  'HEAT_PBS': ['5D0B', '5D0A', '5T8Y'],
#  'Helicase': ['3RC8',
#   '5LTAB',
#   '5AOR',
#   '5LTAA',
#   '3I5X',
#   '2HYI',
#   '2XB2',
#   '4TZ0',
#   '4TYY',
#   '5E3H',
#   '3FHT',
#   '4D26',
#   '3PEW',
#   '3I61',
#   '4TZ6',
#   '5F9F',
#   '5LTAB',
#   '3SQX',
#   '3SQW',
#   '4TYW',
#   '2J0S',
#   '2DB3',
#   '3G0H',
#   '5AOR',
#   '4AY2',
#   '5LTAA',
#   '5SUP',
#   '4D25',
#   '3ZD6',
#   '2J0Q',
#   '5ELX',
#   '4BPB',
#   '2XGJ',
#   '3I62',
#   '5F9H',
#   '3EX7',
#   '3ZD7',
#   '2YKG',
#   '3I5Y',
#   '3PEY',
#   '5F98',
#   '2XGJ',
#   '3RC8',
#   '2XGJ',
#   '3RC8',
#   '5C0Y',
#   '5K36',
#   '4OO1',
#   '5VZJ',
#   '2JLZ',
#   '5GJB',
#   '2JLY',
#   '5MFX',
#   '3O8R',
#   '2JLV',
#   '3O8C',
#   '2JLW',
#   '4E78',
#   '2JLX',
#   '2JLU',
#   '5XC6',
#   '3I5X',
#   '2HYI',
#   '2XB2',
#   '4TZ0',
#   '5JCF',
#   '5JC3',
#   '4TYY',
#   '5E3H',
#   '3FHT',
#   '4D26',
#   '3PEW',
#   '3I61',
#   '4TZ6',
#   '5F9F',
#   '5LTAB',
#   '3SQX',
#   '3SQW',
#   '4TYW',
#   '2J0S',
#   '2DB3',
#   '3G0H',
#   '5ZAM',
#   '5AOR',
#   '5JAJB',
#   '4AY2',
#   '5JB2',
#   '5ZAL',
#   '5LTAA',
#   '5SUP',
#   '4D25',
#   '3ZD6',
#   '2J0Q',
#   '5ELX',
#   '4BPB',
#   '5JC7',
#   '2XGJ',
#   '3I62',
#   '5F9H',
#   '3EX7',
#   '3ZD7',
#   '2YKG',
#   '5JCH',
#   '3RC8',
#   '4DB2',
#   '3I5Y',
#   '5JAJA',
#   '5JBG',
#   '3PEY',
#   '5F98',
#   '3MOJ',
#   '5LTAB',
#   '5AOR',
#   '5LTAA',
#   '2XZL'],
#  'Hfq': ['3RER',
#   '4QVD',
#   '1KQ2',
#   '3HSB',
#   '4HT9',
#   '4Y91',
#   '3AHU',
#   '4V2S',
#   '4NL3',
#   '4HT8',
#   '4QVC',
#   '3GIB',
#   '5NEW'],
#  'HutP': ['3BOY', '1WPU', '1WRQ', '1WMQ'],
#  'IPPT': ['2ZXU', '3EPK', '2ZM5', '3EPJ', '3EPH', '3FOZ'],
#  'IgG_binding_B': ['2I2Y'],
#  'KH': ['4WAL',
#   '5ELSB',
#   '2N8L',
#   '3AEV',
#   '5WWX',
#   '1K1G',
#   '5EMO',
#   '4JVH',
#   '2ANN',
#   '4JVYB',
#   '5ELR',
#   '2ANR',
#   '5ELT',
#   '1EC6',
#   '4AM3',
#   '5WWW',
#   '5ELSA',
#   '4JVYA',
#   '2MJH',
#   '2N8M',
#   '2PY9',
#   '4WAN',
#   '4B8T',
#   '1XMO',
#   '4DUYA',
#   '4LFB',
#   '3R9X',
#   '4B3T',
#   '4DR3',
#   '4B3R',
#   '1XNR',
#   '4B3S',
#   '1IBL',
#   '4YHH',
#   '2UUA',
#   '4DR6',
#   '4DV6B',
#   '4JYA',
#   '4X64',
#   '4GKJ',
#   '1HR0',
#   '4LF6',
#   '4B3M',
#   '5IWAB',
#   '4DV6A',
#   '4JI3',
#   '4JI1',
#   '2E5L',
#   '3IEVB',
#   '4DR5A',
#   '1IBM',
#   '3T1Y',
#   '1N33',
#   '4X65',
#   '1FJG',
#   '3R9W',
#   '3IEVA',
#   '2HHH',
#   '2UU9',
#   '2VQE',
#   '4LF8',
#   '1XNQ',
#   '1I94',
#   '4JI7A',
#   '2UUB',
#   '5BR8',
#   '4DV7',
#   '1N32',
#   '4DR5B',
#   '4LF7',
#   '4LF4',
#   '4JV5',
#   '4AQY',
#   '5IWAA',
#   '4LF9',
#   '2UXD',
#   '2UXB',
#   '4JI7B',
#   '2UUC',
#   '1HNW',
#   '4KHP',
#   '1J5E',
#   '2VQF',
#   '4GKK',
#   '4DR2',
#   '4JI0A',
#   '1HNX',
#   '2ZM6',
#   '4DUYB',
#   '4X66',
#   '3T1H',
#   '1HNZ',
#   '2UXC',
#   '4JI0B',
#   '4K0K',
#   '4X62',
#   '1XMQ',
#   '1IBK',
#   '3AF6',
#   '2ATW',
#   '2ASB',
#   '5LM7',
#   '5JEA',
#   '4IFD',
#   '5K36',
#   '4OO1',
#   '5VZJ'],
#  'KOW': ['3CCQ',
#   '1KC8',
#   '2D3O',
#   '1YHQ',
#   '3CMA',
#   '3CF5',
#   '1VQ5',
#   '3CCJ',
#   '1VQO',
#   '5JVGA',
#   '1N8R',
#   '1QVG',
#   '1VQ6',
#   '5NRGB',
#   '3CXC',
#   '3CD6',
#   '1Q86',
#   '1Q7Y',
#   '1JJ2',
#   '4WF9',
#   '2QEX',
#   '1M90',
#   '1YJW',
#   '1VQL',
#   '1NJI',
#   '1VQ7',
#   '1YI2',
#   '1NWY',
#   '4WFB',
#   '1QVF',
#   '1VQK',
#   '4WFA',
#   '3CCE',
#   '3CC2',
#   '3I55',
#   '1VQ9',
#   '3G4S',
#   '1VQ8',
#   '3CC4',
#   '1VQM',
#   '1Q81',
#   '1NKW',
#   '3DLL',
#   '4IOA',
#   '3OW2',
#   '1XBP',
#   '1NWX',
#   '4IO9',
#   '3G71',
#   '3G6E',
#   '3PIP',
#   '5DM6',
#   '3CCL',
#   '3PIO',
#   '1YJN',
#   '3CCR',
#   '1VQP',
#   '2ZJQ',
#   '3CCS',
#   '3CCM',
#   '1K9M',
#   '1YJ9B',
#   '1SM1',
#   '1KQS',
#   '2OTL',
#   '1S72',
#   '3CC7',
#   '3CME',
#   '2ZJR',
#   '5DM7',
#   '3I56',
#   '1W2B',
#   '3CPW',
#   '1YJ9A',
#   '1YIJ',
#   '1K73',
#   '3CCU',
#   '5NRGA',
#   '1K8A',
#   '2OTJ',
#   '1YIT',
#   '5JVGB',
#   '1FFK',
#   '1VQ4',
#   '1M1K',
#   '1VQN',
#   '1KD1',
#   '1Q82',
#   '3CCV'],
#  'KTI12': ['3ADB', '3ADD', '3AM1', '3ADC'],
#  'LRR': ['1A9N',
#   '3CIY',
#   '3CIY',
#   '4Z0C',
#   '5GMF',
#   '5GMG',
#   '3CIY',
#   '4Z0C',
#   '5GMF',
#   '5GMG'],
#  'LSM': ['1M8V', '4M7D', '1I5L', '4PJO', '4M7A'],
#  'La': ['1XOK',
#   '1AV6',
#   '4GCW',
#   '2FK6',
#   '5HAB',
#   '3T3N',
#   '3T3O',
#   '5DTO',
#   '2XBM',
#   '1ZH5',
#   '1YTY',
#   '2VOO',
#   '4WKR',
#   '2VON',
#   '2VOP',
#   '2VOD',
#   '3NMU',
#   '5GIN',
#   '5GIP',
#   '4BY9',
#   '3NVK',
#   '3PLA',
#   '4XWW',
#   '3IE1',
#   '5A0V',
#   '3IEM',
#   '5A0T',
#   '3HTX',
#   '2JLZ',
#   '5GJB',
#   '2JLY',
#   '5MFX',
#   '3O8R',
#   '2JLV',
#   '3O8C',
#   '2JLW',
#   '4E78',
#   '2JLX',
#   '2JLU',
#   '5XC6',
#   '6FQ3',
#   '6FQL',
#   '3AF6'],
#  'Lactamase': ['4XWW',
#   '5HAB',
#   '3IE1',
#   '5A0V',
#   '3T3N',
#   '3AF6',
#   '3IEM',
#   '3T3O',
#   '5A0T',
#   '4GCW',
#   '2FK6',
#   '5HAB',
#   '3T3N',
#   '3T3O',
#   '4XWW',
#   '3IE1',
#   '5A0V',
#   '3IEM',
#   '5A0T',
#   '3AF6'],
#  'Lys': ['5JEA', '4M4O', '4M6D'],
#  'MPP6': ['5VZJ'],
#  'MRP': ['2LA5', '5DE8', '5DE5', '5DEA', '2GJE'],
#  'Macro': ['4TU0'],
#  'MafB19-deam': ['2B3J'],
#  'Methyltr': ['2BH2',
#   '3BT7',
#   '5XJ2',
#   '3OIN',
#   '3OIJ',
#   '4YVJ',
#   '4YVK',
#   '4YVI',
#   '2DET',
#   '2DEU',
#   '2DER',
#   '4N48',
#   '5DTO',
#   '2XBM',
#   '4KR6',
#   '4KR7',
#   '4KR9',
#   '5CCBA',
#   '5CCXA',
#   '5CCXB',
#   '5CCBB',
#   '3HTX',
#   '2ZZN',
#   '2ZZM',
#   '3HTX',
#   '5CCBA',
#   '5CCXA',
#   '5CCXB',
#   '5CCBB',
#   '5WWS',
#   '5WWR',
#   '5WWT'],
#  'Myb_DNA-binding': ['4XBF'],
#  'N36': ['5LM7', '1QFQ'],
#  'NHL': ['4ZLR', '6FQ3', '6FQL', '5EX7'],
#  'NTP_transf': ['2ZHA',
#   '3OVS',
#   '2ZH9',
#   '2ZH6',
#   '4IG8',
#   '4X4VA',
#   '4X4NB',
#   '2DR5',
#   '1TFW',
#   '3OVBA',
#   '4X4TB',
#   '4X4VB',
#   '4X4TA',
#   '3OVA',
#   '2ZH3',
#   '2ZH5',
#   '4X4O',
#   '5W0M',
#   '4X4Q',
#   '2Q66',
#   '4RWP',
#   '3OV7',
#   '4RWN',
#   '3OVBB',
#   '2DVI',
#   '2ZH2',
#   '2DR7',
#   '2DRB',
#   '2ZHB',
#   '4RWO',
#   '5W0O',
#   '3OUY',
#   '4X4U',
#   '2ZH1',
#   '4X4P',
#   '4X4R',
#   '1TFY',
#   '4X4NA',
#   '2DRA',
#   '4X4S',
#   '2DR9',
#   '2DR8',
#   '2ZH4',
#   '2ZH8',
#   '2ZH7'],
#  'NUC': ['5IP2',
#   '3T5Q',
#   '3T5N',
#   '2ZHA',
#   '3OVS',
#   '2ZH9',
#   '2ZH6',
#   '4X4VA',
#   '4X4NB',
#   '2DR5',
#   '1TFW',
#   '3OVBA',
#   '4X4TB',
#   '4X4VB',
#   '4X4TA',
#   '3OVA',
#   '2ZH3',
#   '2ZH5',
#   '4X4O',
#   '4X4Q',
#   '3OV7',
#   '3OVBB',
#   '2DVI',
#   '2ZH2',
#   '2DR7',
#   '2DRB',
#   '2ZHB',
#   '3OUY',
#   '4X4U',
#   '2ZH1',
#   '4X4P',
#   '4X4R',
#   '1TFY',
#   '4X4NA',
#   '2DRA',
#   '4X4S',
#   '2DR9',
#   '2DR8',
#   '2ZH4',
#   '2ZH8',
#   '2ZH7',
#   '1YYW',
#   '1RC7',
#   '5ZAM',
#   '5ZAL',
#   '2NUGA',
#   '1YYO',
#   '2NUF',
#   '2NUGB',
#   '5T16',
#   '2NUE',
#   '4OOG',
#   '1YZ9',
#   '2EZ6',
#   '4M30',
#   '4M2Z',
#   '1YYK',
#   '4BWM',
#   '4J1G',
#   '4JNG',
#   '3ZLA',
#   '4BHH',
#   '4IJS',
#   '5XUT',
#   '5XH7',
#   '5XH6',
#   '5XUS',
#   '5B43',
#   '5ID6',
#   '5XUU',
#   '5KK5',
#   '5XUZ',
#   '5NG6',
#   '4OAU',
#   '4OAV'],
#  'NUDIX_2': ['3P6Y', '3MDG', '3MDI', '3Q2T'],
#  'Nop': ['2HVY',
#   '2RFK',
#   '3MQK',
#   '3LWP',
#   '3HAX',
#   '3LWO',
#   '3LWV',
#   '3HJW',
#   '3LWQ',
#   '3LWR',
#   '3NVI',
#   '3NMU',
#   '3SIU',
#   '5GIN',
#   '5GIP',
#   '4BY9',
#   '2OZB',
#   '3NVK',
#   '3PLA',
#   '3SIV'],
#  'Nucleotidyltransferase': ['4AM3'],
#  'NusA': ['5LM7'],
#  'NusB': ['3R2D', '4EYA', '5LM7', '3R2C'],
#  'OAS1_C': ['4IG8', '4S3N', '4RWP', '4RWN', '4RWO'],
#  'PAP': ['5W0M',
#   '5W0O',
#   '2Q66',
#   '1AV6',
#   '4WC2',
#   '4WC7',
#   '4WC3',
#   '4WC6',
#   '3WFRB',
#   '3WFS',
#   '4X0B',
#   '5HC9',
#   '4WC5',
#   '4WC4',
#   '3WFRA',
#   '1VFG',
#   '2Q66',
#   '3WFRB',
#   '3WFS',
#   '5HC9',
#   '3WFRA'],
#  'PIN_4': ['5JEA', '4IFD', '5K36', '5VZJ'],
#  'PPR': ['4OE1', '4M59', '4OE1', '4M59', '4OE1', '4M59', '4OE1', '4M59'],
#  'PUA': ['2HVY',
#   '2RFK',
#   '3MQK',
#   '3LWP',
#   '3HAX',
#   '1ZE2',
#   '3LWO',
#   '3LWV',
#   '3HJW',
#   '1J2B',
#   '2AB4',
#   '1R3E',
#   '3LWQ',
#   '3LWR'],
#  'PUF': ['3K49',
#   '5BZ1A',
#   '5BZU',
#   '5KLA',
#   '5WTY',
#   '2YJY',
#   '3BX2',
#   '3Q0L',
#   '3K4E',
#   '3BSB',
#   '3V6Y',
#   '3K5Z',
#   '5BZ5',
#   '3Q0P',
#   '3QGC',
#   '3K61',
#   '3K5Q',
#   '3Q0M',
#   '3V74',
#   '3BSX',
#   '3Q0R',
#   '3V71',
#   '1M8Y',
#   '3BX3',
#   '3K64',
#   '3K5Y',
#   '5BYM',
#   '1M8WA',
#   '5BZ1B',
#   '3Q0N',
#   '3Q0O',
#   '3QGB',
#   '3QG9',
#   '1M8WB',
#   '3Q0Q',
#   '5BZV',
#   '4DZS',
#   '1M8X',
#   '3Q0S',
#   '3K62'],
#  'Pept_tRNA_hydro': ['3VJR'],
#  'Peptidase': ['3O8R', '3O8C', '4FSJ', '4FTE', '1F8V', '4FTS', '4FTB', '2BBV'],
#  'Phosphoprotein': ['3HHZ'],
#  'Pkinase': ['4OAU', '4OAV'],
#  'PseudoU_synth': ['2NQP',
#   '1ZL3',
#   '1K8W',
#   '4LGT',
#   '3DH3',
#   '2I82',
#   '2HVY',
#   '1ZL3',
#   '2RFK',
#   '3MQK',
#   '3LWP',
#   '3HAX',
#   '1ZE2',
#   '3LWO',
#   '3LWV',
#   '3HJW',
#   '2AB4',
#   '1R3E',
#   '3LWQ',
#   '1K8W',
#   '3LWR',
#   '4KR6',
#   '4KR7',
#   '4KR9',
#   '2HVY',
#   '1ZL3',
#   '2RFK',
#   '3MQK',
#   '3LWP',
#   '3HAX',
#   '1ZE2',
#   '3LWO',
#   '3LWV',
#   '3HJW',
#   '2AB4',
#   '1R3E',
#   '3LWQ',
#   '1K8W',
#   '3LWR',
#   '2HVY',
#   '2RFK',
#   '3MQK'],
#  'Qua1': ['5ELSB', '5EMO', '5ELR', '5ELT', '5ELSA'],
#  'RHD_DNA_bind': ['1OOA'],
#  'RIG': ['5JCF',
#   '5JC3',
#   '5E3H',
#   '5F9F',
#   '5JAJB',
#   '4AY2',
#   '5JB2',
#   '3ZD6',
#   '4BPB',
#   '5JC7',
#   '5F9H',
#   '3ZD7',
#   '2YKG',
#   '5JCH',
#   '5JAJA',
#   '5JBG',
#   '5F98',
#   '2AAR',
#   '2D3O',
#   '1W2B',
#   '5JCF',
#   '5JC3',
#   '5E3H',
#   '5F9F',
#   '3NCU',
#   '5JAJB',
#   '4AY2',
#   '5JB2',
#   '3ZD6',
#   '3LRR',
#   '4BPB',
#   '3EQT',
#   '5JC7',
#   '5F9H',
#   '3ZD7',
#   '2YKG',
#   '3LRN',
#   '5JCH',
#   '5JAJA',
#   '5JBG',
#   '3OG8',
#   '5F98'],
#  'RNA_GG_bind': ['2XC7'],
#  'RNA_cyclase': ['4O8J', '4O8J'],
#  'RNA_pol': ['5E17',
#   '4A93',
#   '2VUM',
#   '5XOG',
#   '4A3D',
#   '4A3K',
#   '4BY7',
#   '4Y52',
#   '3S2H',
#   '3RZD',
#   '3S17',
#   '3S2D',
#   '3S1Q',
#   '2O5J',
#   '5E18',
#   '3HOV',
#   '3S1R',
#   '1I6H',
#   '4A3C',
#   '3HOU',
#   '5OT2',
#   '3GTJ',
#   '3S1M',
#   '3M3Y',
#   '4Q5S',
#   '4A3F',
#   '3PO3',
#   '4A3B',
#   '2NVT',
#   '2E2I',
#   '4BXX',
#   '3HOY',
#   '2PPB',
#   '2YU9',
#   '1R9T',
#   '2O5I',
#   '4Y7N',
#   '3PO2',
#   '2NVQ',
#   '3S16',
#   '3S14',
#   '3S15',
#   '3RZO',
#   '3S1N',
#   '5VI5',
#   '3GTL',
#   '4A3E',
#   '2E2J',
#   '4A93',
#   '2VUM',
#   '5XOG',
#   '4A3D',
#   '4A3K',
#   '4BY7',
#   '3HOV',
#   '4A3C',
#   '3HOU',
#   '5OT2',
#   '4A3F',
#   '3PO3',
#   '4A3B',
#   '4BXX',
#   '3HOY',
#   '3PO2',
#   '4A3E',
#   '5E17',
#   '4A93',
#   '2VUM',
#   '5XOG',
#   '4A3D',
#   '4A3K',
#   '4BY7',
#   '4Y52',
#   '3S2H',
#   '3RZD',
#   '3S17',
#   '3S2D',
#   '3S1Q',
#   '2O5J',
#   '5E18',
#   '3HOV',
#   '3S1R',
#   '1I6H',
#   '4A3C',
#   '3HOU',
#   '5OT2',
#   '3GTJ',
#   '3S1M',
#   '3M3Y',
#   '4Q5S',
#   '4A3F',
#   '3PO3',
#   '4A3B',
#   '2NVT',
#   '2E2I',
#   '4BXX',
#   '3HOY',
#   '2PPB',
#   '2YU9',
#   '1R9T',
#   '2O5I',
#   '4Y7N',
#   '3PO2',
#   '2NVQ',
#   '3S16',
#   '3S14',
#   '3S15',
#   '3RZO',
#   '3S1N',
#   '5VI5',
#   '3GTL',
#   '4A3E',
#   '2E2J',
#   '5E17',
#   '4A93',
#   '2VUM',
#   '5XOG',
#   '4A3D',
#   '4A3K',
#   '4BY7',
#   '4Y52',
#   '3S2H',
#   '3RZD',
#   '3S17',
#   '3S2D',
#   '3S1Q',
#   '2O5J',
#   '5E18',
#   '3HOV',
#   '3S1R',
#   '1I6H',
#   '4A3C',
#   '3HOU',
#   '5OT2',
#   '3GTJ',
#   '3S1M',
#   '3M3Y',
#   '4Q5S',
#   '4A3F',
#   '3PO3',
#   '4A3B',
#   '2NVT',
#   '2E2I',
#   '4BXX',
#   '3HOY',
#   '2PPB',
#   '2YU9',
#   '1R9T',
#   '2O5I',
#   '4Y7N',
#   '3PO2',
#   '2NVQ',
#   '3S16',
#   '3S14',
#   '3S15',
#   '3RZO',
#   '3S1N',
#   '5VI5',
#   '3GTL',
#   '4A3E',
#   '2E2J',
#   '4A93',
#   '2VUM',
#   '5XOG',
#   '4A3D',
#   '4A3K',
#   '4BY7',
#   '4Y52',
#   '3S2H',
#   '3RZD',
#   '3S17',
#   '3S2D',
#   '3S1Q',
#   '3HOV',
#   '3S1R',
#   '1I6H',
#   '4A3C',
#   '3HOU',
#   '5OT2',
#   '3GTJ',
#   '3S1M',
#   '3M3Y',
#   '4A3F',
#   '3PO3',
#   '4A3B',
#   '2NVT',
#   '2E2I',
#   '4BXX',
#   '3HOY',
#   '2YU9',
#   '1R9T',
#   '4Y7N',
#   '3PO2',
#   '2NVQ',
#   '3S16',
#   '3S14',
#   '3S15',
#   '3RZO',
#   '3S1N',
#   '3GTL',
#   '4A3E',
#   '2E2J',
#   '4A93',
#   '2VUM',
#   '5XOG',
#   '4A3D',
#   '4A3K',
#   '4BY7',
#   '4Y52',
#   '3S2H',
#   '3RZD',
#   '3S17',
#   '3S2D',
#   '3S1Q',
#   '3HOV',
#   '3S1R',
#   '1I6H',
#   '4A3C',
#   '3HOU',
#   '5OT2',
#   '3GTJ',
#   '3S1M',
#   '3M3Y',
#   '4A3F',
#   '3PO3',
#   '4A3B',
#   '2NVT',
#   '2E2I',
#   '4BXX',
#   '3HOY',
#   '2YU9',
#   '1R9T',
#   '4Y7N',
#   '3PO2',
#   '2NVQ',
#   '3S16',
#   '3S14',
#   '3S15',
#   '3RZO',
#   '3S1N',
#   '3GTL',
#   '4A3E',
#   '2E2J',
#   '5E17',
#   '4A93',
#   '2VUM',
#   '5XOG',
#   '4A3D',
#   '4A3K',
#   '4BY7',
#   '4Y52',
#   '3S2H',
#   '3RZD',
#   '3S17',
#   '3S2D',
#   '3S1Q',
#   '2O5J',
#   '5E18',
#   '3HOV',
#   '3S1R',
#   '1I6H',
#   '4A3C',
#   '3HOU',
#   '5OT2',
#   '3GTJ',
#   '3S1M',
#   '3M3Y',
#   '4Q5S',
#   '4A3F',
#   '3PO3',
#   '4A3B',
#   '2NVT',
#   '2E2I',
#   '4BXX',
#   '3HOY',
#   '2PPB',
#   '2YU9',
#   '1R9T',
#   '2O5I',
#   '4Y7N',
#   '3PO2',
#   '2NVQ',
#   '3S16',
#   '3S14',
#   '3S15',
#   '3RZO',
#   '3S1N',
#   '5VI5',
#   '3GTL',
#   '4A3E',
#   '2E2J',
#   '4A93',
#   '2VUM',
#   '5XOG',
#   '4A3D',
#   '4A3K',
#   '4BY7',
#   '4Y52',
#   '3S2H',
#   '3RZD',
#   '3S17',
#   '3S2D',
#   '3S1Q',
#   '3HOV',
#   '3S1R',
#   '1I6H',
#   '4A3C',
#   '3HOU',
#   '5OT2',
#   '3GTJ',
#   '3S1M',
#   '3M3Y',
#   '4A3F',
#   '3PO3',
#   '4A3B',
#   '2NVT',
#   '2E2I',
#   '4BXX',
#   '3HOY',
#   '2YU9',
#   '1R9T',
#   '4Y7N',
#   '3PO2',
#   '2NVQ',
#   '3S16',
#   '3S14',
#   '3S15',
#   '3RZO',
#   '3S1N',
#   '3GTL',
#   '4A3E',
#   '2E2J',
#   '5M3H',
#   '5M3J',
#   '5E17',
#   '4A93',
#   '2VUM',
#   '5XOG',
#   '4A3D',
#   '4A3K',
#   '4BY7',
#   '4Y52',
#   '3S2H',
#   '3RZD',
#   '3S17',
#   '3S2D',
#   '3S1Q',
#   '2O5J',
#   '5E18',
#   '3HOV',
#   '3S1R',
#   '1I6H',
#   '4A3C',
#   '3HOU',
#   '5OT2',
#   '3GTJ',
#   '3S1M',
#   '3M3Y',
#   '4Q5S',
#   '4A3F',
#   '3PO3',
#   '4A3B',
#   '2NVT',
#   '2E2I',
#   '4BXX',
#   '3HOY',
#   '2PPB',
#   '2YU9',
#   '1R9T',
#   '2O5I',
#   '4Y7N',
#   '3PO2',
#   '2NVQ',
#   '3S16',
#   '3S14',
#   '3S15',
#   '3RZO',
#   '3S1N',
#   '5VI5',
#   '3GTL',
#   '4A3E',
#   '2E2J',
#   '1S76',
#   '1H38',
#   '1S0V',
#   '1MSW',
#   '1QLN',
#   '4BOC',
#   '3E2E',
#   '1S77',
#   '5E17',
#   '4A93',
#   '2VUM',
#   '5XOG',
#   '4A3D',
#   '4A3K',
#   '4BY7',
#   '4Y52',
#   '3S2H',
#   '3RZD',
#   '3S17',
#   '3S2D',
#   '3S1Q',
#   '2O5J',
#   '5E18',
#   '3HOV',
#   '3S1R',
#   '1I6H',
#   '4A3C',
#   '3HOU',
#   '5OT2',
#   '3GTJ',
#   '3S1M',
#   '3M3Y',
#   '4Q5S',
#   '4A3F',
#   '3PO3',
#   '4A3B',
#   '2NVT',
#   '2E2I',
#   '4BXX',
#   '3HOY',
#   '2PPB',
#   '2YU9',
#   '1R9T',
#   '2O5I',
#   '4Y7N',
#   '3PO2',
#   '2NVQ',
#   '3S16',
#   '3S14',
#   '3S15',
#   '3RZO',
#   '3S1N',
#   '5VI5',
#   '3GTL',
#   '4A3E',
#   '2E2J',
#   '5E17',
#   '4A93',
#   '2VUM',
#   '5XOG',
#   '4A3D',
#   '4A3K',
#   '4BY7',
#   '4Y52',
#   '3S2H',
#   '3RZD',
#   '3S17',
#   '3S2D',
#   '3S1Q',
#   '2O5J',
#   '5E18',
#   '3HOV',
#   '3S1R',
#   '1I6H',
#   '4A3C',
#   '3HOU',
#   '5OT2',
#   '3GTJ',
#   '3S1M',
#   '3M3Y',
#   '4Q5S',
#   '4A3F',
#   '3PO3',
#   '4A3B',
#   '2NVT',
#   '2E2I',
#   '4BXX',
#   '3HOY',
#   '2PPB',
#   '2YU9',
#   '1R9T',
#   '2O5I',
#   '4Y7N',
#   '3PO2',
#   '2NVQ',
#   '3S16',
#   '3S14',
#   '3S15',
#   '3RZO',
#   '3S1N',
#   '5VI5',
#   '3GTL',
#   '4A3E',
#   '2E2J',
#   '4A93',
#   '2VUM',
#   '5XOG',
#   '4A3D',
#   '4A3K',
#   '4BY7',
#   '4Y52',
#   '3S2H',
#   '3RZD',
#   '3S17',
#   '3S2D',
#   '3S1Q',
#   '3HOV',
#   '3S1R',
#   '1I6H',
#   '4A3C',
#   '3HOU',
#   '5OT2',
#   '3GTJ',
#   '3S1M',
#   '3M3Y',
#   '4A3F',
#   '3PO3',
#   '4A3B',
#   '2NVT',
#   '2E2I',
#   '4BXX',
#   '3HOY',
#   '2YU9',
#   '1R9T',
#   '4Y7N',
#   '3PO2',
#   '2NVQ',
#   '3S16',
#   '3S14',
#   '3S15',
#   '3RZO',
#   '3S1N',
#   '3GTL',
#   '4A3E',
#   '2E2J',
#   '5E17',
#   '2O5J',
#   '5E18',
#   '4Q5S',
#   '2PPB',
#   '2O5I',
#   '5VI5',
#   '4A93',
#   '2VUM',
#   '5XOG',
#   '4A3D',
#   '4A3K',
#   '4BY7',
#   '4Y52',
#   '3S2H',
#   '3RZD',
#   '3S17',
#   '3S2D',
#   '3S1Q',
#   '3HOV',
#   '3S1R',
#   '1I6H',
#   '4A3C',
#   '3HOU',
#   '5OT2',
#   '3GTJ',
#   '3S1M',
#   '3M3Y',
#   '4A3F',
#   '3PO3',
#   '4A3B',
#   '2NVT',
#   '2E2I',
#   '4BXX',
#   '3HOY',
#   '2YU9',
#   '1R9T',
#   '4Y7N',
#   '3PO2',
#   '2NVQ',
#   '3S16',
#   '3S14',
#   '3S15',
#   '3RZO',
#   '3S1N',
#   '3GTL',
#   '4A3E',
#   '2E2J',
#   '4A93',
#   '2VUM',
#   '5XOG',
#   '4A3D',
#   '4A3K',
#   '4BY7',
#   '4Y52',
#   '3S2H',
#   '3RZD',
#   '3S17',
#   '3S2D',
#   '3S1Q',
#   '3HOV',
#   '3S1R',
#   '1I6H',
#   '4A3C',
#   '3HOU',
#   '5OT2',
#   '3GTJ',
#   '3S1M',
#   '3M3Y',
#   '4A3F',
#   '3PO3',
#   '4A3B',
#   '2NVT',
#   '2E2I',
#   '4BXX',
#   '3HOY',
#   '2YU9',
#   '1R9T',
#   '4Y7N',
#   '3PO2',
#   '2NVQ',
#   '3S16',
#   '3S14',
#   '3S15',
#   '3RZO',
#   '3S1N',
#   '3GTL',
#   '4A3E',
#   '2E2J',
#   '5E17',
#   '4A93',
#   '2VUM',
#   '5XOG',
#   '4A3D',
#   '4A3K',
#   '4BY7',
#   '4Y52',
#   '3S2H',
#   '3RZD',
#   '3S17',
#   '3S2D',
#   '3S1Q',
#   '2O5J',
#   '5E18',
#   '3HOV',
#   '3S1R',
#   '1I6H',
#   '4A3C',
#   '3HOU',
#   '5OT2',
#   '3GTJ',
#   '3S1M',
#   '3M3Y',
#   '4Q5S',
#   '4A3F',
#   '3PO3',
#   '4A3B',
#   '2NVT',
#   '2E2I',
#   '4BXX',
#   '3HOY',
#   '2PPB',
#   '2YU9',
#   '1R9T',
#   '2O5I',
#   '4Y7N',
#   '3PO2',
#   '2NVQ',
#   '3S16',
#   '3S14',
#   '3S15',
#   '3RZO',
#   '3S1N',
#   '5VI5',
#   '3GTL',
#   '4A3E',
#   '2E2J',
#   '5E17',
#   '4A93',
#   '2VUM',
#   '5XOG',
#   '4A3D',
#   '4A3K',
#   '4BY7',
#   '4Y52',
#   '3S2H',
#   '3RZD',
#   '3S17',
#   '3S2D',
#   '3S1Q',
#   '2O5J',
#   '5E18',
#   '3HOV',
#   '3S1R',
#   '1I6H',
#   '4A3C',
#   '3HOU',
#   '5OT2',
#   '3GTJ',
#   '3S1M',
#   '3M3Y',
#   '4Q5S',
#   '4A3F',
#   '3PO3',
#   '4A3B',
#   '2NVT',
#   '2E2I',
#   '4BXX',
#   '3HOY',
#   '2PPB',
#   '2YU9',
#   '1R9T',
#   '2O5I',
#   '4Y7N',
#   '3PO2',
#   '2NVQ',
#   '3S16',
#   '3S14',
#   '3S15',
#   '3RZO',
#   '3S1N',
#   '5VI5',
#   '3GTL',
#   '4A3E',
#   '2E2J',
#   '4A93',
#   '2VUM',
#   '5XOG',
#   '4A3D',
#   '4A3K',
#   '4BY7',
#   '4Y52',
#   '3S2H',
#   '3RZD',
#   '3S17',
#   '3S2D',
#   '3S1Q',
#   '3HOV',
#   '3S1R',
#   '1I6H',
#   '4A3C',
#   '3HOU',
#   '5OT2',
#   '3GTJ',
#   '3S1M',
#   '3M3Y',
#   '4A3F',
#   '3PO3',
#   '4A3B',
#   '2NVT',
#   '2E2I',
#   '4BXX',
#   '3HOY',
#   '2YU9',
#   '1R9T',
#   '4Y7N',
#   '3PO2',
#   '2NVQ',
#   '3S16',
#   '3S14',
#   '3S15',
#   '3RZO',
#   '3S1N',
#   '3GTL',
#   '4A3E',
#   '2E2J',
#   '4A93',
#   '2VUM',
#   '5XOG',
#   '4A3D',
#   '4A3K',
#   '4BY7',
#   '4Y52',
#   '3S2H',
#   '3RZD',
#   '3S17',
#   '3S2D',
#   '3S1Q',
#   '3HOV',
#   '3S1R',
#   '1I6H',
#   '4A3C',
#   '3HOU',
#   '5OT2',
#   '3GTJ',
#   '3S1M',
#   '3M3Y',
#   '4A3F',
#   '3PO3',
#   '4A3B',
#   '2NVT',
#   '2E2I',
#   '4BXX',
#   '3HOY',
#   '2YU9',
#   '1R9T',
#   '4Y7N',
#   '3PO2',
#   '2NVQ',
#   '3S16',
#   '3S14',
#   '3S15',
#   '3RZO',
#   '3S1N',
#   '3GTL',
#   '4A3E',
#   '2E2J',
#   '1S76',
#   '1H38',
#   '1S0V',
#   '6C2P',
#   '1MSW',
#   '1QLN',
#   '4BOC',
#   '3E2E',
#   '1S77',
#   '5E17',
#   '4A93',
#   '2VUM',
#   '5XOG',
#   '4A3D',
#   '4A3K',
#   '4BY7',
#   '4Y52',
#   '3S2H',
#   '3RZD',
#   '3S17',
#   '3S2D',
#   '3S1Q',
#   '2O5J',
#   '5E18',
#   '3HOV',
#   '3S1R',
#   '1I6H',
#   '4A3C',
#   '3HOU',
#   '5OT2',
#   '3GTJ',
#   '3S1M',
#   '3M3Y',
#   '4Q5S',
#   '4A3F',
#   '3PO3',
#   '4A3B',
#   '2NVT',
#   '2E2I',
#   '4BXX',
#   '3HOY',
#   '2PPB',
#   '2YU9',
#   '1R9T',
#   '2O5I',
#   '4Y7N',
#   '3PO2',
#   '2NVQ',
#   '3S16',
#   '3S14',
#   '3S15',
#   '3RZO',
#   '3S1N',
#   '5VI5',
#   '3GTL',
#   '4A3E',
#   '2E2J',
#   '5E17',
#   '4A93',
#   '2VUM',
#   '5XOG',
#   '4A3D',
#   '4A3K',
#   '4BY7',
#   '4Y52',
#   '3S2H',
#   '3RZD',
#   '3S17',
#   '3S2D',
#   '3S1Q',
#   '2O5J',
#   '5E18',
#   '3HOV',
#   '3S1R',
#   '1I6H',
#   '4A3C',
#   '3HOU',
#   '5OT2',
#   '3GTJ',
#   '3S1M',
#   '3M3Y',
#   '4Q5S',
#   '4A3F',
#   '3PO3',
#   '4A3B',
#   '2NVT',
#   '2E2I',
#   '4BXX',
#   '3HOY',
#   '2PPB',
#   '2YU9',
#   '1R9T',
#   '2O5I',
#   '4Y7N',
#   '3PO2',
#   '2NVQ',
#   '3S16',
#   '3S14',
#   '3S15',
#   '3RZO',
#   '3S1N',
#   '5VI5',
#   '3GTL',
#   '4A3E',
#   '2E2J',
#   '5E17',
#   '4A93',
#   '2VUM',
#   '5XOG',
#   '4A3D',
#   '4A3K',
#   '4BY7',
#   '4Y52',
#   '3S2H',
#   '3RZD',
#   '3S17',
#   '3S2D',
#   '3S1Q',
#   '2O5J',
#   '5E18',
#   '3HOV',
#   '3S1R',
#   '1I6H',
#   '4A3C',
#   '3HOU',
#   '5OT2',
#   '3GTJ',
#   '3S1M',
#   '3M3Y',
#   '4Q5S',
#   '4A3F',
#   '3PO3',
#   '4A3B',
#   '2NVT',
#   '2E2I',
#   '4BXX',
#   '3HOY',
#   '2PPB',
#   '2YU9',
#   '1R9T',
#   '2O5I',
#   '4Y7N',
#   '3PO2',
#   '2NVQ',
#   '3S16',
#   '3S14',
#   '3S15',
#   '3RZO',
#   '3S1N',
#   '5VI5',
#   '3GTL',
#   '4A3E',
#   '2E2J',
#   '4A93',
#   '2VUM',
#   '5XOG',
#   '4A3D',
#   '4A3K',
#   '4BY7',
#   '4Y52',
#   '3S2H',
#   '3RZD',
#   '3S17',
#   '3S2D',
#   '3S1Q',
#   '3HOV',
#   '3S1R',
#   '1I6H',
#   '4A3C',
#   '3HOU',
#   '5OT2',
#   '3GTJ',
#   '3S1M',
#   '3M3Y',
#   '4A3F',
#   '3PO3',
#   '4A3B',
#   '2NVT',
#   '2E2I',
#   '4BXX',
#   '3HOY',
#   '2YU9',
#   '1R9T',
#   '4Y7N',
#   '3PO2',
#   '2NVQ',
#   '3S16',
#   '3S14',
#   '3S15',
#   '3RZO',
#   '3S1N',
#   '3GTL',
#   '4A3E',
#   '2E2J',
#   '4A93',
#   '2VUM',
#   '5XOG',
#   '4A3D',
#   '4A3K',
#   '4BY7',
#   '4Y52',
#   '3S2H',
#   '3RZD',
#   '3S17',
#   '3S2D',
#   '3S1Q',
#   ...],
#  'RNase': ['2VNU',
#   '5JEA',
#   '4IFD',
#   '5K36',
#   '4PMW',
#   '5VZJ',
#   '2PO1',
#   '3M7N',
#   '5JEA',
#   '4IFD',
#   '3M85',
#   '5K36',
#   '2JEA',
#   '4AM3',
#   '4OO1',
#   '4BA2',
#   '5VZJ',
#   '4PMW',
#   '5T16',
#   '4OOG',
#   '2A1R',
#   '4PY5',
#   '4XWW',
#   '3T3N',
#   '3T3O',
#   '4L8R',
#   '1ZBH',
#   '4QOZ',
#   '2PO1',
#   '3M7N',
#   '5JEA',
#   '4IFD',
#   '3M85',
#   '5K36',
#   '2JEA',
#   '4AM3',
#   '4OO1',
#   '4BA2',
#   '5VZJ',
#   '5C0Y',
#   '5K36',
#   '4OO1',
#   '5VZJ',
#   '4HKQ',
#   '4OL8',
#   '2C0B',
#   '5F6C',
#   '2VRT',
#   '2BX2',
#   '3IAB',
#   '2QKB',
#   '2QK9',
#   '4Q0B',
#   '2QKK',
#   '4PUO',
#   '4PWD',
#   '4PQU',
#   '4B3O',
#   '1HYS'],
#  'ROQ_II': ['4Z31', '5F5F', '4QIK', '4QI2B', '4QIL', '4QI2A', '5F5H', '4ZLD'],
#  'RRF': ['1Y69'],
#  'RRM': ['2MKI',
#   '2MKK',
#   '2IY5',
#   '3TUP',
#   '1EIY',
#   '2MQQ',
#   '2N3O',
#   '2AD9',
#   '2ADC',
#   '2MXY',
#   '3P6Y',
#   '1SJ4',
#   '5DDO',
#   '2RS2',
#   '2HYI',
#   '2XB2',
#   '1FXL',
#   '4YOE',
#   '2RQC',
#   '4PKD',
#   '5O1Z',
#   '5EN1',
#   '1DRZ',
#   '1ZH5',
#   '4PR6B',
#   '2FY1',
#   '2NZ4',
#   '4PRFA',
#   '3G9C',
#   '4N0T',
#   '4LMZ',
#   '4W92',
#   '1VBX',
#   '3IRW',
#   '3HHN',
#   '4CIO',
#   '3BO2',
#   '3CUL',
#   '2KG1',
#   '1M5V',
#   '2MGZ',
#   '3G96',
#   '2MQO',
#   '2OIH',
#   '1VBY',
#   '2J0S',
#   '3UD4',
#   '3BO3B',
#   '2XS7',
#   '1YTY',
#   '4PR6A',
#   '1AUD',
#   '3MUR',
#   '1RKJ',
#   '1FJE',
#   '3UCU',
#   '1ZZN',
#   '3NMR',
#   '3UCZ',
#   '1U6B',
#   '3G8T',
#   '5X3Z',
#   '3NNH',
#   '3R1L',
#   '4C4W',
#   '5DDQ',
#   '5DDR',
#   '4ED5',
#   '1A9N',
#   '2J0Q',
#   '2KG0',
#   '2ERR',
#   '1SJ3',
#   '3L3C',
#   '2N7C',
#   '1VC0',
#   '1M5P',
#   '3MUT',
#   '2L41',
#   '2RU3',
#   '3EGZ',
#   '2VOO',
#   '2M8D',
#   '5HO4',
#   '3IWN',
#   '3BO3A',
#   '3NNA',
#   '2KM8',
#   '3R1H',
#   '1B7F',
#   '4WKR',
#   '4BS2',
#   '1VBZ',
#   '2KXN',
#   '1VC5',
#   '5DET',
#   '2LEB',
#   '2CJK',
#   '2MZ1',
#   '2RRA',
#   '2XS2',
#   '3K0J',
#   '2VON',
#   '2VOP',
#   '3EX7',
#   '4YB1',
#   '4F02',
#   '2OJ3',
#   '3UD3',
#   '1G2E',
#   '2ADB',
#   '1VC6',
#   '1DZ5',
#   '1M5O',
#   '3G8S',
#   '5O1Y',
#   '3MUM',
#   '2VOD',
#   '2XS5',
#   '1FNX',
#   '2XNR',
#   '1M5K',
#   '2N82',
#   '2G4B',
#   '3CUN',
#   '2ADC',
#   '5TF6',
#   '1CVJ',
#   '5DDP',
#   '2LEC',
#   '2MB0',
#   '4QQB',
#   '1SJF',
#   '2I2Y',
#   '4W90',
#   '3MXH',
#   '5FJ4',
#   '2YH1',
#   '3BO4',
#   '2KH9',
#   '3Q2T',
#   '1URN',
#   '3NNC',
#   '3MUV',
#   '4N0T',
#   '5TF6',
#   '2MQO',
#   '2MQP'],
#  'RVT': ['4Q0B',
#   '4PUO',
#   '4PWD',
#   '4PQU',
#   '4B3O',
#   '1HYS',
#   '4Q0B',
#   '4PUO',
#   '4PWD',
#   '4PQU',
#   '4B3O',
#   '1HYS',
#   '4H8K',
#   '4HKQ',
#   '4OL8',
#   '4Q0B',
#   '6AR3',
#   '4PUO',
#   '4PWD',
#   '4PQU',
#   '4B3O',
#   '1HYS',
#   '6AR1'],
#  'Ras': ['5C9H', '4O26', '3A6P', '3ICQ'],
#  'RdRP': ['4K4S',
#   '5TSN',
#   '5F8N',
#   '1UVN',
#   '3OL7',
#   '4QPX',
#   '4K50',
#   '4K4W',
#   '4K4T',
#   '1UVI',
#   '3KNA',
#   '2E9R',
#   '3OLB',
#   '3KMQ',
#   '1UVL',
#   '5JXS',
#   '3KLV',
#   '4IQX',
#   '5F8J',
#   '4K4X',
#   '3BSO',
#   '5F8H',
#   '2E9Z',
#   '4K4Y',
#   '2E9T',
#   '4K4Z',
#   '3H5X',
#   '3KOA',
#   '3BSN',
#   '1UVJ',
#   '1WNE',
#   '2EC0',
#   '1UVM',
#   '3NL0',
#   '3KMS',
#   '5F8M',
#   '3OL6',
#   '3OL8',
#   '3OL9',
#   '4X2B',
#   '5F8G',
#   '3NMA',
#   '4K4V',
#   '5F8I',
#   '3OLA',
#   '4K4U',
#   '4WZQ',
#   '5F8L',
#   '4WZM',
#   '3H5Y',
#   '5AMQ',
#   '5AMR',
#   '1N1H',
#   '1N35',
#   '1N38',
#   '2R7R',
#   '2R7W',
#   '2R7S',
#   '2R7T',
#   '2R7U',
#   '2R7X',
#   '2R7V',
#   '5UJ2',
#   '4WTJ',
#   '4WTD',
#   '4WTI',
#   '4WTG',
#   '4WTC',
#   '1NB7',
#   '4WTM',
#   '4WTA',
#   '4E78',
#   '4WTE',
#   '4WTK',
#   '4WTL',
#   '4WTF'],
#  'ResIII': ['5JCF',
#   '5JC3',
#   '5ZAM',
#   '5JAJB',
#   '5JB2',
#   '5ZAL',
#   '5JC7',
#   '5JCH',
#   '5JAJA',
#   '5JBG'],
#  'Rho': ['3ICE',
#   '5JJI',
#   '2A8V',
#   '5JJK',
#   '5JJL',
#   '3ICE',
#   '5JJI',
#   '2A8V',
#   '5JJK',
#   '5JJL'],
#  'Ribonuclease': ['1YYW',
#   '1RC7',
#   '5ZAM',
#   '5ZAL',
#   '2NUGA',
#   '1YYO',
#   '2NUF',
#   '2NUGB',
#   '5T16',
#   '2NUE',
#   '4OOG',
#   '1YZ9',
#   '2EZ6',
#   '4M30',
#   '4M2Z',
#   '1YYK',
#   '2IX1',
#   '2VNU',
#   '5JEA',
#   '4IFD',
#   '5K36',
#   '2IX1',
#   '4PMW',
#   '5VZJ'],
#  'Ribosom': ['1XMO',
#   '4DUYA',
#   '4LFB',
#   '4B3T',
#   '4DR3',
#   '4B3R',
#   '1XNR',
#   '4B3S',
#   '1IBL',
#   '4YHH',
#   '2UUA',
#   '4DR6',
#   '4DV6B',
#   '4JYA',
#   '4X64',
#   '4GKJ',
#   '1HR0',
#   '4LF6',
#   '4B3M',
#   '5IWAB',
#   '4DV6A',
#   '4JI3',
#   '4JI1',
#   '2E5L',
#   '4DR5A',
#   '1IBM',
#   '3T1Y',
#   '1N33',
#   '4X65',
#   '1FJG',
#   '2HHH',
#   '2UU9',
#   '2VQE',
#   '4LF8',
#   '1XNQ',
#   '1I94',
#   '4JI7A',
#   '2UUB',
#   '5BR8',
#   '4DV7',
#   '1N32',
#   '4DR5B',
#   '4LF7',
#   '4LF4',
#   '4JV5',
#   '4AQY',
#   '5IWAA',
#   '4LF9',
#   '2UXD',
#   '2UXB',
#   '4JI7B',
#   '2UUC',
#   '1HNW',
#   '1FKA',
#   '4KHP',
#   '1J5E',
#   '2VQF',
#   '4GKK',
#   '4DR2',
#   '4JI0A',
#   '1HNX',
#   '2ZM6',
#   '4DUYB',
#   '4X66',
#   '3T1H',
#   '1HNZ',
#   '2UXC',
#   '4JI0B',
#   '4K0K',
#   '4X62',
#   '1XMQ',
#   '1IBK',
#   '2HW8',
#   '1MZP',
#   '4QVI',
#   '3U56',
#   '5DM6',
#   '1ZHO',
#   '2VPL',
#   '3U4M',
#   '5DM7',
#   '1U63',
#   '4QG3',
#   '3UMY',
#   '3CCQ',
#   '1KC8',
#   '1YHQ',
#   '3CMA',
#   '1VQ5',
#   '3CCJ',
#   '1VQO',
#   '1N8R',
#   '1QVG',
#   '1VQ6',
#   '3CXC',
#   '3CD6',
#   '1Q86',
#   '1Q7Y',
#   '1JJ2',
#   '2QEX',
#   '1M90',
#   '1YJW',
#   '1VQL',
#   '1NJI',
#   '1VQ7',
#   '1YI2',
#   '1QVF',
#   '1VQK',
#   '3CCE',
#   '3CC2',
#   '3I55',
#   '1VQ9',
#   '3G4S',
#   '1VQ8',
#   '3CC4',
#   '1VQM',
#   '1Q81',
#   '3OW2',
#   '3G71',
#   '3G6E',
#   '3CCL',
#   '1YJN',
#   '3CCR',
#   '1VQP',
#   '3CCS',
#   '3CCM',
#   '1K9M',
#   '1YJ9B',
#   '1KQS',
#   '2OTL',
#   '1S72',
#   '3CC7',
#   '3CME',
#   '3I56',
#   '1W2B',
#   '3CPW',
#   '1YJ9A',
#   '1YIJ',
#   '1K73',
#   '3CCU',
#   '1K8A',
#   '2OTJ',
#   '1YIT',
#   '1FFK',
#   '1VQ4',
#   '1M1K',
#   '1VQN',
#   '1KD1',
#   '1Q82',
#   '3CCV',
#   '3CCQ',
#   '1KC8',
#   '1YHQ',
#   '3CMA',
#   '3CF5',
#   '1VQ5',
#   '3CCJ',
#   '1VQO',
#   '5JVGA',
#   '1N8R',
#   '1QVG',
#   '1VQ6',
#   '5NRGB',
#   '3CXC',
#   '3CD6',
#   '1Q86',
#   '1Q7Y',
#   '1JJ2',
#   '4WF9',
#   '2QEX',
#   '1M90',
#   '1YJW',
#   '1VQL',
#   '1NJI',
#   '1VQ7',
#   '1YI2',
#   '1NWY',
#   '4WFB',
#   '1QVF',
#   '1VQK',
#   '4WFA',
#   '3CCE',
#   '3CC2',
#   '3I55',
#   '1VQ9',
#   '3G4S',
#   '1VQ8',
#   '3CC4',
#   '1VQM',
#   '1Q81',
#   '1NKW',
#   '3DLL',
#   '4IOA',
#   '3OW2',
#   '1XBP',
#   '1NWX',
#   '4IO9',
#   '3G71',
#   '3G6E',
#   '3PIP',
#   '5DM6',
#   '3CCL',
#   '3PIO',
#   '1YJN',
#   '3CCR',
#   '1VQP',
#   '2ZJQ',
#   '3CCS',
#   '3CCM',
#   '1K9M',
#   '1YJ9B',
#   '1SM1',
#   '1KQS',
#   '2OTL',
#   '1S72',
#   '3CC7',
#   '3CME',
#   '2ZJR',
#   '5DM7',
#   '3I56',
#   '1W2B',
#   '3CPW',
#   '1YJ9A',
#   '1YIJ',
#   '1K73',
#   '3CCU',
#   '5NRGA',
#   '1K8A',
#   '2OTJ',
#   '1YIT',
#   '5JVGB',
#   '1FFK',
#   '1VQ4',
#   '1M1K',
#   '1VQN',
#   '1KD1',
#   '1Q82',
#   '3CCV',
#   '3CCQ',
#   '1KC8',
#   '1YHQ',
#   '3CMA',
#   '3CF5',
#   '1VQ5',
#   '3CCJ',
#   '1VQO',
#   '5JVGA',
#   '1N8R',
#   '1QVG',
#   '1VQ6',
#   '5NRGB',
#   '3CXC',
#   '3CD6',
#   '1Q86',
#   '1Q7Y',
#   '1JJ2',
#   '4WF9',
#   '2QEX',
#   '1M90',
#   '1YJW',
#   '1VQL',
#   '1NJI',
#   '1VQ7',
#   '1YI2',
#   '1NWY',
#   '4WFB',
#   '1QVF',
#   '1VQK',
#   '4WFA',
#   '3CCE',
#   '3CC2',
#   '3I55',
#   '1VQ9',
#   '3G4S',
#   '1VQ8',
#   '3CC4',
#   '1VQM',
#   '1Q81',
#   '1NKW',
#   '3DLL',
#   '4IOA',
#   '3OW2',
#   '1XBP',
#   '1NWX',
#   '4IO9',
#   '3G71',
#   '3G6E',
#   '3PIP',
#   '5DM6',
#   '3CCL',
#   '3PIO',
#   '1YJN',
#   '3CCR',
#   '1VQP',
#   '2ZJQ',
#   '3CCS',
#   '3CCM',
#   '1MJI',
#   '1K9M',
#   '1YJ9B',
#   '1SM1',
#   '1KQS',
#   '2OTL',
#   '1S72',
#   '3CC7',
#   '3CME',
#   '2ZJR',
#   '5DM7',
#   '3I56',
#   '1W2B',
#   '3CPW',
#   '1YJ9A',
#   '1YIJ',
#   '1K73',
#   '3CCU',
#   '5NRGA',
#   '1K8A',
#   '2OTJ',
#   '1YIT',
#   '5JVGB',
#   '1FFK',
#   '1VQ4',
#   '1M1K',
#   '1VQN',
#   '1KD1',
#   '1Q82',
#   '3CCV',
#   '1XMO',
#   '4DUYA',
#   '4LFB',
#   '4B3T',
#   '4DR3',
#   '4B3R',
#   '1XNR',
#   '4B3S',
#   '1IBL',
#   '4YHH',
#   '2UUA',
#   '4DR6',
#   '4DV6B',
#   '4JYA',
#   '4X64',
#   '4GKJ',
#   '1HR0',
#   '4LF6',
#   '4B3M',
#   '5IWAB',
#   '4DV6A',
#   '4JI3',
#   '4JI1',
#   '2E5L',
#   '4DR5A',
#   '1IBM',
#   '3T1Y',
#   '1N33',
#   '4X65',
#   '1FJG',
#   '2HHH',
#   '2UU9',
#   '2VQE',
#   '4LF8',
#   '1XNQ',
#   '1I94',
#   '4JI7A',
#   '2UUB',
#   '5BR8',
#   '4DV7',
#   '1N32',
#   '4DR5B',
#   '4LF7',
#   '4LF4',
#   '4JV5',
#   '4AQY',
#   '5IWAA',
#   '4LF9',
#   '2UXD',
#   '2UXB',
#   '4JI7B',
#   '2UUC',
#   '1HNW',
#   '4KHP',
#   '1J5E',
#   '2VQF',
#   '4GKK',
#   '4DR2',
#   '4JI0A',
#   '1HNX',
#   '2ZM6',
#   '4DUYB',
#   '4X66',
#   '3T1H',
#   '1HNZ',
#   '2UXC',
#   '4JI0B',
#   '4K0K',
#   '4X62',
#   '1XMQ',
#   '1IBK',
#   '1XMO',
#   '4DUYA',
#   '4LFB',
#   '4B3T',
#   '4DR3',
#   '4B3R',
#   '1XNR',
#   '4B3S',
#   '1IBL',
#   '4YHH',
#   '2UUA',
#   '4DR6',
#   '4DV6B',
#   '4JYA',
#   '4X64',
#   '4GKJ',
#   '1HR0',
#   '4LF6',
#   '4B3M',
#   '5IWAB',
#   '4DV6A',
#   '4JI3',
#   '4JI1',
#   '2E5L',
#   '4DR5A',
#   '1IBM',
#   '3T1Y',
#   '1N33',
#   '4X65',
#   '1FJG',
#   '2HHH',
#   '2UU9',
#   '2VQE',
#   '4LF8',
#   '1XNQ',
#   '1I94',
#   '4JI7A',
#   '2UUB',
#   '5BR8',
#   '4DV7',
#   '1N32',
#   '4DR5B',
#   '4LF7',
#   '4LF4',
#   '4JV5',
#   '4AQY',
#   '5IWAA',
#   '4LF9',
#   '2UXD',
#   '2UXB',
#   '4JI7B',
#   '2UUC',
#   '1HNW',
#   '4KHP',
#   '1J5E',
#   '2VQF',
#   '4GKK',
#   '4DR2',
#   '4JI0A',
#   '1HNX',
#   '2ZM6',
#   '4DUYB',
#   '4X66',
#   '3T1H',
#   '1HNZ',
#   '2UXC',
#   '4JI0B',
#   '4K0K',
#   '4X62',
#   '1XMQ',
#   '1IBK',
#   '3CF5',
#   '5JVGA',
#   '5NRGB',
#   '4WF9',
#   '1NWY',
#   '4WFB',
#   '4WFA',
#   '1FEU',
#   '1NKW',
#   '1D6K',
#   '3DLL',
#   '4IOA',
#   '1XBP',
#   '1NWX',
#   '4IO9',
#   '3PIP',
#   '5DM6',
#   '3PIO',
#   '2ZJQ',
#   '1SM1',
#   '2ZJR',
#   '5DM7',
#   '5NRGA',
#   '1NJP',
#   '5JVGB',
#   '1DFU',
#   '3CCQ',
#   '1KC8',
#   '1YHQ',
#   '3CMA',
#   '3CF5',
#   '1VQ5',
#   '3CCJ',
#   '1VQO',
#   '5JVGA',
#   '1N8R',
#   '1QVG',
#   '1VQ6',
#   '5NRGB',
#   '3CXC',
#   '3CD6',
#   '1Q86',
#   '1Q7Y',
#   '1JJ2',
#   '4WF9',
#   '2QEX',
#   '1M90',
#   '1YJW',
#   '1VQL',
#   '1NJI',
#   '1VQ7',
#   '1YI2',
#   '1NWY',
#   '4WFB',
#   '1QVF',
#   '1VQK',
#   '4WFA',
#   '3CCE',
#   '3CC2',
#   '3I55',
#   '1VQ9',
#   '3G4S',
#   '1VQ8',
#   '3CC4',
#   '1VQM',
#   '1Q81',
#   '1NKW',
#   '3DLL',
#   '4IOA',
#   '3OW2',
#   '1XBP',
#   '1NWX',
#   '4IO9',
#   '3G71',
#   '3G6E',
#   '3PIP',
#   '5DM6',
#   '3CCL',
#   '3PIO',
#   '1YJN',
#   '3CCR',
#   '1VQP',
#   '2ZJQ',
#   '3CCS',
#   '3CCM',
#   '1K9M',
#   '1YJ9B',
#   '1SM1',
#   '1KQS',
#   '2OTL',
#   '1S72',
#   '3CC7',
#   '3CME',
#   '2ZJR',
#   '5DM7',
#   '3I56',
#   '1W2B',
#   '3CPW',
#   '1YJ9A',
#   '1YIJ',
#   '1K73',
#   '3CCU',
#   '5NRGA',
#   '1K8A',
#   '2OTJ',
#   '1YIT',
#   '5JVGB',
#   '1FFK',
#   '1VQ4',
#   '1M1K',
#   '1VQN',
#   '1KD1',
#   '1Q82',
#   '3CCV',
#   '3CF5',
#   '5JVGA',
#   '5NRGB',
#   '4WF9',
#   '1NWY',
#   '4WFB',
#   '4WFA',
#   '1NKW',
#   '3DLL',
#   '4IOA',
#   '1XBP',
#   '1NWX',
#   '4IO9',
#   '3PIP',
#   '5DM6',
#   '3PIO',
#   '2ZJQ',
#   '1SM1',
#   '1Y69',
#   '2ZJR',
#   '5DM7',
#   '5NRGA',
#   '5JVGB',
#   '3CCQ',
#   '1KC8',
#   '1YHQ',
#   '3CMA',
#   '3CF5',
#   '1VQ5',
#   '3CCJ',
#   '1VQO',
#   '5JVGA',
#   '1N8R',
#   '1QVG',
#   '1VQ6',
#   '5NRGB',
#   '3CXC',
#   '3CD6',
#   '1Q86',
#   '1Q7Y',
#   '1JJ2',
#   '4WF9',
#   '2QEX',
#   '1M90',
#   '1YJW',
#   '1VQL',
#   '1NJI',
#   '1VQ7',
#   '1YI2',
#   '1NWY',
#   '4WFB',
#   '1QVF',
#   '1VQK',
#   '4WFA',
#   '3CCE',
#   '3CC2',
#   '3I55',
#   '1VQ9',
#   '3G4S',
#   '1VQ8',
#   '3CC4',
#   '1VQM',
#   '1Q81',
#   '1NKW',
#   '3DLL',
#   '4IOA',
#   '3OW2',
#   '1XBP',
#   '1NWX',
#   '4IO9',
#   '3G71',
#   '3G6E',
#   '3PIP',
#   '5DM6',
#   '3CCL',
#   '3PIO',
#   '1YJN',
#   '3CCR',
#   '1VQP',
#   '2ZJQ',
#   '3CCS',
#   '3CCM',
#   '1K9M',
#   '1YJ9B',
#   '1SM1',
#   '1KQS',
#   '2OTL',
#   '1S72',
#   '3CC7',
#   '3CME',
#   '2ZJR',
#   '5DM7',
#   '3I56',
#   '1W2B',
#   '3CPW',
#   '1YJ9A',
#   '1YIJ',
#   '1K73',
#   '3CCU',
#   '5NRGA',
#   '1K8A',
#   '2OTJ',
#   '1YIT',
#   '5JVGB',
#   '1FFK',
#   '1VQ4',
#   '1M1K',
#   '1VQN',
#   '1KD1',
#   '1Q82',
#   '3CCV',
#   '3CCQ',
#   '1KC8',
#   '1YHQ',
#   '3CMA',
#   '1VQ5',
#   '3CCJ',
#   '1VQO',
#   '1N8R',
#   '1QVG',
#   '1VQ6',
#   '3CXC',
#   '3CD6',
#   '1Q86',
#   '1Q7Y',
#   '1JJ2',
#   '2QEX',
#   '1M90',
#   '1YJW',
#   '1VQL',
#   '1NJI',
#   '1VQ7',
#   '1YI2',
#   '1QVF',
#   '1VQK',
#   '3CCE',
#   '3CC2',
#   '3I55',
#   '1VQ9',
#   '3G4S',
#   '1VQ8',
#   '3CC4',
#   '1VQM',
#   '1Q81',
#   '3OW2',
#   '3G71',
#   '3G6E',
#   '3CCL',
#   '1YJN',
#   '3CCR',
#   '1VQP',
#   '3CCS',
#   '3CCM',
#   '1K9M',
#   '1YJ9B',
#   '1KQS',
#   '2OTL',
#   '1S72',
#   '3CC7',
#   '3CME',
#   '3I56',
#   '1W2B',
#   '3CPW',
#   '1YJ9A',
#   '1YIJ',
#   '1K73',
#   '3CCU',
#   '1K8A',
#   '2OTJ',
#   '1YIT',
#   '1FFK',
#   '1VQ4',
#   '1M1K',
#   '1VQN',
#   '1KD1',
#   '1Q82',
#   '3CCV',
#   '1XMO',
#   '4DUYA',
#   '4LFB',
#   '4B3T',
#   '4DR3',
#   '4B3R',
#   '1XNR',
#   '4B3S',
#   '1IBL',
#   '4YHH',
#   '2UUA',
#   '4DR6',
#   '4DV6B',
#   '4JYA',
#   '4X64',
#   '4GKJ',
#   '1HR0',
#   '4LF6',
#   '4B3M',
#   '5IWAB',
#   '4DV6A',
#   '4JI3',
#   '4JI1',
#   '2E5L',
#   '4DR5A',
#   '1IBM',
#   '3T1Y',
#   '1N33',
#   '4X65',
#   '1FJG',
#   '2HHH',
#   '2UU9',
#   '2VQE',
#   '4LF8',
#   '1XNQ',
#   '1I94',
#   '4JI7A',
#   '2UUB',
#   '5BR8',
#   '4DV7',
#   '1N32',
#   '4DR5B',
#   '4LF7',
#   '4LF4',
#   '4JV5',
#   '4AQY',
#   '5IWAA',
#   '4LF9',
#   '2UXD',
#   '2UXB',
#   '4JI7B',
#   '2UUC',
#   '1HNW',
#   '4KHP',
#   '1J5E',
#   '2VQF',
#   '4GKK',
#   '4DR2',
#   '4JI0A',
#   '1HNX',
#   '2ZM6',
#   '4DUYB',
#   '4X66',
#   '3T1H',
#   '1HNZ',
#   '2UXC',
#   '4JI0B',
#   '4K0K',
#   '4X62',
#   '1XMQ',
#   '1IBK',
#   '3CCQ',
#   '1KC8',
#   '1YHQ',
#   '3CMA',
#   '3CF5',
#   '1VQ5',
#   '3CCJ',
#   '1VQO',
#   '5JVGA',
#   '1N8R',
#   '1QVG',
#   '1VQ6',
#   '5NRGB',
#   '3CXC',
#   '3CD6',
#   '1Q86',
#   '1Q7Y',
#   '1JJ2',
#   '4WF9',
#   '2QEX',
#   '1M90',
#   '1YJW',
#   '1VQL',
#   '1NJI',
#   '1VQ7',
#   '1YI2',
#   '1NWY',
#   '4WFB',
#   '1QVF',
#   '1VQK',
#   '4WFA',
#   '3CCE',
#   '3CC2',
#   '3I55',
#   '1VQ9',
#   '3G4S',
#   '1VQ8',
#   '3CC4',
#   '1VQM',
#   '1Q81',
#   '1NKW',
#   '3DLL',
#   '4IOA',
#   '3OW2',
#   '1XBP',
#   '1NWX',
#   '4IO9',
#   '3G71',
#   '3G6E',
#   '3PIP',
#   '5DM6',
#   '3CCL',
#   '3PIO',
#   '1YJN',
#   '3CCR',
#   '1VQP',
#   '2ZJQ',
#   '3CCS',
#   '3CCM',
#   '1MJI',
#   '1K9M',
#   '1YJ9B',
#   '1SM1',
#   '1KQS',
#   '2OTL',
#   '1S72',
#   '3CC7',
#   '3CME',
#   '2ZJR',
#   '5DM7',
#   '3I56',
#   '1W2B',
#   '3CPW',
#   '1YJ9A',
#   '1YIJ',
#   '1K73',
#   '3CCU',
#   '5NRGA',
#   '1K8A',
#   '2OTJ',
#   '1YIT',
#   '5JVGB',
#   '1FFK',
#   '1VQ4',
#   '1M1K',
#   '1VQN',
#   '1KD1',
#   '1Q82',
#   '3CCV',
#   '1JZY',
#   '3CCQ',
#   '1KC8',
#   '1YHQ',
#   '3CMA',
#   '3CF5',
#   '1VQ5',
#   '3CCJ',
#   '1VQO',
#   '5JVGA',
#   '1N8R',
#   '1QVG',
#   '1VQ6',
#   '1JZX',
#   '5NRGB',
#   '3CXC',
#   '3CD6',
#   '1Q86',
#   '1Q7Y',
#   '1JJ2',
#   '4WF9',
#   '2QEX',
#   '1M90',
#   '1YJW',
#   '1VQL',
#   '1NJI',
#   '1VQ7',
#   '1YI2',
#   '1NWY',
#   '4WFB',
#   '1QVF',
#   '1VQK',
#   '4WFA',
#   '3CCE',
#   '3CC2',
#   '3I55',
#   '1VQ9',
#   '3G4S',
#   '1VQ8',
#   '3CC4',
#   '1VQM',
#   '1Q81',
#   '1NKW',
#   '3DLL',
#   '4IOA',
#   '3OW2',
#   '1XBP',
#   '1NWX',
#   '1OND',
#   '4IO9',
#   '3G71',
#   '3G6E',
#   '3PIP',
#   '5DM6',
#   '3CCL',
#   '3PIO',
#   '1YJN',
#   '3CCR',
#   '1VQP',
#   '2ZJQ',
#   '3CCS',
#   '3CCM',
#   '1K9M',
#   '1YJ9B',
#   '1SM1',
#   '1KQS',
#   '2OTL',
#   '1S72',
#   '3CC7',
#   '3CME',
#   '2ZJR',
#   '5DM7',
#   '3I56',
#   '1W2B',
#   '3CPW',
#   '1YJ9A',
#   '1K01',
#   '1YIJ',
#   '1K73',
#   '3CCU',
#   ...],
#  'RrnaAD': ['3R9X', '3FTE', '3FTF'],
#  'S1': ['2VNU',
#   '5JEA',
#   '4IFD',
#   '5K36',
#   '5VZJ',
#   '6FUW',
#   '2C0B',
#   '4A93',
#   '2VUM',
#   '5XOG',
#   '5F6C',
#   '3AEV',
#   '4A3D',
#   '4A3K',
#   '4BY7',
#   '3HOV',
#   '4A3C',
#   '3HOU',
#   '5OT2',
#   '4A3F',
#   '3PO3',
#   '4A3B',
#   '2VRT',
#   '4BXX',
#   '2BX2',
#   '3HOY',
#   '3PO2',
#   '2IX1',
#   '5LM7',
#   '4A3E',
#   '4IG8',
#   '4S3N',
#   '4RWP',
#   '4RWN',
#   '4RWO'],
#  'SAM': ['5HR7', '5HR6', '2ESE', '2B6G', '2F8K'],
#  'SAP': ['4L8R', '1ZBH', '4QOZ'],
#  'SBP_bac_1': ['1T0K'],
#  'SHS2_Rpb7-N': ['4A93',
#   '2VUM',
#   '5XOG',
#   '4A3D',
#   '4A3K',
#   '4BY7',
#   '3HOV',
#   '4A3C',
#   '3HOU',
#   '5OT2',
#   '4A3F',
#   '3PO3',
#   '4A3B',
#   '4BXX',
#   '3HOY',
#   '3PO2',
#   '4A3E'],
#  'SLBP_RNA_bind': ['4L8R', '4TV0', '4TUW', '4TUX', '4QOZ'],
#  'SPOC': ['4BY7', '4BXX'],
#  'SRP': ['4UYK',
#   '1E8O',
#   '4UYJ',
#   '5AOX',
#   '2V3C',
#   '4C7O',
#   '3NDB',
#   '4P3EB',
#   '5M73',
#   '4P3EA',
#   '5M73',
#   '2V3C',
#   '4C7O',
#   '3NDB',
#   '4UYK',
#   '1E8O',
#   '4UYJ',
#   '5AOX',
#   '2V3C',
#   '4P3EB',
#   '1LNG',
#   '4XCO',
#   '3KTW',
#   '5M73',
#   '3NDB',
#   '1JID',
#   '4P3EA',
#   '1MFQ',
#   '1L9A',
#   '2PXK',
#   '2PXV',
#   '2PXF',
#   '2PXU',
#   '2PXT',
#   '2PXP',
#   '2PXD',
#   '1DUL',
#   '2PXE',
#   '2V3C',
#   '2PXB',
#   '2PXL',
#   '3LQX',
#   '2PXQ',
#   '4XCO',
#   '3NDB',
#   '1HQ1',
#   '1MFQ'],
#  'SSB': ['1EQQ'],
#  'STAR_dimer': ['4JVH', '4JVYB', '4JVYA'],
#  'SWIRM': ['4XBF'],
#  'Selen_transf': ['4ZDPA',
#   '4ZDPB',
#   '4ZDOB',
#   '3HL2A',
#   '4ZDOA',
#   '5X6B',
#   '3HL2B'],
#  'She2p': ['5M0J', '5M0I'],
#  'SmpB': ['2CZJ', '1P6V'],
#  'Staufen_C': ['1DI2'],
#  'TAL_effector': ['4GG4'],
#  'TGS': ['1QF6'],
#  'THUMP': ['4KR6', '4KR7', '4KR9'],
#  'TPR': ['4HORA',
#   '4HOS',
#   '5UDL',
#   '5UDJ',
#   '5W5H',
#   '5W5I',
#   '4HOT',
#   '5UDI',
#   '4HORB',
#   '6C6K',
#   '5UDK',
#   '4HORA',
#   '4HOS',
#   '5UDL',
#   '5UDJ',
#   '5W5H',
#   '5W5I',
#   '4HOT',
#   '5UDI',
#   '4HORB',
#   '6C6K',
#   '5UDK',
#   '4HORA',
#   '4HOS',
#   '4HOT',
#   '4HORB'],
#  'TRAM': ['2BH2'],
#  'TROVE': ['1YVP', '2I91'],
#  'Tap-RNA_bind': ['3RW6'],
#  'Telomerase_RBD': ['5C9H', '4O26'],
#  'ThiI': ['4KR6', '4KR7', '4KR9'],
#  'Thrombin_light': ['5DO4'],
#  'Thx': ['1XMO',
#   '4DUYA',
#   '4LFB',
#   '4B3T',
#   '4DR3',
#   '4B3R',
#   '1XNR',
#   '4B3S',
#   '1IBL',
#   '4YHH',
#   '2UUA',
#   '4DR6',
#   '4DV6B',
#   '4JYA',
#   '4X64',
#   '4GKJ',
#   '1HR0',
#   '4LF6',
#   '4B3M',
#   '5IWAB',
#   '4DV6A',
#   '4JI3',
#   '4JI1',
#   '2E5L',
#   '4DR5A',
#   '1IBM',
#   '3T1Y',
#   '1N33',
#   '4X65',
#   '1FJG',
#   '2HHH',
#   '2UU9',
#   '2VQE',
#   '4LF8',
#   '1XNQ',
#   '1I94',
#   '4JI7A',
#   '2UUB',
#   '5BR8',
#   '4DV7',
#   '1N32',
#   '4DR5B',
#   '4LF7',
#   '4LF4',
#   '4JV5',
#   '4AQY',
#   '5IWAA',
#   '4LF9',
#   '2UXD',
#   '2UXB',
#   '4JI7B',
#   '2UUC',
#   '1HNW',
#   '4KHP',
#   '1J5E',
#   '2VQF',
#   '4GKK',
#   '4DR2',
#   '4JI0A',
#   '1HNX',
#   '2ZM6',
#   '4DUYB',
#   '4X66',
#   '3T1H',
#   '1HNZ',
#   '2UXC',
#   '4JI0B',
#   '4K0K',
#   '4X62',
#   '1XMQ',
#   '1IBK'],
#  'Transc_F': ['5VI5',
#   '4BY7',
#   '3PO3',
#   '4BXX',
#   '4A93',
#   '2VUM',
#   '5XOG',
#   '4A3D',
#   '4A3K',
#   '4BY7',
#   '4Y52',
#   '3S2H',
#   '3RZD',
#   '3S17',
#   '3S2D',
#   '3S1Q',
#   '3HOV',
#   '3S1R',
#   '1I6H',
#   '4A3C',
#   '3HOU',
#   '5OT2',
#   '3GTJ',
#   '3S1M',
#   '3M3Y',
#   '4A3F',
#   '3PO3',
#   '4A3B',
#   '2NVT',
#   '2E2I',
#   '4BXX',
#   '3HOY',
#   '2YU9',
#   '1R9T',
#   '4Y7N',
#   '3PO2',
#   '2NVQ',
#   '3S16',
#   '3S14',
#   '3S15',
#   '3RZO',
#   '3S1N',
#   '3GTL',
#   '4A3E',
#   '2E2J'],
#  'Transc_IF': ['5E17',
#   '5E18',
#   '4Q5S',
#   '5VI5',
#   '5E17',
#   '5E18',
#   '4Q5S',
#   '5VI5',
#   '5E17',
#   '5E18',
#   '4Q5S',
#   '5VI5',
#   '5E17',
#   '5E18',
#   '4Q5S',
#   '5VI5'],
#  'Transl_IF': ['3QSY', '3AEV', '3QSY', '1HR0'],
#  'Translin': ['3ZC0A', '5JRC', '3ZC0B'],
#  'Trigger': ['2AAR', '2D3O', '1W2B'],
#  'TrpBP': ['5EEV',
#   '1GTN',
#   '1C9S',
#   '5EF0',
#   '5EF2',
#   '5EF1',
#   '5EF3',
#   '1GTF',
#   '5EEX',
#   '5EEZ',
#   '1UTD',
#   '5EEY',
#   '5EEW',
#   '5EEU'],
#  'Trypsin': ['3DD2', '5DO4'],
#  'V-set': ['5UK4'],
#  'WD40': ['5GXHA',
#   '5GXI',
#   '5H1L',
#   '5H3U',
#   '6FUW',
#   '5H1K',
#   '5GXHA',
#   '5GXI',
#   '5H1L',
#   '5H3U',
#   '5H1K'],
#  'Xpo1': ['3A6P', '3ICQ'],
#  'YTH': ['5EIM', '2MTV', '6FPX', '4R3I', '4RCJ', '6FPQ', '4U8T', '5DNO'],
#  'actin_cross-linking': ['6FQ3', '6FQL'],
#  'coat': ['1CWP',
#   '1XOK',
#   '1LAJ',
#   '1DDL',
#   '2FZ2',
#   '2XPJ',
#   '2QUX',
#   '4L8H',
#   '2B2D',
#   '1ZSE',
#   '2C50',
#   '4ANGB',
#   '2C4Z',
#   '1ZDK',
#   '2IZ8',
#   '5MSF',
#   '4ANGA',
#   '1AQ3',
#   '1ZDJ',
#   '2IZN',
#   '2C51',
#   '2IZ9',
#   '1AQ4',
#   '2BU1',
#   '2BS0',
#   '2C4Y',
#   '2BQ5',
#   '2B2E',
#   '2C4Q',
#   '1ZDH',
#   '2BNY',
#   '1ZDI',
#   '6MSF',
#   '2BS1',
#   '1U1Y',
#   '2B2G',
#   '2IZM',
#   '7MSF',
#   '1PGL',
#   '1BMV'],
#  'dsRBD': ['3HTX'],
#  'dsrm': ['1YYW',
#   '2L3C',
#   '1RC7',
#   '1T4L',
#   '1DI2',
#   '2L3J',
#   '2L2K',
#   '2NUGA',
#   '5DV7',
#   '2LBS',
#   '1YYO',
#   '2NUF',
#   '2NUGB',
#   '5T16',
#   '3ADI',
#   '2NUE',
#   '4OOG',
#   '3ADL',
#   '1YZ9',
#   '2EZ6',
#   '1EKZ',
#   '4M30',
#   '4M2Z',
#   '3VYX',
#   '3VYY',
#   '2LUP',
#   '1YYK'],
#  'exonuclease': ['2VNU',
#   '5JEA',
#   '4IFD',
#   '5K36',
#   '4PMW',
#   '5VZJ',
#   '4PMW',
#   '4J7M',
#   '4J7L',
#   '5BUD',
#   '5BTE'],
#  'exosome': ['5JEA',
#   '4IFD',
#   '5K36',
#   '4OO1',
#   '5VZJ',
#   '3M7N',
#   '5JEA',
#   '4IFD',
#   '3M85',
#   '5K36',
#   '4OO1',
#   '5VZJ',
#   '3M7N',
#   '5JEA',
#   '4IFD',
#   '3M85',
#   '5K36',
#   '4OO1',
#   '5VZJ'],
#  'ncap': ['5IP2',
#   '4XJN',
#   '4GV6',
#   '4GV9',
#   '4FVU',
#   '4GV3',
#   '4G9Z',
#   '3T5Q',
#   '3T5N',
#   '2WJ8',
#   '4J1G',
#   '4JNG',
#   '3ZLA',
#   '4BHH',
#   '4IJS',
#   '3PU1',
#   '5UK4',
#   '2GTT',
#   '3HHZ',
#   '3PTX',
#   '3PU0',
#   '2GIC',
#   '3PU4'],
#  'phosphoesterase': ['5K78', '4PEH'],
#  'spliceosome': ['4PKD', '4PJO'],
#  'tRNA-ribosyltransf': ['1J2B', '1J2B', '1Q2S', '1J2B', '1Q2R'],
#  'tRNA_SAD': ['3WQZ', '1QF6', '3WQY'],
#  'tRNA_bind': ['2IY5', '1EIY', '3W3S'],
#  'tRNA_int_endo': ['2GJW', '2GJW'],
#  'tRNA_synt': ['4KR3',
#   '4YYE',
#   '4QEI',
#   '4RDX',
#   '1KOG',
#   '1QF6',
#   '1H4S',
#   '5E6M',
#   '4KR2',
#   '1H4Q',
#   '2BTE',
#   '2BYT',
#   '2V0G',
#   '5E6M',
#   '1U0B',
#   '4A93',
#   '2VUM',
#   '5XOG',
#   '4A3D',
#   '4A3K',
#   '4BY7',
#   '4Y52',
#   '3S2H',
#   '3RZD',
#   '3S17',
#   '3S2D',
#   '3S1Q',
#   '3HOV',
#   '3S1R',
#   '1I6H',
#   '4A3C',
#   '3HOU',
#   '5OT2',
#   '3GTJ',
#   '3S1M',
#   '3M3Y',
#   '4A3F',
#   '3PO3',
#   '4A3B',
#   '2NVT',
#   '2E2I',
#   '4BXX',
#   '3HOY',
#   '2YU9',
#   '1R9T',
#   '4Y7N',
#   '3PO2',
#   '2NVQ',
#   '3S16',
#   '3S14',
#   '3S15',
#   '3RZO',
#   '3S1N',
#   '3GTL',
#   '4A3E',
#   '2E2J',
#   '4AQ7',
#   '2BTE',
#   '4ARI',
#   '5OMW',
#   '5AH5',
#   '3ZJV',
#   '4ARC',
#   '3ZJU',
#   '5ONH',
#   '2BYT',
#   '5ON2',
#   '3ZGZ',
#   '4CQN',
#   '4AS1',
#   '2V0G',
#   '5ON3',
#   '3ZJT',
#   '2IY5',
#   '3TUP',
#   '1EIY',
#   '3WQZ',
#   '3WQY',
#   '4RQF',
#   '1SER',
#   '2DU4',
#   '2DU3',
#   '2DU6',
#   '2DU5',
#   '2XGJ',
#   '2IY5',
#   '1EIY',
#   '3WQZ',
#   '3WQY',
#   '1H4S',
#   '1H4Q',
#   '2IY5',
#   '1EIY',
#   '4A93',
#   '2VUM',
#   '5XOG',
#   '4A3D',
#   '4A3K',
#   '4BY7',
#   '4Y52',
#   '3S2H',
#   '3RZD',
#   '3S17',
#   '3S2D',
#   '3S1Q',
#   '3HOV',
#   '3S1R',
#   '1I6H',
#   '4A3C',
#   '3HOU',
#   '5OT2',
#   '3GTJ',
#   '3S1M',
#   '3M3Y',
#   '4A3F',
#   '3PO3',
#   '4A3B',
#   '2NVT',
#   '2E2I',
#   '4BXX',
#   '3HOY',
#   '2YU9',
#   '1R9T',
#   '4Y7N',
#   '3PO2',
#   '2NVQ',
#   '3S16',
#   '3S14',
#   '3S15',
#   '3RZO',
#   '3S1N',
#   '3GTL',
#   '4A3E',
#   '2E2J',
#   '1F7V',
#   '2ZUFB',
#   '1F7U',
#   '2ZUEA',
#   '2ZUFA',
#   '2ZUEB',
#   '3KFU',
#   '1IL2',
#   '1EFW',
#   '1ASZ',
#   '1C0A',
#   '4WJ4',
#   '1ASY',
#   '2ZNI',
#   '2IY5',
#   '2DU4',
#   '2DU3',
#   '2DU6',
#   '3TUP',
#   '1EIY',
#   '2DU5',
#   '1IVS',
#   '1GAX',
#   '2CSX',
#   '2CT8',
#   '2AKE',
#   '2DLC',
#   '2AZX',
#   '1J1U',
#   '2DR2',
#   '1H3E',
#   '4JYZ',
#   '2RD2',
#   '1N77',
#   '1N78',
#   '2CV0',
#   '1O0B',
#   '4JXZ',
#   '1EUQ',
#   '1QRS',
#   '2CV2',
#   '1QRU',
#   '3AKZ',
#   '1ZJW',
#   '1EUY',
#   '1GTS',
#   '1QRT',
#   '1O0C',
#   '2RE8',
#   '1QTQ',
#   '1G59',
#   '1GTR',
#   '2CV1',
#   '4JXX',
#   '3AL0',
#   '2DXI',
#   '1EXD',
#   '1F7V',
#   '2ZUFB',
#   '1F7U',
#   '2ZUEA',
#   '2ZUFA',
#   '2ZUEB',
#   '1F7V',
#   '2ZUFB',
#   '1F7U',
#   '2ZUEA',
#   '2ZUFA',
#   '2ZUEB',
#   '2IY5',
#   '1EIY',
#   '3KFU',
#   '3AMT',
#   '1IL2',
#   '1EFW',
#   '1ASZ',
#   '1C0A',
#   '4WJ4',
#   '3AMU',
#   '1ASY',
#   '2IY5',
#   '1EIY',
#   '4KR3',
#   '4RQF',
#   '4YYE',
#   '4QEI',
#   '1KOG',
#   '1QF6',
#   '1H4S',
#   '5E6M',
#   '4KR2',
#   '1SER',
#   '1H4Q',
#   '3W3S',
#   '4RDX',
#   '4JYZ',
#   '2RD2',
#   '1O0B',
#   '4JXZ',
#   '1EUQ',
#   '1QRS',
#   '1QRU',
#   '1ZJW',
#   '1EUY',
#   '1GTS',
#   '1QRT',
#   '1O0C',
#   '2RE8',
#   '1QTQ',
#   '1GTR',
#   '4JXX',
#   '1EXD',
#   '4AQ7',
#   '2BTE',
#   '1IVS',
#   '4ARI',
#   '1FFY',
#   '5OMW',
#   '1WZ2',
#   '5AH5',
#   '3ZJV',
#   '4ARC',
#   '3ZJU',
#   '5ONH',
#   '2BYT',
#   '5ON2',
#   '1QU2',
#   '1QU3',
#   '3ZGZ',
#   '1GAX',
#   '4CQN',
#   '4AS1',
#   '2V0G',
#   '5ON3',
#   '3ZJT',
#   '1U0B'],
#  'toxin': ['4MDX', '5HK0', '2C06', '5HJZ', '2XD0', '4ATO', '2XDB', '2XDD'],
#  'unknown': ['2XZL',
#   '2XZO',
#   '5X6B',
#   '1IL2',
#   '1EFW',
#   '1C0A',
#   '4WJ4',
#   '2D6F',
#   '3X1L',
#   '5D0B',
#   '5D0A',
#   '5T8Y',
#   '2ZZN',
#   '2ZZM',
#   '3X1L',
#   '3AMT',
#   '3AMU',
#   '6B0B',
#   '4YHW'],
#  'virus': ['5E17',
#   '4A93',
#   '2VUM',
#   '5XOG',
#   '4A3D',
#   '4A3K',
#   '4BY7',
#   '4Y52',
#   '3S2H',
#   '3RZD',
#   '3S17',
#   '3S2D',
#   '3S1Q',
#   '2O5J',
#   '5E18',
#   '3HOV',
#   '3S1R',
#   '1I6H',
#   '4A3C',
#   '3HOU',
#   '5OT2',
#   '3GTJ',
#   '3S1M',
#   '3M3Y',
#   '4Q5S',
#   '4A3F',
#   '3PO3',
#   '4A3B',
#   '2NVT',
#   '2E2I',
#   '4BXX',
#   '3HOY',
#   '2PPB',
#   '2YU9',
#   '1R9T',
#   '2O5I',
#   '4Y7N',
#   '3PO2',
#   '2NVQ',
#   '3S16',
#   '3S14',
#   '3S15',
#   '3RZO',
#   '3S1N',
#   '5VI5',
#   '3GTL',
#   '4A3E',
#   '2E2J',
#   '3L25',
#   '4LG2',
#   '3L26',
#   '3KS8',
#   '4GHL',
#   '4GHA',
#   '5HSW',
#   '5E17',
#   '4A93',
#   '2VUM',
#   '5XOG',
#   '4A3D',
#   '4A3K',
#   '4BY7',
#   '4Y52',
#   '3S2H',
#   '3RZD',
#   '3S17',
#   '3S2D',
#   '3S1Q',
#   '2O5J',
#   '5E18',
#   '3HOV',
#   '3S1R',
#   '1I6H',
#   '4A3C',
#   '3HOU',
#   '5OT2',
#   '3GTJ',
#   '3S1M',
#   '3M3Y',
#   '4Q5S',
#   '4A3F',
#   '3PO3',
#   '4A3B',
#   '2NVT',
#   '2E2I',
#   '4BXX',
#   '3HOY',
#   '2PPB',
#   '2YU9',
#   '1R9T',
#   '2O5I',
#   '4Y7N',
#   '3PO2',
#   '2NVQ',
#   '3S16',
#   '3S14',
#   '3S15',
#   '3RZO',
#   '3S1N',
#   '5VI5',
#   '3GTL',
#   '4A3E',
#   '2E2J',
#   '1PGL',
#   '1BMV',
#   '5E17',
#   '4A93',
#   '2VUM',
#   '5XOG',
#   '4A3D',
#   '4A3K',
#   '4BY7',
#   '4Y52',
#   '3S2H',
#   '3RZD',
#   '3S17',
#   '3S2D',
#   '3S1Q',
#   '2O5J',
#   '5E18',
#   '3HOV',
#   '3S1R',
#   '1I6H',
#   '4A3C',
#   '3HOU',
#   '5OT2',
#   '3GTJ',
#   '3S1M',
#   '3M3Y',
#   '4Q5S',
#   '4A3F',
#   '3PO3',
#   '4A3B',
#   '2NVT',
#   '2E2I',
#   '4BXX',
#   '3HOY',
#   '2PPB',
#   '2YU9',
#   '1R9T',
#   '2O5I',
#   '4Y7N',
#   '3PO2',
#   '2NVQ',
#   '3S16',
#   '3S14',
#   '3S15',
#   '3RZO',
#   '3S1N',
#   '5VI5',
#   '3GTL',
#   '4A3E',
#   '2E2J',
#   '5AMQ',
#   '5AMR',
#   '5AMQ',
#   '5AMR',
#   '4A93',
#   '2VUM',
#   '5XOG',
#   '4A3D',
#   '4A3K',
#   '4BY7',
#   '4Y52',
#   '3S2H',
#   '3RZD',
#   '3S17',
#   '3S2D',
#   '3S1Q',
#   '3HOV',
#   '3S1R',
#   '1I6H',
#   '4A3C',
#   '3HOU',
#   '5OT2',
#   '3GTJ',
#   '3S1M',
#   '3M3Y',
#   '4A3F',
#   '3PO3',
#   '4A3B',
#   '2NVT',
#   '2E2I',
#   '4BXX',
#   '3HOY',
#   '2YU9',
#   '1R9T',
#   '4Y7N',
#   '3PO2',
#   '2NVQ',
#   '3S16',
#   '3S14',
#   '3S15',
#   '3RZO',
#   '3S1N',
#   '3GTL',
#   '4A3E',
#   '2E2J',
#   '1LAJ',
#   '5E17',
#   '2O5J',
#   '5E18',
#   '4Q5S',
#   '2PPB',
#   '2O5I',
#   '5VI5',
#   '5LM7',
#   '1QFQ',
#   '1MNB',
#   '2W2H',
#   '1ZBN',
#   '1BIV',
#   '5E17',
#   '4A93',
#   '2VUM',
#   '5XOG',
#   '4A3D',
#   '4A3K',
#   '4BY7',
#   '4Y52',
#   '3S2H',
#   '3RZD',
#   '3S17',
#   '3S2D',
#   '3S1Q',
#   '2O5J',
#   '5E18',
#   '3HOV',
#   '3S1R',
#   '1I6H',
#   '4A3C',
#   '3HOU',
#   '5OT2',
#   '3GTJ',
#   '3S1M',
#   '3M3Y',
#   '4Q5S',
#   '4A3F',
#   '3PO3',
#   '4A3B',
#   '2NVT',
#   '2E2I',
#   '4BXX',
#   '3HOY',
#   '2PPB',
#   '2YU9',
#   '1R9T',
#   '2O5I',
#   '4Y7N',
#   '3PO2',
#   '2NVQ',
#   '3S16',
#   '3S14',
#   '3S15',
#   '3RZO',
#   '3S1N',
#   '5VI5',
#   '3GTL',
#   '4A3E',
#   '2E2J',
#   '2ZKO',
#   '1KNZ',
#   '5DTO',
#   '2XBM',
#   '5FMZ',
#   '6EVK',
#   '4WRT',
#   '4WSB',
#   '5M3H',
#   '4WSA',
#   '5M3J',
#   '4H5P',
#   '4CSF',
#   '4KQ0',
#   '4KNQ',
#   '4JGN',
#   '4KTGA',
#   '4JK0',
#   '4J39B',
#   '4KTGB',
#   '4JNXB',
#   '4J5VA',
#   '1RPUA',
#   '1R9F',
#   '1RPUB',
#   '4J5VB',
#   '4JNXA',
#   '4J39A',
#   '5FMZ',
#   '6EVK',
#   '4WRT',
#   '4WSB',
#   '5M3H',
#   '4WSA',
#   '5M3J',
#   '4J1G',
#   '4JNG',
#   '3ZLA',
#   '4BHH',
#   '4IJS',
#   '5FMZ',
#   '6EVK',
#   '4WRT',
#   '4WSB',
#   '5M3H',
#   '4WSA',
#   '5M3J',
#   '2JLZ',
#   '5GJB',
#   '2JLY',
#   '5MFX',
#   '3O8R',
#   '2JLV',
#   '3O8C',
#   '2JLW',
#   '4E78',
#   '2JLX',
#   '2JLU',
#   '5XC6',
#   '1H2C',
#   '1H2D',
#   '5MJV',
#   '4Z92',
#   '3CZ3A',
#   '3CZ3B',
#   '2ZI0',
#   '5E17',
#   '4A93',
#   '2VUM',
#   '5XOG',
#   '4A3D',
#   '4A3K',
#   '4BY7',
#   '4Y52',
#   '3S2H',
#   '3RZD',
#   '3S17',
#   '3S2D',
#   '3S1Q',
#   '2O5J',
#   '5E18',
#   '3HOV',
#   '3S1R',
#   '1I6H',
#   '4A3C',
#   '3HOU',
#   '5OT2',
#   '3GTJ',
#   '3S1M',
#   '3M3Y',
#   '4Q5S',
#   '4A3F',
#   '3PO3',
#   '4A3B',
#   '2NVT',
#   '2E2I',
#   '4BXX',
#   '3HOY',
#   '2PPB',
#   '2YU9',
#   '1R9T',
#   '2O5I',
#   '4Y7N',
#   '3PO2',
#   '2NVQ',
#   '3S16',
#   '3S14',
#   '3S15',
#   '3RZO',
#   '3S1N',
#   '5VI5',
#   '3GTL',
#   '4A3E',
#   '2E2J',
#   '1ETF',
#   '484D',
#   '1ETG',
#   '4PMI',
#   '1ULL',
#   '2R7R',
#   '2R7W',
#   '2R7S',
#   '2R7T',
#   '2R7U',
#   '2R7X',
#   '2R7V',
#   '3BSU',
#   '2AZ0',
#   '2AZ2',
#   '4A93',
#   '2VUM',
#   '5XOG',
#   '4A3D',
#   '4A3K',
#   '4BY7',
#   '4Y52',
#   '3S2H',
#   '3RZD',
#   '3S17',
#   '3S2D',
#   '3S1Q',
#   '3HOV',
#   '3S1R',
#   '1I6H',
#   '4A3C',
#   '3HOU',
#   '5OT2',
#   '3GTJ',
#   '3S1M',
#   '3M3Y',
#   '4A3F',
#   '3PO3',
#   '4A3B',
#   '2NVT',
#   '2E2I',
#   '4BXX',
#   '3HOY',
#   '2YU9',
#   '1R9T',
#   '4Y7N',
#   '3PO2',
#   '2NVQ',
#   '3S16',
#   '3S14',
#   '3S15',
#   '3RZO',
#   '3S1N',
#   '3GTL',
#   '4A3E',
#   '2E2J',
#   '1PGL',
#   '1BMV'],
#  'zf': ['3G9YA',
#   '3G9YB',
#   '4PJO',
#   '1FFY',
#   '1QU2',
#   '2MKN',
#   '1RGO',
#   '5ELK',
#   '3D2S',
#   '1UN6',
#   '2HGH',
#   '2MQV',
#   '3TS2',
#   '1F6U',
#   '1WWG',
#   '2IHX',
#   '2MS0',
#   '3TRZ',
#   '5UDZ',
#   '1WWF',
#   '1U6P',
#   '5W0M',
#   '2LI8',
#   '3TS0',
#   '1WWE',
#   '1A1T',
#   '1WWD',
#   '2MS1',
#   '5L2LB',
#   '4LJ0',
#   '5L2LA',
#   '6FUW',
#   '5ELH',
#   '2KG1']}

# %%
pdb_group = inv_dict(group_pdb)
pdb_group
# Out:
# {'1JZY': ['Ribosom', 'Ribosom', 'Ribosom'],
#  '2AKE': ['tRNA_synt'],
#  '3CCQ': ['KOW',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom'],
#  '4L8R': ['SLBP_RNA_bind', 'SAP', 'RNase'],
#  '5XUT': ['NUC', 'CRISPR', 'CRISPR'],
#  '5CCBA': ['Methyltr', 'Methyltr'],
#  '3QJJ': ['Cas'],
#  '2PXK': ['SRP'],
#  '4KR3': ['tRNA_synt', 'tRNA_synt'],
#  '1KC8': ['KOW',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom'],
#  '2ZNI': ['tRNA_synt'],
#  '4K4S': ['RdRP'],
#  '1L1C': ['CAT_RBD'],
#  '2ZXU': ['IPPT'],
#  '1M8V': ['LSM'],
#  '2HVY': ['PseudoU_synth',
#   'PseudoU_synth',
#   'PseudoU_synth',
#   'DKCLD',
#   'Nop',
#   'Ribosom',
#   'PUA'],
#  '4WAL': ['KH'],
#  '2MFC': ['CsrA'],
#  '3SNP': ['EC_4_2_1', 'EC_4_2_1'],
#  '1Q2S': ['tRNA-ribosyltransf'],
#  '4JYZ': ['tRNA_synt', 'tRNA_synt'],
#  '5XBL': ['Cas', 'Cas', 'Cas', 'CRISPR', 'CRISPR'],
#  '2MXY': ['RRM'],
#  '1XMO': ['Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Thx',
#   'KH'],
#  '4H5P': ['virus'],
#  '4L8H': ['coat'],
#  '3QJL': ['Cas'],
#  '4HORA': ['TPR', 'TPR', 'TPR'],
#  '4AQ7': ['tRNA_synt', 'tRNA_synt', 'Anticodon_1'],
#  '5EIM': ['YTH'],
#  '1YYW': ['Ribonuclease', 'NUC', 'dsrm'],
#  '4RDX': ['tRNA_synt', 'tRNA_synt'],
#  '5EMO': ['KH', 'Qua1'],
#  '2AAR': ['Trigger', 'RIG', 'Ribosom', 'Ribosom'],
#  '4DUYA': ['Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Thx',
#   'KH'],
#  '5GUH': ['Ago', 'Ago'],
#  '4CSF': ['virus'],
#  '3TS2': ['CSD', 'zf'],
#  '4ZT0': ['Cas', 'Cas', 'Cas', 'CRISPR', 'CRISPR'],
#  '2PXV': ['SRP'],
#  '5D0B': ['HEAT_PBS', 'unknown'],
#  '4LFB': ['Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Thx',
#   'KH'],
#  '2D3O': ['KOW', 'Trigger', 'RIG', 'Ribosom', 'Ribosom', 'Ribosom'],
#  '5EEV': ['TrpBP'],
#  '3KFU': ['EC_3_5_1', 'tRNA_synt', 'tRNA_synt', 'Glu-tRNAGln', 'Gat', 'Gat'],
#  '4JYA': ['Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Thx',
#   'KH'],
#  '4JI1': ['Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Thx',
#   'KH'],
#  '3R9X': ['RrnaAD', 'Ribosom', 'GTPase', 'KH'],
#  '1N1H': ['RdRP'],
#  '2B2D': ['coat'],
#  '5ELSB': ['KH', 'Qua1'],
#  '2ZHA': ['NUC', 'NTP_transf'],
#  '2RD2': ['tRNA_synt', 'tRNA_synt'],
#  '2PXF': ['SRP'],
#  '2MKI': ['RRM', 'CEBP'],
#  '3KNA': ['RdRP'],
#  '1YHQ': ['KOW',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom'],
#  '4KQ0': ['virus'],
#  '2DLC': ['tRNA_synt'],
#  '1ZSE': ['coat'],
#  '5K78': ['phosphoesterase'],
#  '5E17': ['Transc_IF',
#   'Transc_IF',
#   'Transc_IF',
#   'Transc_IF',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'virus',
#   'virus',
#   'virus',
#   'virus',
#   'virus',
#   'virus'],
#  '3K49': ['PUF'],
#  '5VM9': ['Ago', 'Ago', 'Ago', 'Ago', 'Ago', 'Ago'],
#  '3I5X': ['Cas', 'Helicase', 'Helicase'],
#  '1HC8': ['Ribosom'],
#  '4B3T': ['Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Thx',
#   'KH'],
#  '4AL6': ['Cas'],
#  '3P6Y': ['RRM', 'NUDIX_2'],
#  '1M5P': ['RRM'],
#  '4KR6': ['PseudoU_synth', 'ThiI', 'Methyltr', 'THUMP'],
#  '4RQF': ['tRNA_synt', 'tRNA_synt'],
#  '3OVS': ['NUC', 'NTP_transf'],
#  '5DDO': ['RRM'],
#  '2XS7': ['RRM'],
#  '4AY2': ['Cas', 'RIG', 'RIG', 'Helicase', 'Helicase'],
#  '1CWP': ['coat'],
#  '1VQ5': ['KOW',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom'],
#  '4TV0': ['SLBP_RNA_bind'],
#  '2L3C': ['dsrm'],
#  '1SJ4': ['RRM'],
#  '4J7M': ['exonuclease'],
#  '5TSN': ['RdRP'],
#  '5UK4': ['V-set', 'ncap'],
#  '4OLA': ['Ago', 'Ago', 'Ago', 'Ago', 'Ago', 'Ago'],
#  '5F8N': ['RdRP'],
#  '3PKM': ['Cas'],
#  '2C0B': ['S1', 'RNase'],
#  '2ZKO': ['virus'],
#  '1ZL3': ['PseudoU_synth', 'PseudoU_synth', 'PseudoU_synth'],
#  '4ZDPB': ['Selen_transf'],
#  '5DM6': ['KOW',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom'],
#  '4OHZ': ['CLP1_P', 'CLP1', 'CLP1', 'CLP1'],
#  '5M0J': ['She2p'],
#  '4NGC': ['Ago'],
#  '2A1R': ['RNase'],
#  '3CCR': ['KOW',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom'],
#  '1AQ4': ['coat'],
#  '2ERR': ['RRM'],
#  '4DR3': ['Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Thx',
#   'KH'],
#  '4NHA': ['Ago'],
#  '2HYI': ['Cas', 'RRM', 'Ago', 'Btz', 'Helicase', 'Helicase'],
#  '1XNR': ['Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Thx',
#   'KH'],
#  '3BO3B': ['RRM'],
#  '4A93': ['S1',
#   'tRNA_synt',
#   'tRNA_synt',
#   'Transc_F',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'DNA_pol',
#   'SHS2_Rpb7-N',
#   'virus',
#   'virus',
#   'virus',
#   'virus',
#   'virus',
#   'virus',
#   'virus'],
#  '2PXU': ['SRP'],
#  '1SI3': ['Ago'],
#  '1I6U': ['Ribosom'],
#  '2VUM': ['S1',
#   'tRNA_synt',
#   'tRNA_synt',
#   'Transc_F',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'DNA_pol',
#   'SHS2_Rpb7-N',
#   'virus',
#   'virus',
#   'virus',
#   'virus',
#   'virus',
#   'virus',
#   'virus'],
#  '1UVN': ['RdRP'],
#  '4B3G': ['AAA', 'AAA'],
#  '1QFQ': ['N36', 'virus'],
#  '1FXL': ['RRM'],
#  '4YOE': ['RRM'],
#  '3CCJ': ['KOW',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom'],
#  '3CC4': ['KOW',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom'],
#  '4B3S': ['Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Thx',
#   'KH'],
#  '4WJ4': ['tRNA_synt', 'tRNA_synt', 'unknown'],
#  '2ASB': ['KH'],
#  '5XOG': ['S1',
#   'tRNA_synt',
#   'tRNA_synt',
#   'Transc_F',
#   'EF',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'DNA_pol',
#   'SHS2_Rpb7-N',
#   'virus',
#   'virus',
#   'virus',
#   'virus',
#   'virus',
#   'virus',
#   'virus'],
#  '2RQC': ['RRM'],
#  '3OL7': ['RdRP'],
#  '3ICE': ['ATP-synt_ab', 'Rho', 'Rho'],
#  '5BZ1A': ['PUF'],
#  '2LA5': ['FXMRP1_C_core', 'MRP'],
#  '4K4U': ['RdRP'],
#  '3K61': ['PUF'],
#  '2UXD': ['Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Thx',
#   'KH'],
#  '5F6C': ['S1', 'RNase'],
#  '6MSF': ['coat'],
#  '1OLN': ['Ribosom', 'Ribosom'],
#  '2ZH9': ['NUC', 'NTP_transf'],
#  '4PKD': ['RRM', 'spliceosome'],
#  '4QPX': ['RdRP'],
#  '5FMZ': ['virus', 'virus', 'virus'],
#  '5G4U': ['Ribosom'],
#  '1E7K': ['Ribosom'],
#  '2MFG': ['CsrA'],
#  '4K50': ['RdRP'],
#  '5O1Z': ['RRM'],
#  '5EN1': ['RRM'],
#  '2MQQ': ['RRM'],
#  '4W5O': ['Ago', 'Ago', 'Ago', 'Ago', 'Ago', 'Ago'],
#  '5W5I': ['TPR', 'TPR'],
#  '1DRZ': ['RRM'],
#  '1IBL': ['Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Thx',
#   'KH'],
#  '2VNU': ['S1', 'Ribonuclease', 'CSD', 'CSD', 'exonuclease', 'RNase'],
#  '1ZH5': ['RRM', 'La'],
#  '5JVGA': ['KOW',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom'],
#  '1DDL': ['coat'],
#  '1N35': ['RdRP'],
#  '4YYE': ['tRNA_synt', 'tRNA_synt'],
#  '2MFH': ['CsrA'],
#  '2JPP': ['CsrA'],
#  '4PR6B': ['RRM'],
#  '5JCF': ['Cas', 'RIG', 'RIG', 'ResIII', 'Helicase'],
#  '4YHH': ['Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Thx',
#   'KH'],
#  '5DO4': ['Thrombin_light', 'Trypsin'],
#  '2IY5': ['tRNA_synt',
#   'tRNA_synt',
#   'tRNA_synt',
#   'tRNA_synt',
#   'tRNA_synt',
#   'tRNA_synt',
#   'RRM',
#   'tRNA_bind'],
#  '4K4W': ['RdRP'],
#  '2UUA': ['Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Thx',
#   'KH'],
#  '3ZC0A': ['Translin'],
#  '1N8R': ['KOW',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom'],
#  '3HJW': ['PseudoU_synth', 'PseudoU_synth', 'DKCLD', 'Nop', 'Ribosom', 'PUA'],
#  '5BZU': ['PUF'],
#  '2FY1': ['RRM'],
#  '4UYK': ['SRP', 'SRP'],
#  '1QVG': ['KOW',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom'],
#  '3MDG': ['NUDIX_2'],
#  '4K4T': ['RdRP'],
#  '2NZ4': ['RRM'],
#  '1F6U': ['zf'],
#  '1UVI': ['RdRP'],
#  '3VJR': ['Pept_tRNA_hydro'],
#  '1U0B': ['tRNA_synt', 'tRNA_synt'],
#  '4FWT': ['Cas', 'EF', 'EF', 'EF', 'EF'],
#  '1N78': ['tRNA_synt'],
#  '5JC3': ['Cas', 'RIG', 'RIG', 'ResIII', 'Helicase'],
#  '1YVP': ['TROVE'],
#  '2ZH6': ['NUC', 'NTP_transf'],
#  '2MQV': ['zf'],
#  '4ANGB': ['coat'],
#  '1EQQ': ['SSB'],
#  '4PRFA': ['RRM'],
#  '3RER': ['Hfq'],
#  '2N8L': ['KH'],
#  '4TYY': ['Cas', 'Helicase', 'Helicase'],
#  '2C4Z': ['coat'],
#  '2MTV': ['YTH'],
#  '5C9H': ['Ras', 'Telomerase_RBD'],
#  '3K5Q': ['PUF'],
#  '4DR6': ['Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Thx',
#   'KH'],
#  '2CSX': ['tRNA_synt', 'Anticodon_1'],
#  '4PY5': ['RNase'],
#  '4WC3': ['PAP'],
#  '5E3H': ['Cas', 'RIG', 'RIG', 'Helicase', 'Helicase'],
#  '4MDX': ['toxin'],
#  '5XOW': ['Ago', 'Ago'],
#  '4IG8': ['S1', 'OAS1_C', 'NTP_transf'],
#  '1ETF': ['virus'],
#  '4OOG': ['Ribonuclease', 'NUC', 'dsrm', 'RNase'],
#  '6FPX': ['YTH'],
#  '2LEC': ['RRM'],
#  '1VQ6': ['KOW',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom'],
#  '4LMZ': ['RRM'],
#  '4Z4D': ['Ago', 'Ago', 'Ago', 'Ago', 'Ago', 'Ago'],
#  '1AV6': ['PAP', 'La'],
#  '2JQ7': ['Ribosom', 'Ribosom'],
#  '5GJB': ['La', 'Helicase', 'virus'],
#  '1TTT': ['EF', 'EF', 'EF'],
#  '3PF4B': ['CSD'],
#  '2BTE': ['tRNA_synt', 'tRNA_synt', 'tRNA_synt', 'Anticodon_1'],
#  '4W92': ['RRM'],
#  '3NVI': ['Nop', 'Ribosom'],
#  '4XBF': ['Amino_oxidase', 'Myb_DNA-binding', 'SWIRM'],
#  '4DV6B': ['Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Thx',
#   'KH'],
#  '1ZDK': ['coat'],
#  '1VBX': ['RRM'],
#  '5W6V': ['Ago', 'Ago', 'Ago', 'Ago', 'Ago', 'Ago', 'Ago'],
#  '5GMG': ['LRR', 'LRR'],
#  '2DET': ['Methyltr'],
#  '5GXHA': ['WD40', 'WD40'],
#  '4X4VA': ['NUC', 'NTP_transf'],
#  '3AEV': ['S1', 'Transl_IF', 'KH'],
#  '5WTY': ['PUF'],
#  '5WWX': ['KH'],
#  '6EVK': ['virus', 'virus', 'virus'],
#  '4WC2': ['PAP'],
#  '4LJ0': ['zf'],
#  '1RC7': ['Ribonuclease', 'NUC', 'dsrm'],
#  '4A3D': ['S1',
#   'tRNA_synt',
#   'tRNA_synt',
#   'Transc_F',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'DNA_pol',
#   'SHS2_Rpb7-N',
#   'virus',
#   'virus',
#   'virus',
#   'virus',
#   'virus',
#   'virus',
#   'virus'],
#  '1URN': ['RRM'],
#  '2OZB': ['Nop', 'Ribosom'],
#  '2XD0': ['toxin'],
#  '3NMU': ['Nop', 'La', 'Ribosom'],
#  '1T4L': ['dsrm'],
#  '5XH6': ['NUC', 'CRISPR', 'CRISPR'],
#  '3CZ3A': ['virus'],
#  '2PXT': ['SRP'],
#  '4OE1': ['PPR', 'PPR', 'PPR', 'PPR'],
#  '2C50': ['coat'],
#  '3HM9': ['Ago', 'Ago'],
#  '5NRGB': ['KOW',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom'],
#  '3CXC': ['KOW',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom'],
#  '3MOJ': ['Helicase'],
#  '3WBM': ['Alba'],
#  '2PO1': ['RNase', 'RNase'],
#  '3IRW': ['RRM'],
#  '4A3K': ['S1',
#   'tRNA_synt',
#   'tRNA_synt',
#   'Transc_F',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'DNA_pol',
#   'SHS2_Rpb7-N',
#   'virus',
#   'virus',
#   'virus',
#   'virus',
#   'virus',
#   'virus',
#   'virus'],
#  '4X64': ['Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Thx',
#   'KH'],
#  '4BY7': ['S1',
#   'tRNA_synt',
#   'tRNA_synt',
#   'Transc_F',
#   'Transc_F',
#   'SPOC',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'DNA_pol',
#   'SHS2_Rpb7-N',
#   'virus',
#   'virus',
#   'virus',
#   'virus',
#   'virus',
#   'virus',
#   'virus'],
#  '4GKJ': ['Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Thx',
#   'KH'],
#  '2MKN': ['zf'],
#  '3O7V': ['Ago'],
#  '1HR0': ['Transl_IF',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Thx',
#   'KH'],
#  '4LF6': ['Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Thx',
#   'KH'],
#  '4Y52': ['tRNA_synt',
#   'tRNA_synt',
#   'Transc_F',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'DNA_pol',
#   'virus',
#   'virus',
#   'virus',
#   'virus',
#   'virus',
#   'virus',
#   'virus'],
#  '2N3O': ['RRM'],
#  '5DAR': ['Ribosom', 'Ribosom', 'Ribosom', 'Ribosom'],
#  '4X4NB': ['NUC', 'NTP_transf'],
#  '4D26': ['Cas', 'Helicase', 'Helicase'],
#  '5HK0': ['toxin'],
#  '1UN6': ['zf'],
#  '4QEI': ['tRNA_synt', 'tRNA_synt'],
#  '4B3M': ['Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Thx',
#   'KH'],
#  '5IWAB': ['Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Thx',
#   'KH'],
#  '4JGN': ['virus'],
#  '3PEW': ['Cas', 'Helicase', 'Helicase'],
#  '1DK1B': ['Ribosom'],
#  '2BH2': ['TRAM', 'Methyltr'],
#  '5CCXA': ['Methyltr', 'Methyltr'],
#  '4Z4E': ['Ago', 'Ago', 'Ago', 'Ago', 'Ago', 'Ago'],
#  '3S2H': ['tRNA_synt',
#   'tRNA_synt',
#   'Transc_F',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'DNA_pol',
#   'virus',
#   'virus',
#   'virus',
#   'virus',
#   'virus',
#   'virus',
#   'virus'],
#  '4PDB': ['Ribosom'],
#  '3HHN': ['RRM'],
#  '2IZ8': ['coat'],
#  '3I61': ['Cas', 'Helicase', 'Helicase'],
#  '4TZ6': ['Cas', 'Helicase', 'Helicase'],
#  '3A6P': ['Ras', 'Xpo1'],
#  '2JEA': ['RNase', 'RNase'],
#  '1MSW': ['RNA_pol', 'RNA_pol'],
#  '3CD6': ['KOW',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom'],
#  '1MNB': ['virus'],
#  '5WWT': ['Methyltr'],
#  '4CIO': ['RRM'],
#  '4XWW': ['Lactamase', 'Lactamase', 'La', 'RNase'],
#  '2PXL': ['SRP'],
#  '5JS2': ['Ago', 'Ago', 'Ago', 'Ago', 'Ago', 'Ago'],
#  '2PXP': ['SRP'],
#  '1DI2': ['Staufen_C', 'dsrm'],
#  '4DV6A': ['Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Thx',
#   'KH'],
#  '5XUS': ['NUC', 'CRISPR', 'CRISPR'],
#  '2FZ2': ['coat'],
#  '4JVH': ['STAR_dimer', 'KH'],
#  '3SIU': ['Nop', 'Ribosom'],
#  '4Z4I': ['Ago', 'Ago', 'Ago', 'Ago', 'Ago', 'Ago'],
#  '3PF5B': ['CSD'],
#  '5EEY': ['TrpBP'],
#  '4Z31': ['ROQ_II'],
#  '4YVJ': ['Methyltr'],
#  '3NNC': ['RRM'],
#  '5MSF': ['coat'],
#  '3MDI': ['NUDIX_2'],
#  '2HW8': ['Ribosom'],
#  '2E5L': ['Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Thx',
#   'KH'],
#  '1Q7Y': ['KOW',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom'],
#  '1JJ2': ['KOW',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom'],
#  '1GTN': ['TrpBP'],
#  '4ANGA': ['coat'],
#  '2CV0': ['tRNA_synt'],
#  '5UJ2': ['RdRP'],
#  '5AOR': ['Cas', 'Helicase', 'Helicase', 'Helicase', 'Helicase'],
#  '2E9R': ['RdRP'],
#  '3V6Y': ['PUF'],
#  '3OLB': ['RdRP'],
#  '3HOV': ['S1',
#   'tRNA_synt',
#   'tRNA_synt',
#   'Transc_F',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'DNA_pol',
#   'SHS2_Rpb7-N',
#   'virus',
#   'virus',
#   'virus',
#   'virus',
#   'virus',
#   'virus',
#   'virus'],
#  '4TUW': ['SLBP_RNA_bind'],
#  '3IEVB': ['GTPase', 'KH'],
#  '4KTGA': ['virus'],
#  '5F9F': ['Cas', 'RIG', 'RIG', 'Helicase', 'Helicase'],
#  '4DR5A': ['Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Thx',
#   'KH'],
#  '1IVS': ['tRNA_synt', 'tRNA_synt', 'Anticodon_1'],
#  '5JJI': ['ATP-synt_ab', 'Rho', 'Rho'],
#  '5DE8': ['FXMRP1_C_core', 'MRP'],
#  '2I91': ['TROVE'],
#  '5LTAB': ['Cas', 'Helicase', 'Helicase', 'Helicase', 'Helicase'],
#  '4KRF': ['Ago', 'Ago', 'Ago', 'Ago', 'Ago', 'Ago'],
#  '5ZAL': ['Cas',
#   'Ribonuclease',
#   'NUC',
#   'Ago',
#   'ResIII',
#   'Dicer_dimer',
#   'Helicase'],
#  '3WQZ': ['tRNA_synt', 'tRNA_synt', 'tRNA_SAD'],
#  '4WTJ': ['RdRP'],
#  '1IBM': ['Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Thx',
#   'KH'],
#  '3RZD': ['tRNA_synt',
#   'tRNA_synt',
#   'Transc_F',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'DNA_pol',
#   'virus',
#   'virus',
#   'virus',
#   'virus',
#   'virus',
#   'virus',
#   'virus'],
#  '4FXD': ['DNA_pol', 'DNA_pol'],
#  '2YJY': ['PUF'],
#  '1AQ3': ['coat'],
#  '3OVBA': ['NUC', 'NTP_transf'],
#  '3AMT': ['tRNA_synt', 'unknown'],
#  '4M4O': ['Lys'],
#  '1PGL': ['coat', 'virus', 'virus'],
#  '2A8V': ['Rho', 'Rho'],
#  '4JK0': ['virus'],
#  '2ANN': ['KH'],
#  '4R3I': ['YTH'],
#  '4QM6B': ['AAA'],
#  '3T1Y': ['Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Thx',
#   'KH'],
#  '5B43': ['NUC', 'CRISPR', 'CRISPR'],
#  '3BX2': ['PUF'],
#  '3PU1': ['ncap'],
#  '3BO2': ['RRM'],
#  '5IP2': ['NUC', 'ncap'],
#  '1WWG': ['zf'],
#  '2IHX': ['zf'],
#  '4WTD': ['RdRP'],
#  '4ZLR': ['NHL'],
#  '2QEX': ['KOW',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom'],
#  '2RFK': ['PseudoU_synth',
#   'PseudoU_synth',
#   'PseudoU_synth',
#   'DKCLD',
#   'Nop',
#   'PUA'],
#  '4M7D': ['LSM'],
#  '4Z92': ['virus'],
#  '4HOS': ['TPR', 'TPR', 'TPR'],
#  '4HKQ': ['RVT', 'RNase'],
#  '4X4TB': ['NUC', 'NTP_transf'],
#  '4OL8': ['RVT', 'RNase'],
#  '2L5D': ['Ago', 'Ago'],
#  '1DUL': ['SRP'],
#  '3I5Y': ['Cas', 'Helicase', 'Helicase'],
#  '4ZDPA': ['Selen_transf'],
#  '1N33': ['Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Thx',
#   'KH'],
#  '1N32': ['Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Thx',
#   'KH'],
#  '2KG1': ['RRM', 'zf'],
#  '4WRT': ['virus', 'virus', 'virus'],
#  '5XUZ': ['NUC', 'CRISPR', 'CRISPR'],
#  '3L26': ['virus'],
#  '2XPJ': ['coat'],
#  '4X4VB': ['NUC', 'NTP_transf'],
#  '3R1H': ['RRM'],
#  '1O0B': ['tRNA_synt', 'tRNA_synt'],
#  '1N77': ['tRNA_synt'],
#  '4WC7': ['PAP'],
#  '2O5I': ['RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'virus',
#   'virus',
#   'virus',
#   'virus',
#   'virus',
#   'virus'],
#  '3G9YA': ['zf'],
#  '1H38': ['RNA_pol', 'RNA_pol'],
#  '3AVV': ['Cas', 'EF', 'EF', 'EF', 'EF'],
#  '2PXD': ['SRP'],
#  '3NCU': ['RIG'],
#  '4QVD': ['Hfq'],
#  '5FW2': ['Cas', 'Cas', 'Cas', 'CRISPR', 'CRISPR'],
#  '2DEU': ['Methyltr'],
#  '1RGO': ['zf'],
#  '1M5V': ['RRM'],
#  '1S0V': ['RNA_pol', 'RNA_pol'],
#  '3S17': ['tRNA_synt',
#   'tRNA_synt',
#   'Transc_F',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'DNA_pol',
#   'virus',
#   'virus',
#   'virus',
#   'virus',
#   'virus',
#   'virus',
#   'virus'],
#  '4QQB': ['CSD', 'RRM'],
#  '1FJG': ['Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Thx',
#   'KH'],
#  '4W5N': ['Ago', 'Ago', 'Ago', 'Ago', 'Ago', 'Ago'],
#  '4X4R': ['NUC', 'NTP_transf'],
#  '3EPJ': ['IPPT'],
#  '4X4TA': ['NUC', 'NTP_transf'],
#  '5JXS': ['RdRP'],
#  '2CJK': ['RRM'],
#  '3OVA': ['NUC', 'NTP_transf'],
#  '4TUX': ['SLBP_RNA_bind'],
#  '4JVYA': ['STAR_dimer', 'KH'],
#  '4GV9': ['ncap'],
#  '2QKB': ['RNase'],
#  '4TU0': ['Macro'],
#  '4ARI': ['tRNA_synt', 'tRNA_synt', 'Anticodon_1'],
#  '1SJF': ['RRM'],
#  '3G96': ['RRM'],
#  '3B0U': ['Dus'],
#  '1VQL': ['KOW',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom'],
#  '1TFW': ['NUC', 'NTP_transf'],
#  '1NJI': ['KOW',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom'],
#  '3SQW': ['Cas', 'Helicase', 'Helicase'],
#  '5WWR': ['Methyltr'],
#  '2BS1': ['coat'],
#  '1KQ2': ['Hfq'],
#  '4JVYB': ['STAR_dimer', 'KH'],
#  '4RCJ': ['YTH'],
#  '1VQ7': ['KOW',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom'],
#  '4YCP': ['Dus'],
#  '4JI3': ['Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Thx',
#   'KH'],
#  '2PXE': ['SRP'],
#  '1IL2': ['tRNA_synt', 'tRNA_synt', 'unknown'],
#  '1VBY': ['RRM'],
#  '5T8Y': ['HEAT_PBS', 'unknown'],
#  '4LG2': ['virus'],
#  '3S2D': ['tRNA_synt',
#   'tRNA_synt',
#   'Transc_F',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'DNA_pol',
#   'virus',
#   'virus',
#   'virus',
#   'virus',
#   'virus',
#   'virus',
#   'virus'],
#  '2ESE': ['SAM'],
#  '2C06': ['toxin'],
#  '4TYW': ['Cas', 'Helicase', 'Helicase'],
#  '3KLV': ['RdRP'],
#  '2J0S': ['Cas', 'RRM', 'Ago', 'Btz', 'Helicase', 'Helicase'],
#  '3AVT': ['Cas', 'EF', 'EF', 'EF', 'EF'],
#  '2ATW': ['KH'],
#  '3S1Q': ['tRNA_synt',
#   'tRNA_synt',
#   'Transc_F',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'DNA_pol',
#   'virus',
#   'virus',
#   'virus',
#   'virus',
#   'virus',
#   'virus',
#   'virus'],
#  '1FFY': ['tRNA_synt', 'Anticodon_1', 'zf'],
#  '2QK9': ['RNase'],
#  '2DB3': ['Cas', 'Helicase', 'Helicase'],
#  '5OMW': ['tRNA_synt', 'tRNA_synt', 'Anticodon_1'],
#  '3R9W': ['GTPase', 'KH'],
#  '4IQX': ['RdRP'],
#  '4X65': ['Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Thx',
#   'KH'],
#  '2V3C': ['SRP', 'SRP', 'SRP', 'SRP'],
#  '3IEVA': ['GTPase', 'KH'],
#  '2HHH': ['Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Thx',
#   'KH'],
#  '4Z4C': ['Ago', 'Ago', 'Ago', 'Ago', 'Ago', 'Ago'],
#  '3PLA': ['Nop', 'La', 'Ribosom'],
#  '4KRE': ['Ago', 'Ago', 'Ago', 'Ago', 'Ago', 'Ago'],
#  '5ELK': ['zf'],
#  '4ALP': ['CSD'],
#  '5W3V': ['EC_3_5_4'],
#  '1ZDJ': ['coat'],
#  '5AXW': ['Cas', 'Cas', 'Cas', 'Cas', 'CRISPR', 'CRISPR', 'CRISPR'],
#  '4LGT': ['PseudoU_synth', 'Ribosom'],
#  '2XZL': ['AAA', 'AAA', 'unknown', 'Helicase'],
#  '4Z7L': ['Cas', 'Cas'],
#  '2E9Z': ['RdRP'],
#  '2CZJ': ['SmpB'],
#  '5UDZ': ['CSD', 'zf'],
#  '3O6E': ['Ago'],
#  '4J7L': ['exonuclease'],
#  '2IZN': ['coat'],
#  '3R1L': ['RRM'],
#  '5HJZ': ['toxin'],
#  '3UD4': ['RRM'],
#  '2UU9': ['Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Thx',
#   'KH'],
#  '3DH3': ['PseudoU_synth', 'Ribosom'],
#  '3G0H': ['Cas', 'Helicase', 'Helicase'],
#  '1K1G': ['KH'],
#  '2VQE': ['Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Thx',
#   'KH'],
#  '5MJV': ['virus'],
#  '4BWM': ['NUC', 'DNA_pol'],
#  '4FSJ': ['Peptidase'],
#  '5ZAM': ['Cas',
#   'Ribonuclease',
#   'NUC',
#   'Ago',
#   'ResIII',
#   'Dicer_dimer',
#   'Helicase'],
#  '2JLY': ['La', 'Helicase', 'virus'],
#  '4O8J': ['RNA_cyclase', 'RNA_cyclase'],
#  '1OB5': ['EF', 'EF', 'EF'],
#  '2DU4': ['tRNA_synt', 'tRNA_synt'],
#  '4ATO': ['toxin'],
#  '3MQK': ['PseudoU_synth',
#   'PseudoU_synth',
#   'PseudoU_synth',
#   'DKCLD',
#   'Nop',
#   'PUA'],
#  '5T7B': ['Ago', 'Ago', 'Ago', 'Ago', 'Ago', 'Ago'],
#  '1WWF': ['zf'],
#  '3LWP': ['PseudoU_synth', 'PseudoU_synth', 'DKCLD', 'Nop', 'Ribosom', 'PUA'],
#  '5JS1': ['Ago', 'Ago', 'Ago', 'Ago', 'Ago', 'Ago'],
#  '1U6P': ['zf'],
#  '3M7N': ['exosome', 'exosome', 'RNase', 'RNase'],
#  '5D6G': ['Ribosom', 'Ribosom'],
#  '3Q0L': ['PUF'],
#  '4GCW': ['Lactamase', 'La'],
#  '4FTE': ['Peptidase'],
#  '2F8S': ['Ago', 'Ago'],
#  '1YTY': ['RRM', 'La'],
#  '4PR6A': ['RRM'],
#  '1QF6': ['TGS', 'tRNA_synt', 'tRNA_synt', 'tRNA_SAD'],
#  '3UCU': ['RRM'],
#  '1AUD': ['RRM'],
#  '3ADD': ['KTI12'],
#  '1R9F': ['virus'],
#  '3MUR': ['RRM'],
#  '6FQ3': ['actin_cross-linking', 'La', 'NHL'],
#  '3HXM': ['Ago', 'Ago'],
#  '4QM6A': ['AAA'],
#  '2ZH5': ['NUC', 'NTP_transf'],
#  '4ZT9': ['Cas', 'Cas', 'Cas', 'CRISPR', 'CRISPR'],
#  '2R7R': ['RdRP', 'virus'],
#  '5KLA': ['PUF'],
#  '1XNQ': ['Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Thx',
#   'KH'],
#  '5HSW': ['virus'],
#  '1MZP': ['Ribosom'],
#  '4KTGB': ['virus'],
#  '4W5R': ['Ago', 'Ago', 'Ago', 'Ago', 'Ago', 'Ago'],
#  '2GJW': ['tRNA_int_endo', 'tRNA_int_endo'],
#  '4N48': ['Methyltr'],
#  '3DD2': ['Trypsin', '1D-14L'],
#  '1RKJ': ['RRM'],
#  '3AVW': ['Cas', 'EF', 'EF', 'EF', 'EF'],
#  '2MF0': ['CsrA'],
#  '5JB2': ['Cas', 'RIG', 'RIG', 'ResIII', 'Helicase'],
#  '3V7E': ['Ribosom'],
#  '1F7YB': ['Ribosom'],
#  '1H4S': ['tRNA_synt', 'tRNA_synt', 'tRNA_synt'],
#  '4X4O': ['NUC', 'NTP_transf'],
#  '2J0Q': ['Cas', 'RRM', 'Ago', 'Btz', 'Helicase', 'Helicase'],
#  '1FJE': ['RRM'],
#  '5F8I': ['RdRP'],
#  '4JNXB': ['virus'],
#  '5JEA': ['S1',
#   'PIN_4',
#   'Ribonuclease',
#   'Lys',
#   'exosome',
#   'exosome',
#   'exosome',
#   'CSD',
#   'CSD',
#   'exonuclease',
#   'RNase',
#   'RNase',
#   'RNase',
#   'KH'],
#  '2C51': ['coat'],
#  '2DER': ['Methyltr'],
#  '5F8J': ['RdRP'],
#  '1YI2': ['KOW',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom'],
#  '3CUL': ['RRM'],
#  '1SDS': ['Ribosom'],
#  '1NWY': ['KOW',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom'],
#  '1I94': ['Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Thx',
#   'KH'],
#  '6C2P': ['RNA_pol'],
#  '2DU3': ['tRNA_synt', 'tRNA_synt'],
#  '3K4E': ['PUF'],
#  '4YCO': ['Dus'],
#  '5W0M': ['PAP', 'zf', 'NTP_transf'],
#  '3SN2': ['EC_4_2_1', 'EC_4_2_1'],
#  '2OIH': ['RRM'],
#  '4WTI': ['RdRP'],
#  '3ZJT': ['tRNA_synt', 'tRNA_synt', 'Anticodon_1'],
#  '5XC6': ['La', 'Helicase', 'virus'],
#  '2ANR': ['KH'],
#  '2JLZ': ['La', 'Helicase', 'virus'],
#  '5DDQ': ['RRM'],
#  '5JJK': ['ATP-synt_ab', 'Rho', 'Rho'],
#  '5E18': ['Transc_IF',
#   'Transc_IF',
#   'Transc_IF',
#   'Transc_IF',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'virus',
#   'virus',
#   'virus',
#   'virus',
#   'virus',
#   'virus'],
#  '2L2K': ['dsrm'],
#  '3S1R': ['tRNA_synt',
#   'tRNA_synt',
#   'Transc_F',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'DNA_pol',
#   'virus',
#   'virus',
#   'virus',
#   'virus',
#   'virus',
#   'virus',
#   'virus'],
#  '3AVY': ['Cas', 'EF', 'EF', 'EF', 'EF'],
#  '2ZUFA': ['tRNA_synt', 'tRNA_synt', 'tRNA_synt'],
#  '3OIN': ['Methyltr'],
#  '2XLJ': ['Cas'],
#  '4QIK': ['ROQ_II'],
#  '3NMR': ['RRM'],
#  '3UCZ': ['RRM'],
#  '4Q0B': ['RVT', 'RVT', 'RVT', 'RNase'],
#  '4JI7A': ['Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Thx',
#   'KH'],
#  '4X4Q': ['NUC', 'NTP_transf'],
#  '4KJI': ['CsrA'],
#  '4WFB': ['KOW',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom'],
#  '2R7W': ['RdRP', 'virus'],
#  '2UUB': ['Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Thx',
#   'KH'],
#  '1WZ2': ['tRNA_synt', 'Anticodon_1'],
#  '3KMQ': ['RdRP'],
#  '1I6H': ['tRNA_synt',
#   'tRNA_synt',
#   'Transc_F',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'DNA_pol',
#   'virus',
#   'virus',
#   'virus',
#   'virus',
#   'virus',
#   'virus',
#   'virus'],
#  '2Q66': ['PAP', 'PAP', 'NTP_transf'],
#  '5ED1': ['EC_3_5_4'],
#  '5D0A': ['HEAT_PBS', 'unknown'],
#  '5W5H': ['TPR', 'TPR'],
#  '1U6B': ['RRM'],
#  '5AH5': ['tRNA_synt', 'tRNA_synt', 'Anticodon_1'],
#  '2W2H': ['Cyclin', 'virus'],
#  '1QVF': ['KOW',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom'],
#  '3BSB': ['PUF'],
#  '2LI8': ['zf'],
#  '2AD9': ['RRM'],
#  '4A3C': ['S1',
#   'tRNA_synt',
#   'tRNA_synt',
#   'Transc_F',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'DNA_pol',
#   'SHS2_Rpb7-N',
#   'virus',
#   'virus',
#   'virus',
#   'virus',
#   'virus',
#   'virus',
#   'virus'],
#  '4QI2B': ['ROQ_II'],
#  '1KUQB': ['Ribosom'],
#  '4S3N': ['S1', 'OAS1_C'],
#  '2PXB': ['SRP'],
#  '1VQK': ['KOW',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom'],
#  '3G8T': ['RRM'],
#  '4OO8': ['Cas', 'Cas', 'Cas', 'CRISPR', 'CRISPR'],
#  '3HOU': ['S1',
#   'tRNA_synt',
#   'tRNA_synt',
#   'Transc_F',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'DNA_pol',
#   'SHS2_Rpb7-N',
#   'virus',
#   'virus',
#   'virus',
#   'virus',
#   'virus',
#   'virus',
#   'virus'],
#  '7MSF': ['coat'],
#  '5LTAA': ['Cas', 'Helicase', 'Helicase', 'Helicase', 'Helicase'],
#  '4F1N': ['Ago', 'Ago', 'Ago'],
#  '1ZBH': ['SAP', 'RNase'],
#  '4WFA': ['KOW',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom'],
#  '1FEU': ['Ribosom', 'Ribosom'],
#  '5ON2': ['tRNA_synt', 'tRNA_synt', 'Anticodon_1'],
#  '3CF5': ['KOW',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom'],
#  '4ILM': ['Cas', 'Cas', 'CRISPR'],
#  '4HORB': ['TPR', 'TPR', 'TPR'],
#  '3OV7': ['NUC', 'NTP_transf'],
#  '3ZJV': ['tRNA_synt', 'tRNA_synt', 'Anticodon_1'],
#  '5X3Z': ['RRM'],
#  '4WC6': ['PAP'],
#  '5L2LB': ['zf'],
#  '2R7T': ['RdRP', 'virus'],
#  '3K5Z': ['PUF'],
#  '3HSB': ['Hfq'],
#  '2NUGA': ['Ribonuclease', 'NUC', 'dsrm'],
#  '4J5VA': ['virus'],
#  '2BGG': ['Ago'],
#  '1C9S': ['TrpBP'],
#  '3BOY': ['HutP'],
#  '5BR8': ['Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Thx',
#   'KH'],
#  '1K9M': ['KOW',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom'],
#  '4HT9': ['Hfq'],
# ...
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Thx',
#   'KH'],
#  '1BIV': ['virus'],
#  '3LWO': ['PseudoU_synth', 'PseudoU_synth', 'DKCLD', 'Nop', 'Ribosom', 'PUA'],
#  '5EF3': ['TrpBP'],
#  '4WC4': ['PAP'],
#  '4C8Z': ['Cas', 'CRISPR'],
#  '3LWV': ['PseudoU_synth', 'PseudoU_synth', 'DKCLD', 'Nop', 'Ribosom', 'PUA'],
#  '4BHH': ['NUC', 'ncap', 'virus'],
#  '4RWP': ['S1', 'OAS1_C', 'NTP_transf'],
#  '1NWX': ['KOW',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom'],
#  '4BXX': ['S1',
#   'tRNA_synt',
#   'tRNA_synt',
#   'Transc_F',
#   'Transc_F',
#   'SPOC',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'DNA_pol',
#   'SHS2_Rpb7-N',
#   'virus',
#   'virus',
#   'virus',
#   'virus',
#   'virus',
#   'virus',
#   'virus'],
#  '3NNA': ['RRM'],
#  '1OND': ['Ribosom', 'Ribosom'],
#  '2Y8W': ['CRISPR'],
#  '4IO9': ['KOW',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom'],
#  '2NUGB': ['Ribonuclease', 'NUC', 'dsrm'],
#  '3PF5A': ['CSD'],
#  '2FMT': ['Formyl_trans', 'Formyl_trans'],
#  '5T16': ['Ribonuclease', 'NUC', 'dsrm', 'RNase'],
#  '3G71': ['KOW',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom'],
#  '1WWE': ['zf'],
#  '2KM8': ['RRM'],
#  '5HC9': ['PAP', 'PAP'],
#  '4J39B': ['virus'],
#  '5HAB': ['Lactamase', 'Lactamase', 'La'],
#  '5DEA': ['FXMRP1_C_core', 'MRP'],
#  '3O8C': ['Peptidase', 'La', 'Helicase', 'virus'],
#  '3AKZ': ['tRNA_synt'],
#  '3TS0': ['CSD', 'zf'],
#  '1B7F': ['RRM'],
#  '3G6E': ['KOW',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom'],
#  '4UN4': ['Cas', 'Cas', 'Cas', 'CRISPR', 'CRISPR'],
#  '3KOA': ['RdRP'],
#  '3ADI': ['dsrm'],
#  '3U56': ['Ribosom'],
#  '2BX2': ['S1', 'RNase'],
#  '5ELH': ['zf'],
#  '3QJP': ['Cas'],
#  '4OAV': ['Pkinase', 'NUC', 'Ank'],
#  '3CIY': ['LRR', 'LRR', 'LRR'],
#  '3BSX': ['PUF'],
#  '2UUC': ['Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Thx',
#   'KH'],
#  '1HNW': ['Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Thx',
#   'KH'],
#  '3HOY': ['S1',
#   'tRNA_synt',
#   'tRNA_synt',
#   'Transc_F',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'DNA_pol',
#   'SHS2_Rpb7-N',
#   'virus',
#   'virus',
#   'virus',
#   'virus',
#   'virus',
#   'virus',
#   'virus'],
#  '3BSU': ['virus'],
#  '4KR7': ['PseudoU_synth', 'ThiI', 'Methyltr', 'THUMP'],
#  '5WEA': ['Ago', 'Ago', 'Ago', 'Ago', 'Ago', 'Ago'],
#  '5E6M': ['tRNA_synt', 'tRNA_synt', 'tRNA_synt'],
#  '3IE1': ['Cas', 'Lactamase', 'Lactamase', 'La'],
#  '3PIP': ['KOW',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom'],
#  '3AHU': ['Hfq'],
#  '5B2T': ['Cas', 'Cas', 'Cas', 'CRISPR', 'CRISPR'],
#  '1ZJW': ['tRNA_synt', 'tRNA_synt'],
#  '3NNH': ['RRM'],
#  '4C9D': ['Cas', 'CRISPR'],
#  '3HK2': ['Ago', 'Ago'],
#  '3QRP': ['CRISPR'],
#  '1L9A': ['SRP'],
#  '2ZH2': ['NUC', 'NTP_transf'],
#  '3CCM': ['KOW',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom'],
#  '5A0V': ['Lactamase', 'Lactamase', 'La'],
#  '1VC5': ['RRM'],
#  '2GJE': ['MRP'],
#  '4GV3': ['ncap'],
#  '3Q0R': ['PUF'],
#  '1FKA': ['Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom'],
#  '1NB7': ['RdRP'],
#  '1GTS': ['tRNA_synt', 'tRNA_synt'],
#  '2XC7': ['RNA_GG_bind'],
#  '2NUE': ['Ribonuclease', 'NUC', 'dsrm'],
#  '1SER': ['tRNA_synt', 'tRNA_synt'],
#  '2ZZN': ['Methyltr', 'unknown'],
#  '4AM3': ['Nucleotidyltransferase', 'RNase', 'RNase', 'KH'],
#  '4WTM': ['RdRP'],
#  '4F3T': ['Ago', 'Ago', 'Ago', 'Ago', 'Ago', 'Ago'],
#  '1GTF': ['TrpBP'],
#  '3BT7': ['Methyltr'],
#  '1QRT': ['tRNA_synt', 'tRNA_synt'],
#  '3V71': ['PUF'],
#  '3PTX': ['ncap'],
#  '4ZDOA': ['Selen_transf'],
#  '1M8Y': ['PUF'],
#  '3BX3': ['PUF'],
#  '4M59': ['PPR', 'PPR', 'PPR', 'PPR'],
#  '3X1L': ['Cas', 'Cas', 'unknown', 'unknown'],
#  '4JXX': ['tRNA_synt', 'tRNA_synt'],
#  '1QU2': ['tRNA_synt', 'Anticodon_1', 'zf'],
#  '1WSU': ['EF'],
#  '2DR7': ['NUC', 'NTP_transf'],
#  '1J2B': ['tRNA-ribosyltransf',
#   'tRNA-ribosyltransf',
#   'tRNA-ribosyltransf',
#   'PUA'],
#  '2YU9': ['tRNA_synt',
#   'tRNA_synt',
#   'Transc_F',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'DNA_pol',
#   'virus',
#   'virus',
#   'virus',
#   'virus',
#   'virus',
#   'virus',
#   'virus'],
#  '2Y9H': ['CRISPR'],
#  '2MJH': ['KH'],
#  '5WWW': ['KH'],
#  '3K64': ['PUF'],
#  '2DRB': ['NUC', 'NTP_transf'],
#  '4DV7': ['Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Thx',
#   'KH'],
#  '4KNQ': ['virus'],
#  '5HP3': ['EC_3_5_4'],
#  '4C7O': ['SRP', 'SRP'],
#  '3K5Y': ['PUF'],
#  '1R9T': ['tRNA_synt',
#   'tRNA_synt',
#   'Transc_F',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'DNA_pol',
#   'virus',
#   'virus',
#   'virus',
#   'virus',
#   'virus',
#   'virus',
#   'virus'],
#  '5CCBB': ['Methyltr', 'Methyltr'],
#  '3CCU': ['KOW',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom'],
#  '5DET': ['RRM'],
#  '4V2S': ['Hfq'],
#  '2DU6': ['tRNA_synt', 'tRNA_synt'],
#  '2C4Y': ['coat'],
#  '5BYM': ['PUF'],
#  '1ZHO': ['Ribosom'],
#  '5H1K': ['WD40', 'WD40'],
#  '1A1T': ['zf'],
#  '3PIO': ['KOW',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom'],
#  '1UVL': ['RdRP'],
#  '2ZHB': ['NUC', 'NTP_transf'],
#  '4Y7N': ['tRNA_synt',
#   'tRNA_synt',
#   'Transc_F',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'DNA_pol',
#   'virus',
#   'virus',
#   'virus',
#   'virus',
#   'virus',
#   'virus',
#   'virus'],
#  '3E2E': ['RNA_pol', 'RNA_pol'],
#  '1BMV': ['coat', 'virus', 'virus'],
#  '3PO2': ['S1',
#   'tRNA_synt',
#   'tRNA_synt',
#   'Transc_F',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'DNA_pol',
#   'SHS2_Rpb7-N',
#   'virus',
#   'virus',
#   'virus',
#   'virus',
#   'virus',
#   'virus',
#   'virus'],
#  '2VPL': ['Ribosom'],
#  '2PLY': ['EF', 'EF', 'EF'],
#  '1M90': ['KOW',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom'],
#  '4QIL': ['ROQ_II'],
#  '1YJW': ['KOW',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom'],
#  '1QU3': ['tRNA_synt', 'Anticodon_1'],
#  '2AZ0': ['virus'],
#  '2PXQ': ['SRP'],
#  '2NVQ': ['tRNA_synt',
#   'tRNA_synt',
#   'Transc_F',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'DNA_pol',
#   'virus',
#   'virus',
#   'virus',
#   'virus',
#   'virus',
#   'virus',
#   'virus'],
#  '5FQ5': ['Cas', 'Cas', 'Cas', 'CRISPR', 'CRISPR'],
#  '4Z4F': ['Ago', 'Ago', 'Ago', 'Ago', 'Ago', 'Ago'],
#  '484D': ['virus'],
#  '1YJN': ['KOW',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom'],
#  '4YHW': ['unknown'],
#  '2XGJ': ['Cas', 'tRNA_synt', 'Helicase', 'Helicase', 'Helicase', 'Helicase'],
#  '3S16': ['tRNA_synt',
#   'tRNA_synt',
#   'Transc_F',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'RNA_pol',
#   'DNA_pol',
#   'virus',
#   'virus',
#   'virus',
#   'virus',
#   'virus',
#   'virus',
#   'virus'],
#  '1ULL': ['virus'],
#  '4KR2': ['tRNA_synt', 'tRNA_synt'],
#  '3SQX': ['Cas', 'Helicase', 'Helicase'],
#  '5X2G': ['Cas'],
#  '1FFK': ['KOW',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom'],
#  '4KR9': ['PseudoU_synth', 'ThiI', 'Methyltr', 'THUMP'],
#  '2ZI0': ['virus'],
#  '2BQ5': ['coat'],
#  '4BS2': ['RRM'],
#  '2RS2': ['RRM'],
#  '4KHP': ['Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Thx',
#   'KH'],
#  '4WTA': ['RdRP'],
#  '2LEB': ['RRM'],
#  '1VQP': ['KOW',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom'],
#  '4GV6': ['ncap'],
#  '2AZX': ['tRNA_synt'],
#  '5WWS': ['Methyltr'],
#  '5XUU': ['NUC', 'CRISPR', 'CRISPR'],
#  '3VNV': ['Cas', 'EF', 'EF', 'EF', 'EF'],
#  '2ZJQ': ['KOW',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom'],
#  '3ZGZ': ['tRNA_synt', 'tRNA_synt', 'Anticodon_1'],
#  '4OO1': ['exosome',
#   'exosome',
#   'exosome',
#   'DNA_pol',
#   'RNase',
#   'RNase',
#   'RNase',
#   'KH',
#   'Helicase'],
#  '5BUD': ['exonuclease'],
#  '2MZ1': ['RRM'],
#  '1UVJ': ['RdRP'],
#  '3FHT': ['Cas', 'Helicase', 'Helicase'],
#  '4RWO': ['S1', 'OAS1_C', 'NTP_transf'],
#  '1ETG': ['virus'],
#  '1WNE': ['RdRP'],
#  '5ELSA': ['KH', 'Qua1'],
#  '5W0O': ['PAP', 'NTP_transf'],
#  '3CCS': ['KOW',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom',
#   'Ribosom'],
#  '1EUY': ['tRNA_synt', 'tRNA_synt'],
#  '1KOG': ['tRNA_synt', 'tRNA_synt'],
#  '3Q0P': ['PUF'],
#  '2XS2': ['RRM'],
#  '1T0K': ['SBP_bac_1', 'Ribosom'],
#  '4KXT': ['Ago', 'Ago', 'Ago', 'Ago', 'Ago', 'Ago'],
#  ...}

# %% [markdown]
# check family redundancies in AAA

# %%
# select AAA fragments that bind the protein
AAA = fragments[mask_seq["AAA"] & mask_close["any"]]

# %%
count_AAA_per_pdb = dict(zip(*np.unique(AAA["structure"], return_counts = True)))

# %%
count_AAA_per_pfam = count_pdb_to_fam(count_AAA_per_pdb, pdb_pfam)
count_AAA_per_fam = count_pdb_to_fam(count_AAA_per_pdb, pdb_fam)
count_AAA_per_group = count_fam_to_group(count_AAA_per_fam)

# %%
count_AAA_per_group

# %%
inv_count_AAA_per_group = inv_dict(count_AAA_per_group)
inv_count_AAA_per_group

# %%
GGG = fragments[mask_seq["GGG"] & mask_close["any"]]
count_GGG_per_pdb = dict(zip(*np.unique(GGG["structure"], return_counts = True)))
count_GGG_per_fam = count_pdb_to_fam(count_GGG_per_pdb, pdb_fam)
count_GGG_per_group = count_fam_to_group(count_GGG_per_fam)
inv_count_GGG_per_group = inv_dict(count_GGG_per_group)

# %%
inv_count_GGG_per_group

# %% [markdown]
# Do the stats change if we remove Ribosomal complexes?

# %%
nn = np.array(group_pdb['Ribosom'])
len(nn)

# %%
fragments["structure"]

# %%
mask_noRib = np.isin(fragments["structure"], group_pdb['Ribosom'], invert = True)
mask_Rib = np.isin(fragments["structure"], group_pdb['Ribosom'])

# %%
print(sum(mask_noRib))
print(sum(mask_Rib))
392112/(392112+91006)

# %%
AAA_noRib = fragments[mask_seq["AAA"] & mask_noRib ]
AAA_Rib = fragments[mask_seq["AAA"] & mask_Rib]
GGG_noRib = fragments[mask_seq["GGG"] & mask_noRib]
GGG_Rib = fragments[mask_seq["GGG"] & mask_Rib]

# %%
print(len(fragments[mask_seq["GGG"] & mask_Rib & mask_state['ds']]))
print(len(fragments[mask_seq["GGG"] & mask_noRib & mask_state['ds']]))

# %%
for i in [AAA_noRib, AAA_Rib, GGG_noRib, GGG_Rib]:
    print(len(i))

# %%
def count_mask(new_mask):
    new_count = {}
    for part in parts:
        if new_mask is None:
            mask0 = mask_close[part]
        else:
            mask0 = new_mask & mask_close[part]
        for state in states:
            mask1 = mask0 & mask_state[state]
            for seq in seqs:
                mask2 = mask1 & mask_seq[seq]
                new_count[seq, state, part] = mask2.sum()
    return new_count

# %%
count_noRib = count_mask(mask_noRib)

# %%
count_all = counts
np.isin(fragments["structure"], pfam_pdb[pfam])

# %%
mask_all = np.isin(fragments["seq"], seqs)

# %%
print(count_noRib["AAA", 'ds', 'base'])
print(counts["AAA", 'ds', 'base'])

# %%
d_noRib_AAA = count_seqs(count_noRib, ["AAA"])[0]
d_noRib_GGG = count_seqs(count_noRib, ["GGG"])[0]
d_AAA = count_seqs(counts, ["AAA"])[0]
d_GGG = count_seqs(counts, ["GGG"])[0]

# %%
fisher_counts(d_02A_AAA, d_02A_GGG, "nonspecif")

# %%
fisher_counts(d_02A_AAA, d_02A_GGG, "base")

# %%
d_02A_AAA['any']

# %%
d_noRib_GGG['any']

# %%
fisher_counts(d_02A_AAA, d_02A_GGG, "specif")

# %%
print(0.8947 * 76)
print(0.70065 * 922)
print(0.5086 * 1111)
print(0.8766 * 235)

# %%
tt = [[276, 922-276],[29,235-29]]
fisher_exact(tt)

# %%
fisher_counts(d_noRib_AAA, d_noRib_GGG, "nonspecif")

# %%
print(0.9015 * 76)
print(0.96795 * 235)
print(0.67 * 1111)
print(0.8527 * 922)

# %%
print(0.9015 * 71)
print(0.96795 * 156)
print(0.67 * 315)
print(0.8527 * 509)

# %%
tt = [[64, 71-64],[434,509-434]]
fisher_exact(tt)

# %% [markdown]
# # Question 2
# For single-stranded fragments with a protein-bound middle residue,
#  how many stacking interactions does it make with neighboring bases?

# %%
ph = mask_veryclose["ph"]
base = mask_veryclose["base"]
sug = mask_veryclose["sug"]
nonspecif = mask_veryclose["nonspecif"]
any = mask_veryclose["any"]

# %%
# mask on frag_ss with central base stacking with base n-1 / n+1 / not neighbor
ss_stackprev = query(chaindata, chainschema, fragments, 0, "stacking", pos="n-1")
ss_stacknext = query(chaindata, chainschema, fragments, 0, "stacking", pos="n+1")
ss_stackother = query(chaindata, chainschema, fragments, 0, "stacking", pos="other")

# %%
stackprev = ss_stackprev[:,1]
stacknext = ss_stacknext[:,1]
stackother = ss_stackother[:,1]
nostack = ~stackprev & ~stacknext & ~stackother

# %%
sum(any & ~base & ss & stackother)

# %%
sum(sug & ss & stackother & (stackprev|stacknext))

# %%
sum(any & ss)

# %%
def pp(part, name, value, tot):
    print(part, name, value, round(100 * float(value)/tot))

for part in parts:
    m = mask_veryclose[part] & mask_state['ss']
    tot = sum(m)
    print(tot)
    pp(part, "none", sum(m&~(stackprev|stacknext|stackother)), tot)
    pp(part, "any_neighbor", sum(m&(stackprev|stacknext)), tot)
    pp(part, "both_neighbor", sum(m&(stackprev&stacknext)), tot)
    pp(part, "other", sum(m&stackother), tot)

# %%
a1 = sum(any & mask_state['ss'] & (stackprev|stacknext|stackother))
b1 = sum(any & mask_state['ss'] & ~(stackprev|stacknext|stackother))
a2 = sum(base & mask_state['ss'] & (stackprev|stacknext|stackother))
b2 = sum(base & mask_state['ss'] & ~(stackprev|stacknext|stackother))
table = [[a1, b1],  [a2, b2]]
fisher_exact(table)

# %%
def pval(tot1, n1, tot2, n2):
    table = [[n1, tot1-n1], [n2, tot2-n2]]
    r, p = fisher_exact(table)
    return p
    
count_seq_nostacking = {}
mask_ss = mask_state['ss']
mask_base = mask_veryclose["base"]
mask_phsug = mask_veryclose["nonspecif"]
for seq in seqs:
    m_base = mask_base & mask_seq[seq]
    m_phsug = mask_phsug &  mask_seq[seq]
    tot_base = sum(m_base)
    tot_phsug = sum(m_phsug)
    nostack_base = sum(nostack & m_base)
    nostack_phsug = sum(nostack & m_phsug)
    p_base = round( 100 * nostack_base/tot_base)
    p_phsug = round( 100 * nostack_phsug/tot_phsug)
    p = pval(tot_base, nostack_base, tot_phsug, nostack_phsug)
    count_seq_nostacking[seq] = [p_base, p_phsug, p]

# %%
count_seq_nostacking["AAA"]

# %%
signif = [k for k in seqs if count_seq_nostacking[k][2]< 0.001]
not_signif = [k for k in seqs if count_seq_nostacking[k][2] > 0.001]

# %%
signif

# %%
mask_phsug = mask_nonspecif

# %%
count_motif_nostacking = {}
for m in motifs:
    m_base = mask_base & mask_motif[m]
    m_phsug = mask_phsug &  mask_motif[m]
    tot_base = sum(m_base)
    tot_phsug = sum(m_phsug)
    nostack_base = sum(nostack & m_base)
    nostack_phsug = sum(nostack & m_phsug)
    p_base = round( 100 * nostack_base/tot_base)
    p_phsug = round( 100 * nostack_phsug/tot_phsug)
    p = pval(tot_base, nostack_base, tot_phsug, nostack_phsug)
    count_motif_nostacking[m] = [p_base, p_phsug, p]

# %%
signif = [k for k in motifs if count_motif_nostacking[k][2]< 0.001]
not_signif = [k for k in motifs if count_motif_nostacking[k][2] > 0.001]

# %%
signif

# %%
not_signif

# %% [markdown]
# # Question 3
# Does the original sequence have an influence on the structure of the mutated fragment?
# => do the frag with same original sequence cluster together?

# %%
def frag2dict(f):
    return {field:f[field] for field in fragments.dtype.fields}

# %%
frag2dict(fragments[1])
# Out:
# {'chain': b'0',
#  'clust0.2': 2247,
#  'clust0.2_center': False,
#  'clust1.0': 1,
#  'clust1.0_center': False,
#  'clust2.0': 1,
#  'clust2.0_center': False,
#  'frag': 17170,
#  'indices': array([2413, 2414, 2415], dtype=uint32),
#  'missing_atoms': array([0, 0, 0], dtype=uint8),
#  'model': 1,
#  'motif': b'AAA',
#  'resid': array([b'2522', b'2523', b'2524'], dtype='|S5'),
#  'seq': b'GGG',
#  'structure': b'1OND'}

# %%
# sequences belonging to each motif
motif_seq = {}
for m in motifs:
    seq = [f["seq"].decode() for f in fragments[mask_motif[m]]]
    sequ = list(set(seq))
    motif_seq[m] = sequ
motif_seq
# Out:
# {'AAA': ['AGG', 'GAA', 'AAG', 'AAA', 'GGA', 'GAG', 'AGA', 'GGG'],
#  'AAC': ['GGU', 'AAC', 'GGC', 'GAC', 'GAU', 'AAU', 'AGC', 'AGU'],
#  'ACA': ['ACG', 'GUG', 'GUA', 'GCA', 'GCG', 'AUG', 'ACA', 'AUA'],
#  'ACC': ['ACC', 'ACU', 'AUU', 'GUC', 'GCC', 'GUU', 'GCU', 'AUC'],
#  'CAA': ['CGG', 'UGG', 'UAA', 'CAG', 'UAG', 'CAA', 'CGA', 'UGA'],
#  'CAC': ['UAU', 'CGU', 'UGC', 'CAC', 'CGC', 'UGU', 'UAC', 'CAU'],
#  'CCA': ['CUA', 'CCA', 'UCA', 'CCG', 'UUG', 'UUA', 'UCG', 'CUG'],
#  'CCC': ['CCC', 'CUC', 'CCU', 'UCC', 'UCU', 'UUU', 'CUU', 'UUC']}

# %%
motifs
# Out:
# ['AAA', 'AAC', 'ACA', 'ACC', 'CAA', 'CAC', 'CCA', 'CCC']

# %%
# Number of clusters per motif
motif_Nclust1 = {}
for motif in motifs:
    clust1 = [f["clust1.0"] for f in fragments[mask_motif[motif]]]
    clust1u = len(np.unique(clust1))
    motif_Nclust1[motif] = clust1u
motif_Nclust1
# Out:
# {'AAA': 4670,
#  'AAC': 3369,
#  'ACA': 3120,
#  'ACC': 2565,
#  'CAA': 3511,
#  'CAC': 2433,
#  'CCA': 2821,
#  'CCC': 3091}

# %%
# Number of frag of each sequences in each cluster
count_clust_seq = {}
for m in motifs:
    count_clust_seq[m] = {}
    frag_motif = fragments[mask_motif[m]]
    for clust1 in range(motif_Nclust1[m]):
        count_clust_seq[m][str(clust1)] = {}
        frag_clust = frag_motif[(frag_motif["clust1.0"] == clust1)]
        for seq in motif_seq[m]:
            n = (frag_clust["seq"] == seq.encode()).sum()
            count_clust_seq[m][str(clust1)][seq] = n
#            
# Number of sequences in each cluster
count_clust_seq_nonzero = {}
for m in motifs:
    count_clust_seq_nonzero[m] = {}
    d = count_clust_seq[m]
    for clust in d:
        count_clust_seq_nonzero[m][clust] = len([s for s in d[clust] if d[clust][s] > 0])

# %%
# Nomber of clusters containing 1, 2 .. 8 sequences
count_Nclust_per_Nseq = {}
for seq in count_clust_seq_nonzero:
    count_Nclust_per_Nseq[seq] = {}
    for i in range(1,9):
        count_Nclust_per_Nseq[seq][i] = 0
    for k in count_clust_seq_nonzero[seq]:
        l = count_clust_seq_nonzero[seq][k]
        count_Nclust_per_Nseq[seq][l] += 1
count_Nclust_per_Nseq
# Out:
# {'AAA': {1: 4321, 2: 210, 3: 73, 4: 25, 5: 19, 6: 8, 7: 9, 8: 5},
#  'AAC': {1: 3081, 2: 170, 3: 65, 4: 22, 5: 19, 6: 3, 7: 3, 8: 6},
#  'ACA': {1: 2886, 2: 147, 3: 39, 4: 21, 5: 12, 6: 6, 7: 4, 8: 5},
#  'ACC': {1: 2328, 2: 143, 3: 48, 4: 24, 5: 7, 6: 4, 7: 7, 8: 4},
#  'CAA': {1: 3194, 2: 206, 3: 53, 4: 21, 5: 20, 6: 6, 7: 4, 8: 7},
#  'CAC': {1: 2242, 2: 115, 3: 43, 4: 16, 5: 8, 6: 2, 7: 4, 8: 3},
#  'CCA': {1: 2599, 2: 135, 3: 46, 4: 16, 5: 11, 6: 5, 7: 4, 8: 5},
#  'CCC': {1: 2865, 2: 127, 3: 51, 4: 23, 5: 8, 6: 4, 7: 5, 8: 8}}

# %%
#frequence of each sequence in the non-redundant fragments of each motif
frag_freq_per_seq = {}
for m in motifs:
    N_motif = sum(mask_motif[m]) 
    frag_freq_per_seq[m] = {}
    for seq in motif_seq[m]:
        g = mask_seq[seq]
        freq = float((mask_seq[seq] & mask_motif[m]).sum()) / N_motif
        frag_freq_per_seq[m][seq] = freq

# %%
# assign cluster size to each fragment
motif_names, motif_indices = np.unique(fragments["motif"], return_inverse=True)
cluster_indices = fragments["clust1.0"] + 100000 * motif_indices
clust_ids0, clust_sizes0 = np.unique(cluster_indices, return_counts=True)

ordered_clust_sizes = np.zeros(max(clust_ids0)+1, dtype=int)
ordered_clust_sizes[clust_ids0] = clust_sizes0
frag_clust_size = ordered_clust_sizes[cluster_indices]

# %% [markdown]
# Compare frequence of a seq in all fragments to frequence in singleton clusters => does that sequence have a larger conformatinoal diversity than other sequence in the same motif?

# %%
#frequence of each sequence in the singletons
mask_clust_size_1 = (frag_clust_size == 1)
single_freq = {}
for motif in motifs:
    single_freq[motif] = {}
    N_single = float((mask_motif[motif] & mask_clust_size_1).sum())
    assert N_single > 0, motif
    for seq in motif_seq[motif]:
        single_freq[motif][seq] = (mask_seq[seq] & mask_clust_size_1).sum() / N_single

# %%
print(frag_freq_per_seq["AAA"]["AAA"])
print(single_freq["AAA"]["AAA"])
# Out:
# 0.13901852637533588
# 0.14418721690991446

# %%
print(frag_freq_per_seq["AAA"]["GGG"])
print(single_freq["AAA"]["GGG"])
# Out:
# 0.10210719841606562
# 0.08958228485153498

# %%
print(frag_freq_per_seq["CCC"]["CCC"])
print(single_freq["CCC"]["CCC"])
# Out:
# 0.10083493898522801
# 0.0737913486005089

# %%
print(frag_freq_per_seq["CCC"]["UUU"])
print(single_freq["CCC"]["UUU"])
# Out:
# 0.21815457075572683
# 0.2529989094874591

# %% [markdown]
# Compare frequence of a seq in all fragments to average frequence in clusters of a given size (> 8*5 = 40)
# => does that sequence have a tendency to cluster together ?

# %%
fragments[0]["clust1.0"]
(fragments["clust1.0"] == 92).sum()
frags = fragments[(fragments["clust1.0"] == 92)]
frags
# Out:
# array([(b'AAA', 66603, b'484D', 17, b'B', [b'10', b'11', b'12'], [  10,   11,   12], [0, 0, 0], b'GAG',  8511,  True, 92,  True, 1, False),
#        (b'ACA',  2885, b'1I94',  1, b'A', [b'1208', b'1209', b'1210'], [1207, 1208, 1209], [0, 0, 0], b'ACA',  8021,  True, 92,  True, 1, False),
#        (b'ACA', 51120, b'4JI7B',  1, b'A', [b'1227', b'1228', b'1229'], [1201, 1202, 1203], [0, 0, 0], b'ACA', 12744, False, 92, False, 1, False),
#        (b'ACA', 50926, b'4JI7A',  1, b'A', [b'1227', b'1228', b'1229'], [1201, 1202, 1203], [0, 0, 0], b'ACA', 12744,  True, 92, False, 1, False),
#        (b'CCC', 32925, b'3ICE',  1, b'G', [b'4', b'5', b'6'], [   4,    5,    6], [0, 0, 0], b'UUU',  6453,  True, 92,  True, 1, False),
#        (b'ACC',  4886, b'1K01',  1, b'A', [b'2750', b'2751', b'2752'], [2650, 2651, 2652], [0, 0, 0], b'GCC', 10311, False, 92, False, 1, False),
#        (b'ACC', 22564, b'2D3O',  1, b'0', [b'2290', b'2291', b'2292'], [2215, 2216, 2217], [0, 0, 0], b'AUC', 10966,  True, 92, False, 1, False),
#        (b'ACC', 27200, b'2UU9',  1, b'A', [b'794', b'795', b'796'], [ 773,  774,  775], [0, 0, 0], b'ACC', 11204,  True, 92, False, 1, False),
#        (b'ACC', 43367, b'4ILM',  1, b'K', [b'1', b'2', b'3'], [   1,    2,    3], [0, 1, 0], b'GCU', 12091,  True, 92, False, 1, False),
#        (b'ACC', 51208, b'5IWAB',  1, b'A', [b'794', b'795', b'796'], [ 777,  778,  779], [0, 0, 0], b'ACC', 12710,  True, 92, False, 1, False),
#        (b'ACC', 18855, b'1Y69',  1, b'0', [b'1110', b'1111', b'1112'], [1035, 1036, 1037], [0, 0, 0], b'GCU', 10827,  True, 92, False, 1, False),
#        (b'ACC', 41769, b'4DR5A',  1, b'A', [b'794', b'795', b'796'], [ 771,  772,  773], [0, 0, 0], b'ACC', 12004,  True, 92, False, 1, False),
#        (b'ACC', 25135, b'2MQV',  1, b'B', [b'143', b'144', b'145'], [  51,   52,   53], [0, 0, 0], b'AUU', 11083,  True, 92,  True, 1, False),
#        (b'ACC', 25989, b'2OGM',  1, b'0', [b'2750', b'2751', b'2752'], [2642, 2643, 2644], [0, 0, 0], b'GCC', 11155,  True, 92, False, 1, False),
#        (b'ACC', 51047, b'5IWAA',  1, b'A', [b'794', b'795', b'796'], [ 777,  778,  779], [0, 0, 0], b'ACC', 12700,  True, 92, False, 1, False),
#        (b'ACC', 44095, b'4JI0A',  1, b'A', [b'794', b'795', b'796'], [ 771,  772,  773], [0, 0, 0], b'ACC', 12164,  True, 92, False, 1, False),
#        (b'ACC', 41928, b'4DR5B',  1, b'A', [b'794', b'795', b'796'], [ 771,  772,  773], [0, 0, 0], b'ACC', 12004, False, 92, False, 1, False),
#        (b'ACC', 27080, b'2R7V',  1, b'X', [b'1102', b'1103', b'1104'], [   1,    2,    3], [0, 1, 0], b'GCU', 11189,  True, 92, False, 1, False),
#        (b'ACC', 44252, b'4JI0B',  1, b'A', [b'794', b'795', b'796'], [ 771,  772,  773], [0, 0, 0], b'ACC', 12164, False, 92, False, 1, False),
#        (b'ACC', 45790, b'4KR7',  1, b'X', [b'36', b'37', b'38'], [  36,   37,   38], [0, 0, 0], b'ACC', 12300,  True, 92, False, 1, False),
#        (b'CAC', 43534, b'5DM7',  1, b'X', [b'432', b'433', b'434'], [ 354,  355,  356], [0, 0, 0], b'CGC',  8768,  True, 92,  True, 1, False),
#        (b'AAC', 61262, b'4WFB',  1, b'X', [b'1527', b'1528', b'1529'], [1453, 1454, 1455], [0, 0, 0], b'AGU',  9824,  True, 92,  True, 1, False),
#        (b'CAA', 62925, b'5DM7',  1, b'X', [b'2105', b'2106', b'2107'], [2008, 2009, 2010], [0, 0, 0], b'UGG',  9708,  True, 92,  True, 1, False),
#        (b'CCA', 47013, b'4WFA',  1, b'X', [b'1096', b'1097', b'1098'], [1075, 1076, 1077], [0, 0, 0], b'CUA', 13984,  True, 92,  True, 1, False)],
#       dtype=[('motif', 'S3'), ('frag', '<u4'), ('structure', 'S5'), ('model', '<u2'), ('chain', 'S1'), ('resid', 'S5', (3,)), ('indices', '<u4', (3,)), ('missing_atoms', 'u1', (3,)), ('seq', 'S3'), ('clust0.2', '<u2'), ('clust0.2_center', '?'), ('clust1.0', '<u2'), ('clust1.0_center', '?'), ('clust2.0', '<u2'), ('clust2.0_center', '?')])

# %%
# assign cluster size to each fragment, per motif
frag_clust_size = {}
clust_sizes = {}
clust_ids = {}
for motif in motifs:
    frags = fragments[mask_motif[motif]]
    cluster_indices = frags["clust1.0"]
    clust_ids[motif], clust_sizes[motif] = np.unique(cluster_indices, return_counts=True)
    #ordered_clust_sizes = np.zeros(max(clust_ids[motif])+1, dtype=int)
    #ordered_clust_sizes[clust_ids[motif]] = clust_sizes[motif]
    #frag_clust_size[motif] = ordered_clust_sizes[cluster_indices]

# %%
#occurences of each sequence in the non-redundant fragments of each motif
n_seq = {}
for motif in motifs:
    for seq in motif_seq[motif]:
        n_seq[seq] = mask_seq[seq].sum()

# %%
# Occurences of each motif
n_motif = {}
for m in motifs:
    n_motif[m] = mask_motif[m].sum()

# %%
# Indices of clusters of size >= x, per motif
bigclust = {}
bigclust["40"] = {m:list(clust_ids[m][clust_sizes[m] >= 40]) for m in motifs}
bigclust["30"] = {m:list(clust_ids[m][clust_sizes[m] >= 30]) for m in motifs}
bigclust["10"] = {m:list(clust_ids[m][clust_sizes[m] >= 10]) for m in motifs}

# %%
sum([len(bigclust["10"][m]) for m in motifs])
# Out:
# 205

# %%
[sum((fragments["clust1.0"] == i) & mask_motif["AAA"]) for i in bigclust["30"]["AAA"][:10] ]
# Out:
# [270, 58, 69, 46, 33, 53, 31, 46, 31, 44]

# %%
# occurences of each sequence in each cluster of size >= x
t = {}
freq_obs = {}
#for m in motifs:
for m in motifs:
    freq_obs[m] = {}
    t[m] = {}
    for i in bigclust["10"][m]:
        freq_obs[m][i] = {}
        mask0 = (fragments["clust1.0"] == i) & mask_motif[m]
        t[m][i] = mask0.sum()
        #print("***************************", i)
        #print(m, t[m][i])
        for s in motif_seq[m]:
            mask1 = mask0 & (fragments["seq"] == s.encode())
            freq_obs[m][i][s] = mask1.sum()
            #print(s, sum(mask1))

# %%
# Nb "fails" in non-redundant frag of each motif for each seq
n_nonseq = {}
freq_e = {}
for m in motifs:
    seqs = motif_seq[m]
    for s in seqs:
        n_nonseq[s] = n_motif[m] - n_seq[s]
        freq_e[s] = int(round(100 * n_seq[s] / float(n_motif[m])))

# %%
# enrichment of each cluster in each sequence, with p-value
clusters_enrichment = {}
for m in motifs:
    clusters_enrichment[m] = {}
    print("   motif %s"%m)
    for i in bigclust["10"][m]:
        seqs = motif_seq[m]
        clusters_enrichment[m][i] = {}
        for s in seqs:
            nc_seq = freq_obs[m][i][s]
            nc_nonseq = t[m][i] - freq_obs[m][i][s]
            freq_o = float(freq_obs[m][i][s]) / t[m][i]
            table = [[n_seq[s], n_nonseq[s]], [nc_seq, nc_nonseq]]
            f, p = fisher_exact(table)
            clusters_enrichment[m][i][s] = [freq_o, p]
            #if p < 0.05:
            #    print("%s, clust %.3f%%, tot %i%%, p-val %.3f"%(s, freq_o, freq_e[s] , p))
# Out:
#    motif AAA
#    motif AAC
#    motif ACA
#    motif ACC
#    motif CAA
#    motif CAC
#    motif CCA
#    motif CCC

# %%
m = "CCC"
[[s, clusters_enrichment[m][i][s]] for s in motif_seq[m]]
# Out:
# [['CCC', [0.0, 0.6163090680180277]],
#  ['CUC', [0.09090909090909091, 1.0]],
#  ['CCU', [0.0, 0.6150481595141855]],
#  ['UCC', [0.0, 0.6291084910594509]],
#  ['UCU', [0.2727272727272727, 0.08969827290518134]],
#  ['UUU', [0.45454545454545453, 0.07046783451873184]],
#  ['CUU', [0.18181818181818182, 0.3388614715042333]],
#  ['UUC', [0.0, 0.3789357447696692]]]

# %%
#Nb of cluster significantly enriched in only x sequences
x = 0
tot = 0
for m in motifs:
    nc = 0
    e_list = []
    for i in bigclust["10"][m]:
        ne = 0
        for s in motif_seq[m]:
            f, p = clusters_enrichment[m][i][s]
            if p < 0.05 and freq_e[s] < 100 * f: 
                ne +=1
                e_list.append(s)
        if ne == x:
            nc += 1
    tot +=nc
    #print(m, nc, set(e_list), len(clust_sizes40[m]))
    print(m, nc, len(bigclust["10"][m]))    
print(tot)
# Out:
# AAA 9 40
# AAC 7 27
# ACA 3 22
# ACC 4 21
# CAA 6 32
# CAC 6 16
# CCA 10 24
# CCC 8 23
# 53

# %%
#Nb of clusters that do contain the original sequence A/C-A/C-A/C
for m in motifs:
    n_clust_no_seq = 0
    for i in bigclust["10"][m]:
        if freq_obs[m][i][m] > 0: 
            n_clust_no_seq +=1
    print(m, n_clust_no_seq, len(bigclust["10"][m]))
# Out:
# AAA 57 138
# AAC 46 114
# ACA 37 97
# ACC 31 70
# CAA 55 146
# CAC 27 70
# CCA 35 74
# CCC 28 59

# %%
#Nb of clusters that contain x ori sequence
x = 0
for m in motifs:
    nc = 0
    for i in bigclust["10"][m]:
        ns = 0
        s_list = []
        for s in motif_seq[m]:
            if freq_obs[m][i][s] > 0: 
                ns +=1
                s_list.append(s)
        if ns == x:
            nc += 1
            print(m, nc, s_list, len(clust_sizes40[m]))

# %%
#Nb of clusters with x sequences, for x in [1,8], for each motif
tot = 0
clustid_nseq = {}
for m in motifs:
    clustid_nseq[m] = {}
    n_x = {}
    for x in range(1,9):
        clustid_nseq[m][x] = []
        n_x[x] = 0
        for i in bigclust["10"][m]:
            ns = 0
            for s in motif_seq[m]:
                if freq_obs[m][i][s] > 0: 
                    ns +=1
            if ns == x:
                n_x[x] += 1
                clustid_nseq[m][x].append(i)
        tot += n_x[x]
    print(m, n_x)
print(tot)
# Out:
# AAA {1: 0, 2: 0, 3: 8, 4: 5, 5: 6, 6: 7, 7: 9, 8: 5}
# AAC {1: 0, 2: 0, 3: 4, 4: 1, 5: 11, 6: 3, 7: 2, 8: 6}
# ACA {1: 0, 2: 1, 3: 1, 4: 4, 5: 4, 6: 3, 7: 4, 8: 5}
# ACC {1: 0, 2: 0, 3: 2, 4: 4, 5: 1, 6: 3, 7: 7, 8: 4}
# CAA {1: 1, 2: 0, 3: 3, 4: 2, 5: 11, 6: 4, 7: 4, 8: 7}
# CAC {1: 0, 2: 0, 3: 2, 4: 3, 5: 2, 6: 2, 7: 4, 8: 3}
# CCA {1: 0, 2: 1, 3: 0, 4: 3, 5: 7, 6: 4, 7: 4, 8: 5}
# CCC {1: 0, 2: 0, 3: 2, 4: 4, 5: 2, 6: 2, 7: 5, 8: 8}
# 205

# %%
clustid_nseq["ACA"][2]
# Out:
# [229]

# %%
m="ACA"
clustidpur = clustid_nseq[m][2]
mask_clustpur = mask_motif[m] & (fragments["clust1.0"] == clustidpur)
fragpur = fragments[mask_clustpur]
print(len(fragpur))
struc = fragpur["structure"]
chain = fragpur["chain"]
for i in range(len(chain)):
    print(struc[i].decode(), chain[i].decode())
pfam = [chaindata[s.decode()]["pfam"] for s in struc]
#pfam
# Out:
# 12
# 5NRGA X
# 1HNZ A
# 5DDP B
# 1FJE A
# 2XD0 I
# 2HGH B
# 1K01 A
# 4ATO G
# 1JBS D
# 2AAR 0
# 4LCK F
# 3CCJ 0

# %%
for f in fragpur:
    print(f["structure"], [int(k) for k in f["resid"]])
# Out:
# b'5NRGA' [904, 905, 906]
# b'1HNZ' [890, 891, 892]
# b'5DDP' [26, 27, 28]
# b'1FJE' [16, 17, 18]
# b'2XD0' [21, 22, 23]
# b'2HGH' [26, 27, 28]
# b'1K01' [469, 470, 471]
# b'4ATO' [23, 24, 25]
# b'1JBS' [10, 11, 12]
# b'2AAR' [1279, 1280, 1281]
# b'4LCK' [20, 21, 22]
# b'3CCJ' [464, 465, 466]

# %%
fragpur["clust2.0"]
# Out:
# array([12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12], dtype=uint16)

# %%
frag2A = mask_motif[m] & (fragments["clust2.0"] == 12 )

# %%
frag2A.sum()
# Out:
# 50

# %%
frag2A.sum()
frags = fragments[frag2A]
print(frags["seq"])
# Out:
# [b'GUA' b'GUA' b'ACA' b'GCA' b'GUA' b'GUA' b'GUA' b'GCG' b'AUA' b'GUG'
#  b'GUA' b'GUA' b'GUA' b'AUA' b'GUA' b'GUA' b'GCG' b'GUA' b'GUG' b'ACA'
#  b'GUA' b'GUA' b'GUG' b'GCG' b'GUA' b'GUG' b'AUA' b'GUA' b'GUA' b'GUA'
#  b'GUA' b'GUA' b'ACG' b'GUA' b'GUA' b'GCA' b'GUA' b'GUA' b'GUA' b'AUA'
#  b'GUA' b'GUA' b'GUA' b'AUA' b'GUA' b'GCG' b'GUA' b'AUA' b'GUA' b'GUA']

# %%
np.unique(frags["seq"], return_counts=True)
# Out:
# (array([b'ACA', b'ACG', b'AUA', b'GCA', b'GCG', b'GUA', b'GUG'],
#        dtype='|S3'), array([ 2,  1,  6,  2,  4, 31,  4]))

# %%
print( [i.decode() for i in fragpur["structure"]])
# Out:
# ['5NRGA', '1HNZ', '5DDP', '1FJE', '2XD0', '2HGH', '1K01', '4ATO', '1JBS', '2AAR', '4LCK', '3CCJ']

# %%
[ set(pdb_group.get(j.decode(), [])) for j in struc ]
# Out:
# [{'KOW', 'Ribosom'},
#  {'KH', 'Ribosom', 'Thx'},
#  {'RRM'},
#  {'RRM'},
#  {'toxin'},
#  {'zf'},
#  {'Ribosom'},
#  {'toxin'},
#  set(),
#  {'RIG', 'Ribosom', 'Trigger'},
#  {'Ribosom'},
#  {'KOW', 'Ribosom'}]

# %%
# proba of each cluster to be pur (all frag from same seq)
prob_pur = np.zeros(800)
count = 0
from math import factorial as fact
from math import log, exp
proba_pur = {}
for m in motifs:
    proba_pur[m] = {}
    for i in bigclust["10"][m]:
        n = mask_motif[m].sum() # Nb frag of motif m
        k = t[m][i] # cluster size
        #print(n, k)
        log_N_any = log(fact(n)) - log(fact(n-k))
        N_pur = 0
        for s in motif_seq[m]:
            ns = n_seq[s]
            #print(ns, k)
            if ns > k:
                nn = 1
                for j in range(ns-k+1, ns):
                    nn *= j
                N_pur += nn
        #print(N_pur)
        if N_pur == 0:
            proba_pur[m][i] = 0
        else:
            log_proba = log(N_pur) - log_N_any
            proba_pur[m][i] = exp(log_proba) 
            prob_pur[count] = proba_pur[m][i]
            count += 1

# %%
# expected number of pur clusters for a random clustering
prob_pur.sum()
# Out:
# 1.0035907156202207e-09

# %%
# Pur clusters
pur_clust = {}
for m in motifs:
    pur_clust[m] = []
    for i in clust_sizes40[m]:
        ns = 0
        for s in motif_seq[m]:
            if freq_obs[m][i][s] > 0: 
                ns +=1
        if ns == 1:
            pur_clust[m].append(i)

# %%
 pur_clust["AAA"]
# Out:
# [1094]

# %%
# seq50 in each pur_clust
fams_pur_clust = {}
seq50_pur_clust = {}
for m in motifs:
    fams_pur_clust[m] = {}
    seq50_pur_clust[m] = {}
    for i in pur_clust[m]:
        mask0 = mask_motif[m] & (fragments["clust1.0"] == i)
        strucs = fragments[mask0]["structure"]
        ss = [s.decode() for s in list(set(strucs))]
        d = chaindata[s]
        chains = d["protchains"]
        s50 = [d["seqclust"][c]["50"] for c in chains]
        #fams_pur_clust[m][i] = [chaindata[s]["pfam"] for s in ss]
        seq50_pur_clust[m][i] = np.array(s50)
        print(m, i, strucs)
        print(s50)
        print(len(s50), len(np.unique(s50)))

# %%
chaindata["1B7F"]["seqclust"]
# Out:
# {'A': {'100': 47245,
#   '30': 3990,
#   '40': 5704,
#   '50': 10567,
#   '70': 11534,
#   '90': 12056,
#   '95': 12143},
#  'B': {'100': 47245,
#   '30': 3990,
#   '40': 5704,
#   '50': 10567,
#   '70': 11534,
#   '90': 12056,
#   '95': 12143}}

# %%
m="AAA"
i=1094
mask0 = mask_motif[m] & (fragments["clust1.0"] == i)
print(mask0.sum())
strucs = [s.decode() for s in fragments[mask0]["structure"]]
seq50_pur = []
for s in strucs:
    d = chaindata[s]
    chains = d["protchains"]
    print(s, chains)
    s50 = [d["seqclust"][c]["50"] for c in chains]
    for j in s50:
        seq50_pur.append(j)
# Out:
# 53
# 2RSK ['C', 'D']
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-101-e5f3caaf63b4> in <module>
#       9     chains = d["protchains"]
#      10     print(s, chains)
# ---> 11     s50 = [d["seqclust"][c]["50"] for c in chains]
#      12     for j in s50:
#      13         seq50_pur.append(j)
#
# <ipython-input-101-e5f3caaf63b4> in <listcomp>(.0)
#       9     chains = d["protchains"]
#      10     print(s, chains)
# ---> 11     s50 = [d["seqclust"][c]["50"] for c in chains]
#      12     for j in s50:
#      13         seq50_pur.append(j)
#
# KeyError: '50'

# %%
mask0 = mask_motif["AAA"] & (fragments["clust1.0"] == 700)

# %%
fams_pur_clust["AAA"].keys()

# %% [markdown]
# # Question 4
# Does the bound protein have an influence on the structure of the mutated fragment?
# => do the frag bound to same prot family cluster together?

# %% [markdown]
# # Question 5
# => do the ssRNA and dsRNA cluster together?

# %%
from matplotlib import pyplot as plt
#frags = fragments[::1000] ###
#print(frags["motif"])
motif_names, motif_indices = np.unique(fragments["motif"], return_inverse=True)
cluster_indices = fragments["clust1.0"] + 100000 * motif_indices
#print(cluster_indices)
clust_ids, clust_sizes = np.unique(cluster_indices, return_counts=True)
#print(clust_sizes)
print("Clusters:", len(clust_sizes))
print("10 largest clusters:", np.sort(clust_sizes)[::-1][:10])
bins = (np.arange(10)+1).tolist() + [20, 50, 100, 200, 500, 1000, 2000, 5000, 10000, 20000, len(fragments)]

hist = np.histogram(clust_sizes, bins=bins)
import pandas as pd
print(pd.DataFrame([bins, hist[0]]).transpose())

fig, ax = plt.subplots()
x=np.arange(len(hist[0]))
ax.bar(height=hist[0], x=x, log=True)
ax.set_xticks(np.arange(len(bins)))
ax.set_xticklabels(bins, rotation='vertical')
plt.show()
fig, ax = plt.subplots()
ax.bar(height=hist[0], x=x)
ax.set_xticks(np.arange(len(bins)))
ax.set_xticklabels(bins, rotation='vertical')
plt.show()

# %%
largest = sum(np.sort(clust_sizes)[::-1][:8])
print(largest, len(fragments), 100 * largest/len(fragments))

# %%
clust_ids[np.argsort(clust_sizes)[::-1][:20]]

# %%
mask_clust1 = (fragments["clust1.0"] == 1)

# %%
mask_clust1.sum() / len(fragments)

# %%
sum(mask_state["ds"] &  mask_clust1)

# %%
sum(mask_state["ds"])

# %%
sum(mask_clust1)

# %%
mask_clust2 = (fragments["clust1.0"] == 2)

# %%
sum(mask_state["ds"] &  mask_clust2)

# %%
motif_names

# %%
print(clust_sizes[:10], clust_ids[:10])
print(clust_ids[:4672])
print(motif_names)
ordered_clust_sizes = np.zeros(max(clust_ids)+1, dtype=int)
ordered_clust_sizes[clust_ids] = clust_sizes
ordered_clust_sizes[100001], clust_sizes[4671], clust_ids[4671]
frag_clust_size = ordered_clust_sizes[cluster_indices]
#fragments[100000]["clust1.0"], fragments[100000]["motif"], ordered_clust_sizes[500001], frag_clust_size[100000]
mask_clust_size_2 = (frag_clust_size == 2)

# %%
mask_size2_ss = mask_clust_size_2 & mask_state["ss"]
mask_size2_ds = mask_clust_size_2 & mask_state["ds"]

# %%
sum(mask_size2_ss), sum(mask_size2_ds)

# %%
sum(mask_clust_size_2)

# %%
clust_size2 = list(clust_ids[clust_sizes==2])

dict_clust_size2 = {k:{"ss": 0, "ds":0} for k in clust_size2 }
for state in ["ds", "ss"]:
    frag_clustsize2 = fragments[mask_clust_size_2 & mask_state[state]]
    for frag in frag_clustsize2:
        motif = frag["motif"]
        motif_ind = list(motif_names).index(motif)
        clust_global_ind = frag["clust1.0"] + 100000 * motif_ind
        #if clust_global_ind not in dict_clust_size2:
        #    dict_clust_size2[clust_global_ind] = {"ss": 0, "ds":0}
        dict_clust_size2[clust_global_ind][state] += 1

# %%
dict_clust_size2

# %%
ss = np.array([v["ss"] for v in dict_clust_size2.values()])
ss0 = (ss == 0).sum()
ss1 = (ss == 1).sum()
ss2 = (ss == 2).sum()
print(ss0/len(ss), ss1/len(ss), ss2/len(ss))

# %%
ssfreq = sum(mask_size2_ss)/sum(mask_clust_size_2)
print(ssfreq)
print((1-ssfreq)*(1-ssfreq), 2*(1-ssfreq)*ssfreq, ssfreq*ssfreq)

# %%
clust_size1 = list(clust_ids[clust_sizes==1])

# %%
frag_clust_size[:10]

# %%
frag_size1 = fragments[frag_clust_size == 1]

# %%
len(frag_size1)

# %%
frag_size1_ss = (frag_clust_size == 1) & mask_state["ss"]

# %%
sum(frag_size1_ss)

# %%
frag_size1_ds = (frag_clust_size == 1) & mask_state["ds"]
sum(frag_size1_ds)

# %%
sum(frag_clust_size == 1)

# %%
sum(mask_Rib & (frag_clust_size == 1))

# %%
sum(mask_noRib & (frag_clust_size == 1))

# %%
5721/13901

# %%
methods = query(chaindata, chainschema, fragments, None, "method")

# %%
method = methods[:,0]

# %%
method[:10]

# %%
xray = (method == "x-ray diffraction")

# %%
sum(xray)

# %%
nmr = (method == "solution nmr")

# %%
sum(nmr)

# %%
sum(nmr & (frag_clust_size == 1))

# %%
sum((frag_clust_size == 1))

# %%
4252/13901

# %%
35455/len(fragments)

# %% [markdown]
# # Question 6
# From what protein families do the fragments come from
