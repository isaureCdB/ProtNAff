# %%
# %run json2npy.py fragments_clust.json fragments_clust.npy
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /home/isaurec/projets/NAfragDB/search_frag_library/json2npy.py in <module>()
#      20 dtype = np.dtype(dtype)
#      21 import json
# ---> 22 jfrags=json.load(open(sys.argv[1])) #fragments_clust-aa_missing.json
#      23 size = 0
#      24 for motif in jfrags:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'fragments_clust.json'

# %%
# %run load_data.py fragments_clust.npy structures.json

# %%
from query import *
from requests import *

# %%
# %run make_chainschema.py

# %%
chainschema = json.load(open("chainschema.json"))

# %%
ss = query(chaindata, chainschema, fragments, is_ss, "ss", part=None)
# Out:
# pdbcode
# {'res': 'res_17', 'model': 'model_1', 'pdbcode': u'4PJO', 'name': 'ss', 'chain': u'chain_4'}
# chain
# {'res': 'res_17', 'model': 'model_1', 'pdbcode': u'4PJO', 'name': 'ss', 'chain': u'chain_4'}
# res
# {'res': 'res_17', 'model': 'model_1', 'pdbcode': u'4PJO', 'name': 'ss', 'chain': u'chain_4'}
# pdbcode
# {'name': 'ss', 'chain': u'chain_4', 'res': 'res_18', 'model': 'model_1', 'pdbcode': u'4PJO'}
# chain
# {'name': 'ss', 'chain': u'chain_4', 'res': 'res_18', 'model': 'model_1', 'pdbcode': u'4PJO'}
# res
# {'name': 'ss', 'chain': u'chain_4', 'res': 'res_18', 'model': 'model_1', 'pdbcode': u'4PJO'}
# pdbcode
# {'name': 'ss', 'chain': u'chain_4', 'res': 'res_19', 'model': 'model_1', 'pdbcode': u'4PJO'}
# chain
# {'name': 'ss', 'chain': u'chain_4', 'res': 'res_19', 'model': 'model_1', 'pdbcode': u'4PJO'}
# res
# {'name': 'ss', 'chain': u'chain_4', 'res': 'res_19', 'model': 'model_1', 'pdbcode': u'4PJO'}
# pdbcode
# {'res': 'res_1', 'model': 'model_1', 'pdbcode': u'4PJO', 'name': 'ss', 'chain': u'chain_y'}
# chain
# {'res': 'res_1', 'model': 'model_1', 'pdbcode': u'4PJO', 'name': 'ss', 'chain': u'chain_y'}
# res
# {'res': 'res_1', 'model': 'model_1', 'pdbcode': u'4PJO', 'name': 'ss', 'chain': u'chain_y'}
# pdbcode
# {'name': 'ss', 'chain': u'chain_y', 'res': 'res_2', 'model': 'model_1', 'pdbcode': u'4PJO'}
# chain
# {'name': 'ss', 'chain': u'chain_y', 'res': 'res_2', 'model': 'model_1', 'pdbcode': u'4PJO'}
# res
# {'name': 'ss', 'chain': u'chain_y', 'res': 'res_2', 'model': 'model_1', 'pdbcode': u'4PJO'}
# pdbcode
# {'name': 'ss', 'chain': u'chain_y', 'res': 'res_3', 'model': 'model_1', 'pdbcode': u'4PJO'}
# chain
# {'name': 'ss', 'chain': u'chain_y', 'res': 'res_3', 'model': 'model_1', 'pdbcode': u'4PJO'}
# res
# {'name': 'ss', 'chain': u'chain_y', 'res': 'res_3', 'model': 'model_1', 'pdbcode': u'4PJO'}
# pdbcode
# {'res': 'res_5', 'model': 'model_1', 'pdbcode': u'4PJO', 'name': 'ss', 'chain': u'chain_y'}
# chain
# {'res': 'res_5', 'model': 'model_1', 'pdbcode': u'4PJO', 'name': 'ss', 'chain': u'chain_y'}
# res
# {'res': 'res_5', 'model': 'model_1', 'pdbcode': u'4PJO', 'name': 'ss', 'chain': u'chain_y'}
# pdbcode
# {'name': 'ss', 'chain': u'chain_y', 'res': 'res_6', 'model': 'model_1', 'pdbcode': u'4PJO'}
# chain
# {'name': 'ss', 'chain': u'chain_y', 'res': 'res_6', 'model': 'model_1', 'pdbcode': u'4PJO'}
# res
# {'name': 'ss', 'chain': u'chain_y', 'res': 'res_6', 'model': 'model_1', 'pdbcode': u'4PJO'}
# pdbcode
# {'name': 'ss', 'chain': u'chain_y', 'res': 'res_7', 'model': 'model_1', 'pdbcode': u'4PJO'}
# chain
# {'name': 'ss', 'chain': u'chain_y', 'res': 'res_7', 'model': 'model_1', 'pdbcode': u'4PJO'}
# res
# {'name': 'ss', 'chain': u'chain_y', 'res': 'res_7', 'model': 'model_1', 'pdbcode': u'4PJO'}
# pdbcode
# {'res': 'res_3', 'model': 'model_1', 'pdbcode': u'1AQ4', 'name': 'ss', 'chain': u'chain_R'}
# chain
# {'res': 'res_3', 'model': 'model_1', 'pdbcode': u'1AQ4', 'name': 'ss', 'chain': u'chain_R'}
# res
# {'res': 'res_3', 'model': 'model_1', 'pdbcode': u'1AQ4', 'name': 'ss', 'chain': u'chain_R'}
# pdbcode
# {'name': 'ss', 'chain': u'chain_R', 'res': 'res_4', 'model': 'model_1', 'pdbcode': u'1AQ4'}
# chain
# {'name': 'ss', 'chain': u'chain_R', 'res': 'res_4', 'model': 'model_1', 'pdbcode': u'1AQ4'}
# res
# {'name': 'ss', 'chain': u'chain_R', 'res': 'res_4', 'model': 'model_1', 'pdbcode': u'1AQ4'}
# pdbcode
# {'name': 'ss', 'chain': u'chain_R', 'res': 'res_5', 'model': 'model_1', 'pdbcode': u'1AQ4'}
# chain
# {'name': 'ss', 'chain': u'chain_R', 'res': 'res_5', 'model': 'model_1', 'pdbcode': u'1AQ4'}
# res
# {'name': 'ss', 'chain': u'chain_R', 'res': 'res_5', 'model': 'model_1', 'pdbcode': u'1AQ4'}
# pdbcode
# {'res': 'res_5', 'model': 'model_1', 'pdbcode': u'1AQ4', 'name': 'ss', 'chain': u'chain_R'}
# chain
# {'res': 'res_5', 'model': 'model_1', 'pdbcode': u'1AQ4', 'name': 'ss', 'chain': u'chain_R'}
# res
# {'res': 'res_5', 'model': 'model_1', 'pdbcode': u'1AQ4', 'name': 'ss', 'chain': u'chain_R'}
# pdbcode
# {'name': 'ss', 'chain': u'chain_R', 'res': 'res_6', 'model': 'model_1', 'pdbcode': u'1AQ4'}
# chain
# {'name': 'ss', 'chain': u'chain_R', 'res': 'res_6', 'model': 'model_1', 'pdbcode': u'1AQ4'}
# res
# {'name': 'ss', 'chain': u'chain_R', 'res': 'res_6', 'model': 'model_1', 'pdbcode': u'1AQ4'}
# pdbcode
# {'name': 'ss', 'chain': u'chain_R', 'res': 'res_7', 'model': 'model_1', 'pdbcode': u'1AQ4'}
# chain
# {'name': 'ss', 'chain': u'chain_R', 'res': 'res_7', 'model': 'model_1', 'pdbcode': u'1AQ4'}
# res
# {'name': 'ss', 'chain': u'chain_R', 'res': 'res_7', 'model': 'model_1', 'pdbcode': u'1AQ4'}
# pdbcode
# {'res': 'res_4', 'model': 'model_1', 'pdbcode': u'1AQ4', 'name': 'ss', 'chain': u'chain_R'}
# chain
# {'res': 'res_4', 'model': 'model_1', 'pdbcode': u'1AQ4', 'name': 'ss', 'chain': u'chain_R'}
# res
# {'res': 'res_4', 'model': 'model_1', 'pdbcode': u'1AQ4', 'name': 'ss', 'chain': u'chain_R'}
# pdbcode
# {'name': 'ss', 'chain': u'chain_R', 'res': 'res_5', 'model': 'model_1', 'pdbcode': u'1AQ4'}
# chain
# {'name': 'ss', 'chain': u'chain_R', 'res': 'res_5', 'model': 'model_1', 'pdbcode': u'1AQ4'}
# res
# {'name': 'ss', 'chain': u'chain_R', 'res': 'res_5', 'model': 'model_1', 'pdbcode': u'1AQ4'}
# pdbcode
# {'name': 'ss', 'chain': u'chain_R', 'res': 'res_6', 'model': 'model_1', 'pdbcode': u'1AQ4'}
# chain
# {'name': 'ss', 'chain': u'chain_R', 'res': 'res_6', 'model': 'model_1', 'pdbcode': u'1AQ4'}
# res
# {'name': 'ss', 'chain': u'chain_R', 'res': 'res_6', 'model': 'model_1', 'pdbcode': u'1AQ4'}
# pdbcode
# {'res': 'res_4', 'model': 'model_1', 'pdbcode': u'1AQ4', 'name': 'ss', 'chain': u'chain_S'}
# chain
# {'res': 'res_4', 'model': 'model_1', 'pdbcode': u'1AQ4', 'name': 'ss', 'chain': u'chain_S'}
# res
# {'res': 'res_4', 'model': 'model_1', 'pdbcode': u'1AQ4', 'name': 'ss', 'chain': u'chain_S'}
# pdbcode
# {'name': 'ss', 'chain': u'chain_S', 'res': 'res_5', 'model': 'model_1', 'pdbcode': u'1AQ4'}
# chain
# {'name': 'ss', 'chain': u'chain_S', 'res': 'res_5', 'model': 'model_1', 'pdbcode': u'1AQ4'}
# res
# {'name': 'ss', 'chain': u'chain_S', 'res': 'res_5', 'model': 'model_1', 'pdbcode': u'1AQ4'}
# pdbcode
# {'name': 'ss', 'chain': u'chain_S', 'res': 'res_6', 'model': 'model_1', 'pdbcode': u'1AQ4'}
# chain
# {'name': 'ss', 'chain': u'chain_S', 'res': 'res_6', 'model': 'model_1', 'pdbcode': u'1AQ4'}
# res
# {'name': 'ss', 'chain': u'chain_S', 'res': 'res_6', 'model': 'model_1', 'pdbcode': u'1AQ4'}
# pdbcode
# {'res': 'res_3', 'model': 'model_1', 'pdbcode': u'1AQ4', 'name': 'ss', 'chain': u'chain_S'}
# chain
# {'res': 'res_3', 'model': 'model_1', 'pdbcode': u'1AQ4', 'name': 'ss', 'chain': u'chain_S'}
# res
# {'res': 'res_3', 'model': 'model_1', 'pdbcode': u'1AQ4', 'name': 'ss', 'chain': u'chain_S'}
# pdbcode
# {'name': 'ss', 'chain': u'chain_S', 'res': 'res_4', 'model': 'model_1', 'pdbcode': u'1AQ4'}
# chain
# {'name': 'ss', 'chain': u'chain_S', 'res': 'res_4', 'model': 'model_1', 'pdbcode': u'1AQ4'}
# res
# {'name': 'ss', 'chain': u'chain_S', 'res': 'res_4', 'model': 'model_1', 'pdbcode': u'1AQ4'}
# pdbcode
# {'name': 'ss', 'chain': u'chain_S', 'res': 'res_5', 'model': 'model_1', 'pdbcode': u'1AQ4'}
# chain
# {'name': 'ss', 'chain': u'chain_S', 'res': 'res_5', 'model': 'model_1', 'pdbcode': u'1AQ4'}
# res
# {'name': 'ss', 'chain': u'chain_S', 'res': 'res_5', 'model': 'model_1', 'pdbcode': u'1AQ4'}
# pdbcode
# {'res': 'res_16', 'model': 'model_1', 'pdbcode': u'4PJO', 'name': 'ss', 'chain': u'chain_1'}
# chain
# {'res': 'res_16', 'model': 'model_1', 'pdbcode': u'4PJO', 'name': 'ss', 'chain': u'chain_1'}
# res
# {'res': 'res_16', 'model': 'model_1', 'pdbcode': u'4PJO', 'name': 'ss', 'chain': u'chain_1'}
# pdbcode
# {'name': 'ss', 'chain': u'chain_1', 'res': 'res_17', 'model': 'model_1', 'pdbcode': u'4PJO'}
# chain
# {'name': 'ss', 'chain': u'chain_1', 'res': 'res_17', 'model': 'model_1', 'pdbcode': u'4PJO'}
# res
# {'name': 'ss', 'chain': u'chain_1', 'res': 'res_17', 'model': 'model_1', 'pdbcode': u'4PJO'}
# pdbcode
# {'name': 'ss', 'chain': u'chain_1', 'res': 'res_18', 'model': 'model_1', 'pdbcode': u'4PJO'}
# chain
# {'name': 'ss', 'chain': u'chain_1', 'res': 'res_18', 'model': 'model_1', 'pdbcode': u'4PJO'}
# res
# {'name': 'ss', 'chain': u'chain_1', 'res': 'res_18', 'model': 'model_1', 'pdbcode': u'4PJO'}
# pdbcode
# {'res': 'res_5', 'model': 'model_1', 'pdbcode': u'1AQ4', 'name': 'ss', 'chain': u'chain_S'}
# chain
# {'res': 'res_5', 'model': 'model_1', 'pdbcode': u'1AQ4', 'name': 'ss', 'chain': u'chain_S'}
# res
# {'res': 'res_5', 'model': 'model_1', 'pdbcode': u'1AQ4', 'name': 'ss', 'chain': u'chain_S'}
# pdbcode
# {'name': 'ss', 'chain': u'chain_S', 'res': 'res_6', 'model': 'model_1', 'pdbcode': u'1AQ4'}
# chain
# {'name': 'ss', 'chain': u'chain_S', 'res': 'res_6', 'model': 'model_1', 'pdbcode': u'1AQ4'}
# res
# {'name': 'ss', 'chain': u'chain_S', 'res': 'res_6', 'model': 'model_1', 'pdbcode': u'1AQ4'}
# pdbcode
# {'name': 'ss', 'chain': u'chain_S', 'res': 'res_7', 'model': 'model_1', 'pdbcode': u'1AQ4'}
# chain
# {'name': 'ss', 'chain': u'chain_S', 'res': 'res_7', 'model': 'model_1', 'pdbcode': u'1AQ4'}
# res
# {'name': 'ss', 'chain': u'chain_S', 'res': 'res_7', 'model': 'model_1', 'pdbcode': u'1AQ4'}
# pdbcode
# {'res': 'res_1', 'model': 'model_1', 'pdbcode': u'4PJO', 'name': 'ss', 'chain': u'chain_X'}
# chain
# {'res': 'res_1', 'model': 'model_1', 'pdbcode': u'4PJO', 'name': 'ss', 'chain': u'chain_X'}
# res
# {'res': 'res_1', 'model': 'model_1', 'pdbcode': u'4PJO', 'name': 'ss', 'chain': u'chain_X'}
# pdbcode
# {'name': 'ss', 'chain': u'chain_X', 'res': 'res_2', 'model': 'model_1', 'pdbcode': u'4PJO'}
# chain
# {'name': 'ss', 'chain': u'chain_X', 'res': 'res_2', 'model': 'model_1', 'pdbcode': u'4PJO'}
# res
# {'name': 'ss', 'chain': u'chain_X', 'res': 'res_2', 'model': 'model_1', 'pdbcode': u'4PJO'}
# pdbcode
# {'name': 'ss', 'chain': u'chain_X', 'res': 'res_3', 'model': 'model_1', 'pdbcode': u'4PJO'}
# chain
# {'name': 'ss', 'chain': u'chain_X', 'res': 'res_3', 'model': 'model_1', 'pdbcode': u'4PJO'}
# res
# {'name': 'ss', 'chain': u'chain_X', 'res': 'res_3', 'model': 'model_1', 'pdbcode': u'4PJO'}
# pdbcode
# {'res': 'res_17', 'model': 'model_1', 'pdbcode': u'4PJO', 'name': 'ss', 'chain': u'chain_1'}
# chain
# {'res': 'res_17', 'model': 'model_1', 'pdbcode': u'4PJO', 'name': 'ss', 'chain': u'chain_1'}
# res
# {'res': 'res_17', 'model': 'model_1', 'pdbcode': u'4PJO', 'name': 'ss', 'chain': u'chain_1'}
# pdbcode
# {'name': 'ss', 'chain': u'chain_1', 'res': 'res_18', 'model': 'model_1', 'pdbcode': u'4PJO'}
# chain
# {'name': 'ss', 'chain': u'chain_1', 'res': 'res_18', 'model': 'model_1', 'pdbcode': u'4PJO'}
# res
# {'name': 'ss', 'chain': u'chain_1', 'res': 'res_18', 'model': 'model_1', 'pdbcode': u'4PJO'}
# pdbcode
# {'name': 'ss', 'chain': u'chain_1', 'res': 'res_19', 'model': 'model_1', 'pdbcode': u'4PJO'}
# chain
# {'name': 'ss', 'chain': u'chain_1', 'res': 'res_19', 'model': 'model_1', 'pdbcode': u'4PJO'}
# res
# {'name': 'ss', 'chain': u'chain_1', 'res': 'res_19', 'model': 'model_1', 'pdbcode': u'4PJO'}
# pdbcode
# {'res': 'res_16', 'model': 'model_1', 'pdbcode': u'4PJO', 'name': 'ss', 'chain': u'chain_2'}
# chain
# {'res': 'res_16', 'model': 'model_1', 'pdbcode': u'4PJO', 'name': 'ss', 'chain': u'chain_2'}
# res
# {'res': 'res_16', 'model': 'model_1', 'pdbcode': u'4PJO', 'name': 'ss', 'chain': u'chain_2'}
# pdbcode
# {'name': 'ss', 'chain': u'chain_2', 'res': 'res_17', 'model': 'model_1', 'pdbcode': u'4PJO'}
# chain
# {'name': 'ss', 'chain': u'chain_2', 'res': 'res_17', 'model': 'model_1', 'pdbcode': u'4PJO'}
# res
# {'name': 'ss', 'chain': u'chain_2', 'res': 'res_17', 'model': 'model_1', 'pdbcode': u'4PJO'}
# pdbcode
# {'name': 'ss', 'chain': u'chain_2', 'res': 'res_18', 'model': 'model_1', 'pdbcode': u'4PJO'}
# chain
# {'name': 'ss', 'chain': u'chain_2', 'res': 'res_18', 'model': 'model_1', 'pdbcode': u'4PJO'}
# res
# {'name': 'ss', 'chain': u'chain_2', 'res': 'res_18', 'model': 'model_1', 'pdbcode': u'4PJO'}
# pdbcode
# {'res': 'res_5', 'model': 'model_1', 'pdbcode': u'4PJO', 'name': 'ss', 'chain': u'chain_X'}
# chain
# {'res': 'res_5', 'model': 'model_1', 'pdbcode': u'4PJO', 'name': 'ss', 'chain': u'chain_X'}
# res
# {'res': 'res_5', 'model': 'model_1', 'pdbcode': u'4PJO', 'name': 'ss', 'chain': u'chain_X'}
# pdbcode
# {'name': 'ss', 'chain': u'chain_X', 'res': 'res_6', 'model': 'model_1', 'pdbcode': u'4PJO'}
# chain
# {'name': 'ss', 'chain': u'chain_X', 'res': 'res_6', 'model': 'model_1', 'pdbcode': u'4PJO'}
# res
# {'name': 'ss', 'chain': u'chain_X', 'res': 'res_6', 'model': 'model_1', 'pdbcode': u'4PJO'}
# pdbcode
# {'name': 'ss', 'chain': u'chain_X', 'res': 'res_7', 'model': 'model_1', 'pdbcode': u'4PJO'}
# chain
# {'name': 'ss', 'chain': u'chain_X', 'res': 'res_7', 'model': 'model_1', 'pdbcode': u'4PJO'}
# res
# {'name': 'ss', 'chain': u'chain_X', 'res': 'res_7', 'model': 'model_1', 'pdbcode': u'4PJO'}
# pdbcode
# {'res': 'res_1', 'model': 'model_1', 'pdbcode': u'4PJO', 'name': 'ss', 'chain': u'chain_x'}
# chain
# {'res': 'res_1', 'model': 'model_1', 'pdbcode': u'4PJO', 'name': 'ss', 'chain': u'chain_x'}
# res
# {'res': 'res_1', 'model': 'model_1', 'pdbcode': u'4PJO', 'name': 'ss', 'chain': u'chain_x'}
# pdbcode
# {'name': 'ss', 'chain': u'chain_x', 'res': 'res_2', 'model': 'model_1', 'pdbcode': u'4PJO'}
# chain
# {'name': 'ss', 'chain': u'chain_x', 'res': 'res_2', 'model': 'model_1', 'pdbcode': u'4PJO'}
# res
# {'name': 'ss', 'chain': u'chain_x', 'res': 'res_2', 'model': 'model_1', 'pdbcode': u'4PJO'}
# pdbcode
# {'name': 'ss', 'chain': u'chain_x', 'res': 'res_3', 'model': 'model_1', 'pdbcode': u'4PJO'}
# chain
# {'name': 'ss', 'chain': u'chain_x', 'res': 'res_3', 'model': 'model_1', 'pdbcode': u'4PJO'}
# res
# {'name': 'ss', 'chain': u'chain_x', 'res': 'res_3', 'model': 'model_1', 'pdbcode': u'4PJO'}
# pdbcode
# {'res': 'res_17', 'model': 'model_1', 'pdbcode': u'4PJO', 'name': 'ss', 'chain': u'chain_2'}
# chain
# {'res': 'res_17', 'model': 'model_1', 'pdbcode': u'4PJO', 'name': 'ss', 'chain': u'chain_2'}
# res
# {'res': 'res_17', 'model': 'model_1', 'pdbcode': u'4PJO', 'name': 'ss', 'chain': u'chain_2'}
# pdbcode
# {'name': 'ss', 'chain': u'chain_2', 'res': 'res_18', 'model': 'model_1', 'pdbcode': u'4PJO'}
# chain
# {'name': 'ss', 'chain': u'chain_2', 'res': 'res_18', 'model': 'model_1', 'pdbcode': u'4PJO'}
# res
# {'name': 'ss', 'chain': u'chain_2', 'res': 'res_18', 'model': 'model_1', 'pdbcode': u'4PJO'}
# pdbcode
# {'name': 'ss', 'chain': u'chain_2', 'res': 'res_19', 'model': 'model_1', 'pdbcode': u'4PJO'}
# chain
# {'name': 'ss', 'chain': u'chain_2', 'res': 'res_19', 'model': 'model_1', 'pdbcode': u'4PJO'}
# res
# {'name': 'ss', 'chain': u'chain_2', 'res': 'res_19', 'model': 'model_1', 'pdbcode': u'4PJO'}
# pdbcode
# {'res': 'res_16', 'model': 'model_1', 'pdbcode': u'4PJO', 'name': 'ss', 'chain': u'chain_3'}
# chain
# {'res': 'res_16', 'model': 'model_1', 'pdbcode': u'4PJO', 'name': 'ss', 'chain': u'chain_3'}
# res
# {'res': 'res_16', 'model': 'model_1', 'pdbcode': u'4PJO', 'name': 'ss', 'chain': u'chain_3'}
# pdbcode
# {'name': 'ss', 'chain': u'chain_3', 'res': 'res_17', 'model': 'model_1', 'pdbcode': u'4PJO'}
# chain
# {'name': 'ss', 'chain': u'chain_3', 'res': 'res_17', 'model': 'model_1', 'pdbcode': u'4PJO'}
# res
# {'name': 'ss', 'chain': u'chain_3', 'res': 'res_17', 'model': 'model_1', 'pdbcode': u'4PJO'}
# pdbcode
# {'name': 'ss', 'chain': u'chain_3', 'res': 'res_18', 'model': 'model_1', 'pdbcode': u'4PJO'}
# chain
# {'name': 'ss', 'chain': u'chain_3', 'res': 'res_18', 'model': 'model_1', 'pdbcode': u'4PJO'}
# res
# {'name': 'ss', 'chain': u'chain_3', 'res': 'res_18', 'model': 'model_1', 'pdbcode': u'4PJO'}
# pdbcode
# {'res': 'res_5', 'model': 'model_1', 'pdbcode': u'4PJO', 'name': 'ss', 'chain': u'chain_x'}
# chain
# {'res': 'res_5', 'model': 'model_1', 'pdbcode': u'4PJO', 'name': 'ss', 'chain': u'chain_x'}
# res
# {'res': 'res_5', 'model': 'model_1', 'pdbcode': u'4PJO', 'name': 'ss', 'chain': u'chain_x'}
# pdbcode
# {'name': 'ss', 'chain': u'chain_x', 'res': 'res_6', 'model': 'model_1', 'pdbcode': u'4PJO'}
# chain
# {'name': 'ss', 'chain': u'chain_x', 'res': 'res_6', 'model': 'model_1', 'pdbcode': u'4PJO'}
# res
# {'name': 'ss', 'chain': u'chain_x', 'res': 'res_6', 'model': 'model_1', 'pdbcode': u'4PJO'}
# pdbcode
# {'name': 'ss', 'chain': u'chain_x', 'res': 'res_7', 'model': 'model_1', 'pdbcode': u'4PJO'}
# chain
# {'name': 'ss', 'chain': u'chain_x', 'res': 'res_7', 'model': 'model_1', 'pdbcode': u'4PJO'}
# res
# {'name': 'ss', 'chain': u'chain_x', 'res': 'res_7', 'model': 'model_1', 'pdbcode': u'4PJO'}
# pdbcode
# {'res': 'res_1', 'model': 'model_1', 'pdbcode': u'4PJO', 'name': 'ss', 'chain': u'chain_Y'}
# chain
# {'res': 'res_1', 'model': 'model_1', 'pdbcode': u'4PJO', 'name': 'ss', 'chain': u'chain_Y'}
# res
# {'res': 'res_1', 'model': 'model_1', 'pdbcode': u'4PJO', 'name': 'ss', 'chain': u'chain_Y'}
# pdbcode
# {'name': 'ss', 'chain': u'chain_Y', 'res': 'res_2', 'model': 'model_1', 'pdbcode': u'4PJO'}
# chain
# {'name': 'ss', 'chain': u'chain_Y', 'res': 'res_2', 'model': 'model_1', 'pdbcode': u'4PJO'}
# res
# {'name': 'ss', 'chain': u'chain_Y', 'res': 'res_2', 'model': 'model_1', 'pdbcode': u'4PJO'}
# pdbcode
# {'name': 'ss', 'chain': u'chain_Y', 'res': 'res_3', 'model': 'model_1', 'pdbcode': u'4PJO'}
# chain
# {'name': 'ss', 'chain': u'chain_Y', 'res': 'res_3', 'model': 'model_1', 'pdbcode': u'4PJO'}
# res
# {'name': 'ss', 'chain': u'chain_Y', 'res': 'res_3', 'model': 'model_1', 'pdbcode': u'4PJO'}
# pdbcode
# {'res': 'res_17', 'model': 'model_1', 'pdbcode': u'4PJO', 'name': 'ss', 'chain': u'chain_3'}
# chain
# {'res': 'res_17', 'model': 'model_1', 'pdbcode': u'4PJO', 'name': 'ss', 'chain': u'chain_3'}
# res
# {'res': 'res_17', 'model': 'model_1', 'pdbcode': u'4PJO', 'name': 'ss', 'chain': u'chain_3'}
# pdbcode
# {'name': 'ss', 'chain': u'chain_3', 'res': 'res_18', 'model': 'model_1', 'pdbcode': u'4PJO'}
# chain
# {'name': 'ss', 'chain': u'chain_3', 'res': 'res_18', 'model': 'model_1', 'pdbcode': u'4PJO'}
# res
# {'name': 'ss', 'chain': u'chain_3', 'res': 'res_18', 'model': 'model_1', 'pdbcode': u'4PJO'}
# pdbcode
# {'name': 'ss', 'chain': u'chain_3', 'res': 'res_19', 'model': 'model_1', 'pdbcode': u'4PJO'}
# chain
# {'name': 'ss', 'chain': u'chain_3', 'res': 'res_19', 'model': 'model_1', 'pdbcode': u'4PJO'}
# res
# {'name': 'ss', 'chain': u'chain_3', 'res': 'res_19', 'model': 'model_1', 'pdbcode': u'4PJO'}
# pdbcode
# {'res': 'res_16', 'model': 'model_1', 'pdbcode': u'4PJO', 'name': 'ss', 'chain': u'chain_4'}
# chain
# {'res': 'res_16', 'model': 'model_1', 'pdbcode': u'4PJO', 'name': 'ss', 'chain': u'chain_4'}
# res
# {'res': 'res_16', 'model': 'model_1', 'pdbcode': u'4PJO', 'name': 'ss', 'chain': u'chain_4'}
# pdbcode
# {'name': 'ss', 'chain': u'chain_4', 'res': 'res_17', 'model': 'model_1', 'pdbcode': u'4PJO'}
# chain
# {'name': 'ss', 'chain': u'chain_4', 'res': 'res_17', 'model': 'model_1', 'pdbcode': u'4PJO'}
# res
# {'name': 'ss', 'chain': u'chain_4', 'res': 'res_17', 'model': 'model_1', 'pdbcode': u'4PJO'}
# pdbcode
# {'name': 'ss', 'chain': u'chain_4', 'res': 'res_18', 'model': 'model_1', 'pdbcode': u'4PJO'}
# chain
# {'name': 'ss', 'chain': u'chain_4', 'res': 'res_18', 'model': 'model_1', 'pdbcode': u'4PJO'}
# res
# {'name': 'ss', 'chain': u'chain_4', 'res': 'res_18', 'model': 'model_1', 'pdbcode': u'4PJO'}
# pdbcode
# {'res': 'res_5', 'model': 'model_1', 'pdbcode': u'4PJO', 'name': 'ss', 'chain': u'chain_Y'}
# chain
# {'res': 'res_5', 'model': 'model_1', 'pdbcode': u'4PJO', 'name': 'ss', 'chain': u'chain_Y'}
# res
# {'res': 'res_5', 'model': 'model_1', 'pdbcode': u'4PJO', 'name': 'ss', 'chain': u'chain_Y'}
# pdbcode
# {'name': 'ss', 'chain': u'chain_Y', 'res': 'res_6', 'model': 'model_1', 'pdbcode': u'4PJO'}
# chain
# {'name': 'ss', 'chain': u'chain_Y', 'res': 'res_6', 'model': 'model_1', 'pdbcode': u'4PJO'}
# res
# {'name': 'ss', 'chain': u'chain_Y', 'res': 'res_6', 'model': 'model_1', 'pdbcode': u'4PJO'}
# pdbcode
# {'name': 'ss', 'chain': u'chain_Y', 'res': 'res_7', 'model': 'model_1', 'pdbcode': u'4PJO'}
# chain
# {'name': 'ss', 'chain': u'chain_Y', 'res': 'res_7', 'model': 'model_1', 'pdbcode': u'4PJO'}
# res
# {'name': 'ss', 'chain': u'chain_Y', 'res': 'res_7', 'model': 'model_1', 'pdbcode': u'4PJO'}

# %%
ds = query(chaindata, chainschema, fragments, is_ds, "ss", part=None)
# Out:
# pdbcode
# {'res': 'res_17', 'model': 'model_1', 'pdbcode': u'4PJO', 'name': 'ss', 'chain': u'chain_4'}
# chain
# {'res': 'res_17', 'model': 'model_1', 'pdbcode': u'4PJO', 'name': 'ss', 'chain': u'chain_4'}
# res
# {'res': 'res_17', 'model': 'model_1', 'pdbcode': u'4PJO', 'name': 'ss', 'chain': u'chain_4'}
# pdbcode
# {'name': 'ss', 'chain': u'chain_4', 'res': 'res_18', 'model': 'model_1', 'pdbcode': u'4PJO'}
# chain
# {'name': 'ss', 'chain': u'chain_4', 'res': 'res_18', 'model': 'model_1', 'pdbcode': u'4PJO'}
# res
# {'name': 'ss', 'chain': u'chain_4', 'res': 'res_18', 'model': 'model_1', 'pdbcode': u'4PJO'}
# pdbcode
# {'name': 'ss', 'chain': u'chain_4', 'res': 'res_19', 'model': 'model_1', 'pdbcode': u'4PJO'}
# chain
# {'name': 'ss', 'chain': u'chain_4', 'res': 'res_19', 'model': 'model_1', 'pdbcode': u'4PJO'}
# res
# {'name': 'ss', 'chain': u'chain_4', 'res': 'res_19', 'model': 'model_1', 'pdbcode': u'4PJO'}
# pdbcode
# {'res': 'res_1', 'model': 'model_1', 'pdbcode': u'4PJO', 'name': 'ss', 'chain': u'chain_y'}
# chain
# {'res': 'res_1', 'model': 'model_1', 'pdbcode': u'4PJO', 'name': 'ss', 'chain': u'chain_y'}
# res
# {'res': 'res_1', 'model': 'model_1', 'pdbcode': u'4PJO', 'name': 'ss', 'chain': u'chain_y'}
# pdbcode
# {'name': 'ss', 'chain': u'chain_y', 'res': 'res_2', 'model': 'model_1', 'pdbcode': u'4PJO'}
# chain
# {'name': 'ss', 'chain': u'chain_y', 'res': 'res_2', 'model': 'model_1', 'pdbcode': u'4PJO'}
# res
# {'name': 'ss', 'chain': u'chain_y', 'res': 'res_2', 'model': 'model_1', 'pdbcode': u'4PJO'}
# pdbcode
# {'name': 'ss', 'chain': u'chain_y', 'res': 'res_3', 'model': 'model_1', 'pdbcode': u'4PJO'}
# chain
# {'name': 'ss', 'chain': u'chain_y', 'res': 'res_3', 'model': 'model_1', 'pdbcode': u'4PJO'}
# res
# {'name': 'ss', 'chain': u'chain_y', 'res': 'res_3', 'model': 'model_1', 'pdbcode': u'4PJO'}
# pdbcode
# {'res': 'res_5', 'model': 'model_1', 'pdbcode': u'4PJO', 'name': 'ss', 'chain': u'chain_y'}
# chain
# {'res': 'res_5', 'model': 'model_1', 'pdbcode': u'4PJO', 'name': 'ss', 'chain': u'chain_y'}
# res
# {'res': 'res_5', 'model': 'model_1', 'pdbcode': u'4PJO', 'name': 'ss', 'chain': u'chain_y'}
# pdbcode
# {'name': 'ss', 'chain': u'chain_y', 'res': 'res_6', 'model': 'model_1', 'pdbcode': u'4PJO'}
# chain
# {'name': 'ss', 'chain': u'chain_y', 'res': 'res_6', 'model': 'model_1', 'pdbcode': u'4PJO'}
# res
# {'name': 'ss', 'chain': u'chain_y', 'res': 'res_6', 'model': 'model_1', 'pdbcode': u'4PJO'}
# pdbcode
# {'name': 'ss', 'chain': u'chain_y', 'res': 'res_7', 'model': 'model_1', 'pdbcode': u'4PJO'}
# chain
# {'name': 'ss', 'chain': u'chain_y', 'res': 'res_7', 'model': 'model_1', 'pdbcode': u'4PJO'}
# res
# {'name': 'ss', 'chain': u'chain_y', 'res': 'res_7', 'model': 'model_1', 'pdbcode': u'4PJO'}
# pdbcode
# {'res': 'res_3', 'model': 'model_1', 'pdbcode': u'1AQ4', 'name': 'ss', 'chain': u'chain_R'}
# chain
# {'res': 'res_3', 'model': 'model_1', 'pdbcode': u'1AQ4', 'name': 'ss', 'chain': u'chain_R'}
# res
# {'res': 'res_3', 'model': 'model_1', 'pdbcode': u'1AQ4', 'name': 'ss', 'chain': u'chain_R'}
# pdbcode
# {'name': 'ss', 'chain': u'chain_R', 'res': 'res_4', 'model': 'model_1', 'pdbcode': u'1AQ4'}
# chain
# {'name': 'ss', 'chain': u'chain_R', 'res': 'res_4', 'model': 'model_1', 'pdbcode': u'1AQ4'}
# res
# {'name': 'ss', 'chain': u'chain_R', 'res': 'res_4', 'model': 'model_1', 'pdbcode': u'1AQ4'}
# pdbcode
# {'name': 'ss', 'chain': u'chain_R', 'res': 'res_5', 'model': 'model_1', 'pdbcode': u'1AQ4'}
# chain
# {'name': 'ss', 'chain': u'chain_R', 'res': 'res_5', 'model': 'model_1', 'pdbcode': u'1AQ4'}
# res
# {'name': 'ss', 'chain': u'chain_R', 'res': 'res_5', 'model': 'model_1', 'pdbcode': u'1AQ4'}
# pdbcode
# {'res': 'res_5', 'model': 'model_1', 'pdbcode': u'1AQ4', 'name': 'ss', 'chain': u'chain_R'}
# chain
# {'res': 'res_5', 'model': 'model_1', 'pdbcode': u'1AQ4', 'name': 'ss', 'chain': u'chain_R'}
# res
# {'res': 'res_5', 'model': 'model_1', 'pdbcode': u'1AQ4', 'name': 'ss', 'chain': u'chain_R'}
# pdbcode
# {'name': 'ss', 'chain': u'chain_R', 'res': 'res_6', 'model': 'model_1', 'pdbcode': u'1AQ4'}
# chain
# {'name': 'ss', 'chain': u'chain_R', 'res': 'res_6', 'model': 'model_1', 'pdbcode': u'1AQ4'}
# res
# {'name': 'ss', 'chain': u'chain_R', 'res': 'res_6', 'model': 'model_1', 'pdbcode': u'1AQ4'}
# pdbcode
# {'name': 'ss', 'chain': u'chain_R', 'res': 'res_7', 'model': 'model_1', 'pdbcode': u'1AQ4'}
# chain
# {'name': 'ss', 'chain': u'chain_R', 'res': 'res_7', 'model': 'model_1', 'pdbcode': u'1AQ4'}
# res
# {'name': 'ss', 'chain': u'chain_R', 'res': 'res_7', 'model': 'model_1', 'pdbcode': u'1AQ4'}
# pdbcode
# {'res': 'res_4', 'model': 'model_1', 'pdbcode': u'1AQ4', 'name': 'ss', 'chain': u'chain_R'}
# chain
# {'res': 'res_4', 'model': 'model_1', 'pdbcode': u'1AQ4', 'name': 'ss', 'chain': u'chain_R'}
# res
# {'res': 'res_4', 'model': 'model_1', 'pdbcode': u'1AQ4', 'name': 'ss', 'chain': u'chain_R'}
# pdbcode
# {'name': 'ss', 'chain': u'chain_R', 'res': 'res_5', 'model': 'model_1', 'pdbcode': u'1AQ4'}
# chain
# {'name': 'ss', 'chain': u'chain_R', 'res': 'res_5', 'model': 'model_1', 'pdbcode': u'1AQ4'}
# res
# {'name': 'ss', 'chain': u'chain_R', 'res': 'res_5', 'model': 'model_1', 'pdbcode': u'1AQ4'}
# pdbcode
# {'name': 'ss', 'chain': u'chain_R', 'res': 'res_6', 'model': 'model_1', 'pdbcode': u'1AQ4'}
# chain
# {'name': 'ss', 'chain': u'chain_R', 'res': 'res_6', 'model': 'model_1', 'pdbcode': u'1AQ4'}
# res
# {'name': 'ss', 'chain': u'chain_R', 'res': 'res_6', 'model': 'model_1', 'pdbcode': u'1AQ4'}
# pdbcode
# {'res': 'res_4', 'model': 'model_1', 'pdbcode': u'1AQ4', 'name': 'ss', 'chain': u'chain_S'}
# chain
# {'res': 'res_4', 'model': 'model_1', 'pdbcode': u'1AQ4', 'name': 'ss', 'chain': u'chain_S'}
# res
# {'res': 'res_4', 'model': 'model_1', 'pdbcode': u'1AQ4', 'name': 'ss', 'chain': u'chain_S'}
# pdbcode
# {'name': 'ss', 'chain': u'chain_S', 'res': 'res_5', 'model': 'model_1', 'pdbcode': u'1AQ4'}
# chain
# {'name': 'ss', 'chain': u'chain_S', 'res': 'res_5', 'model': 'model_1', 'pdbcode': u'1AQ4'}
# res
# {'name': 'ss', 'chain': u'chain_S', 'res': 'res_5', 'model': 'model_1', 'pdbcode': u'1AQ4'}
# pdbcode
# {'name': 'ss', 'chain': u'chain_S', 'res': 'res_6', 'model': 'model_1', 'pdbcode': u'1AQ4'}
# chain
# {'name': 'ss', 'chain': u'chain_S', 'res': 'res_6', 'model': 'model_1', 'pdbcode': u'1AQ4'}
# res
# {'name': 'ss', 'chain': u'chain_S', 'res': 'res_6', 'model': 'model_1', 'pdbcode': u'1AQ4'}
# pdbcode
# {'res': 'res_3', 'model': 'model_1', 'pdbcode': u'1AQ4', 'name': 'ss', 'chain': u'chain_S'}
# chain
# {'res': 'res_3', 'model': 'model_1', 'pdbcode': u'1AQ4', 'name': 'ss', 'chain': u'chain_S'}
# res
# {'res': 'res_3', 'model': 'model_1', 'pdbcode': u'1AQ4', 'name': 'ss', 'chain': u'chain_S'}
# pdbcode
# {'name': 'ss', 'chain': u'chain_S', 'res': 'res_4', 'model': 'model_1', 'pdbcode': u'1AQ4'}
# chain
# {'name': 'ss', 'chain': u'chain_S', 'res': 'res_4', 'model': 'model_1', 'pdbcode': u'1AQ4'}
# res
# {'name': 'ss', 'chain': u'chain_S', 'res': 'res_4', 'model': 'model_1', 'pdbcode': u'1AQ4'}
# pdbcode
# {'name': 'ss', 'chain': u'chain_S', 'res': 'res_5', 'model': 'model_1', 'pdbcode': u'1AQ4'}
# chain
# {'name': 'ss', 'chain': u'chain_S', 'res': 'res_5', 'model': 'model_1', 'pdbcode': u'1AQ4'}
# res
# {'name': 'ss', 'chain': u'chain_S', 'res': 'res_5', 'model': 'model_1', 'pdbcode': u'1AQ4'}
# pdbcode
# {'res': 'res_16', 'model': 'model_1', 'pdbcode': u'4PJO', 'name': 'ss', 'chain': u'chain_1'}
# chain
# {'res': 'res_16', 'model': 'model_1', 'pdbcode': u'4PJO', 'name': 'ss', 'chain': u'chain_1'}
# res
# {'res': 'res_16', 'model': 'model_1', 'pdbcode': u'4PJO', 'name': 'ss', 'chain': u'chain_1'}
# pdbcode
# {'name': 'ss', 'chain': u'chain_1', 'res': 'res_17', 'model': 'model_1', 'pdbcode': u'4PJO'}
# chain
# {'name': 'ss', 'chain': u'chain_1', 'res': 'res_17', 'model': 'model_1', 'pdbcode': u'4PJO'}
# res
# {'name': 'ss', 'chain': u'chain_1', 'res': 'res_17', 'model': 'model_1', 'pdbcode': u'4PJO'}
# pdbcode
# {'name': 'ss', 'chain': u'chain_1', 'res': 'res_18', 'model': 'model_1', 'pdbcode': u'4PJO'}
# chain
# {'name': 'ss', 'chain': u'chain_1', 'res': 'res_18', 'model': 'model_1', 'pdbcode': u'4PJO'}
# res
# {'name': 'ss', 'chain': u'chain_1', 'res': 'res_18', 'model': 'model_1', 'pdbcode': u'4PJO'}
# pdbcode
# {'res': 'res_5', 'model': 'model_1', 'pdbcode': u'1AQ4', 'name': 'ss', 'chain': u'chain_S'}
# chain
# {'res': 'res_5', 'model': 'model_1', 'pdbcode': u'1AQ4', 'name': 'ss', 'chain': u'chain_S'}
# res
# {'res': 'res_5', 'model': 'model_1', 'pdbcode': u'1AQ4', 'name': 'ss', 'chain': u'chain_S'}
# pdbcode
# {'name': 'ss', 'chain': u'chain_S', 'res': 'res_6', 'model': 'model_1', 'pdbcode': u'1AQ4'}
# chain
# {'name': 'ss', 'chain': u'chain_S', 'res': 'res_6', 'model': 'model_1', 'pdbcode': u'1AQ4'}
# res
# {'name': 'ss', 'chain': u'chain_S', 'res': 'res_6', 'model': 'model_1', 'pdbcode': u'1AQ4'}
# pdbcode
# {'name': 'ss', 'chain': u'chain_S', 'res': 'res_7', 'model': 'model_1', 'pdbcode': u'1AQ4'}
# chain
# {'name': 'ss', 'chain': u'chain_S', 'res': 'res_7', 'model': 'model_1', 'pdbcode': u'1AQ4'}
# res
# {'name': 'ss', 'chain': u'chain_S', 'res': 'res_7', 'model': 'model_1', 'pdbcode': u'1AQ4'}
# pdbcode
# {'res': 'res_1', 'model': 'model_1', 'pdbcode': u'4PJO', 'name': 'ss', 'chain': u'chain_X'}
# chain
# {'res': 'res_1', 'model': 'model_1', 'pdbcode': u'4PJO', 'name': 'ss', 'chain': u'chain_X'}
# res
# {'res': 'res_1', 'model': 'model_1', 'pdbcode': u'4PJO', 'name': 'ss', 'chain': u'chain_X'}
# pdbcode
# {'name': 'ss', 'chain': u'chain_X', 'res': 'res_2', 'model': 'model_1', 'pdbcode': u'4PJO'}
# chain
# {'name': 'ss', 'chain': u'chain_X', 'res': 'res_2', 'model': 'model_1', 'pdbcode': u'4PJO'}
# res
# {'name': 'ss', 'chain': u'chain_X', 'res': 'res_2', 'model': 'model_1', 'pdbcode': u'4PJO'}
# pdbcode
# {'name': 'ss', 'chain': u'chain_X', 'res': 'res_3', 'model': 'model_1', 'pdbcode': u'4PJO'}
# chain
# {'name': 'ss', 'chain': u'chain_X', 'res': 'res_3', 'model': 'model_1', 'pdbcode': u'4PJO'}
# res
# {'name': 'ss', 'chain': u'chain_X', 'res': 'res_3', 'model': 'model_1', 'pdbcode': u'4PJO'}
# pdbcode
# {'res': 'res_17', 'model': 'model_1', 'pdbcode': u'4PJO', 'name': 'ss', 'chain': u'chain_1'}
# chain
# {'res': 'res_17', 'model': 'model_1', 'pdbcode': u'4PJO', 'name': 'ss', 'chain': u'chain_1'}
# res
# {'res': 'res_17', 'model': 'model_1', 'pdbcode': u'4PJO', 'name': 'ss', 'chain': u'chain_1'}
# pdbcode
# {'name': 'ss', 'chain': u'chain_1', 'res': 'res_18', 'model': 'model_1', 'pdbcode': u'4PJO'}
# chain
# {'name': 'ss', 'chain': u'chain_1', 'res': 'res_18', 'model': 'model_1', 'pdbcode': u'4PJO'}
# res
# {'name': 'ss', 'chain': u'chain_1', 'res': 'res_18', 'model': 'model_1', 'pdbcode': u'4PJO'}
# pdbcode
# {'name': 'ss', 'chain': u'chain_1', 'res': 'res_19', 'model': 'model_1', 'pdbcode': u'4PJO'}
# chain
# {'name': 'ss', 'chain': u'chain_1', 'res': 'res_19', 'model': 'model_1', 'pdbcode': u'4PJO'}
# res
# {'name': 'ss', 'chain': u'chain_1', 'res': 'res_19', 'model': 'model_1', 'pdbcode': u'4PJO'}
# pdbcode
# {'res': 'res_16', 'model': 'model_1', 'pdbcode': u'4PJO', 'name': 'ss', 'chain': u'chain_2'}
# chain
# {'res': 'res_16', 'model': 'model_1', 'pdbcode': u'4PJO', 'name': 'ss', 'chain': u'chain_2'}
# res
# {'res': 'res_16', 'model': 'model_1', 'pdbcode': u'4PJO', 'name': 'ss', 'chain': u'chain_2'}
# pdbcode
# {'name': 'ss', 'chain': u'chain_2', 'res': 'res_17', 'model': 'model_1', 'pdbcode': u'4PJO'}
# chain
# {'name': 'ss', 'chain': u'chain_2', 'res': 'res_17', 'model': 'model_1', 'pdbcode': u'4PJO'}
# res
# {'name': 'ss', 'chain': u'chain_2', 'res': 'res_17', 'model': 'model_1', 'pdbcode': u'4PJO'}
# pdbcode
# {'name': 'ss', 'chain': u'chain_2', 'res': 'res_18', 'model': 'model_1', 'pdbcode': u'4PJO'}
# chain
# {'name': 'ss', 'chain': u'chain_2', 'res': 'res_18', 'model': 'model_1', 'pdbcode': u'4PJO'}
# res
# {'name': 'ss', 'chain': u'chain_2', 'res': 'res_18', 'model': 'model_1', 'pdbcode': u'4PJO'}
# pdbcode
# {'res': 'res_5', 'model': 'model_1', 'pdbcode': u'4PJO', 'name': 'ss', 'chain': u'chain_X'}
# chain
# {'res': 'res_5', 'model': 'model_1', 'pdbcode': u'4PJO', 'name': 'ss', 'chain': u'chain_X'}
# res
# {'res': 'res_5', 'model': 'model_1', 'pdbcode': u'4PJO', 'name': 'ss', 'chain': u'chain_X'}
# pdbcode
# {'name': 'ss', 'chain': u'chain_X', 'res': 'res_6', 'model': 'model_1', 'pdbcode': u'4PJO'}
# chain
# {'name': 'ss', 'chain': u'chain_X', 'res': 'res_6', 'model': 'model_1', 'pdbcode': u'4PJO'}
# res
# {'name': 'ss', 'chain': u'chain_X', 'res': 'res_6', 'model': 'model_1', 'pdbcode': u'4PJO'}
# pdbcode
# {'name': 'ss', 'chain': u'chain_X', 'res': 'res_7', 'model': 'model_1', 'pdbcode': u'4PJO'}
# chain
# {'name': 'ss', 'chain': u'chain_X', 'res': 'res_7', 'model': 'model_1', 'pdbcode': u'4PJO'}
# res
# {'name': 'ss', 'chain': u'chain_X', 'res': 'res_7', 'model': 'model_1', 'pdbcode': u'4PJO'}
# pdbcode
# {'res': 'res_1', 'model': 'model_1', 'pdbcode': u'4PJO', 'name': 'ss', 'chain': u'chain_x'}
# chain
# {'res': 'res_1', 'model': 'model_1', 'pdbcode': u'4PJO', 'name': 'ss', 'chain': u'chain_x'}
# res
# {'res': 'res_1', 'model': 'model_1', 'pdbcode': u'4PJO', 'name': 'ss', 'chain': u'chain_x'}
# pdbcode
# {'name': 'ss', 'chain': u'chain_x', 'res': 'res_2', 'model': 'model_1', 'pdbcode': u'4PJO'}
# chain
# {'name': 'ss', 'chain': u'chain_x', 'res': 'res_2', 'model': 'model_1', 'pdbcode': u'4PJO'}
# res
# {'name': 'ss', 'chain': u'chain_x', 'res': 'res_2', 'model': 'model_1', 'pdbcode': u'4PJO'}
# pdbcode
# {'name': 'ss', 'chain': u'chain_x', 'res': 'res_3', 'model': 'model_1', 'pdbcode': u'4PJO'}
# chain
# {'name': 'ss', 'chain': u'chain_x', 'res': 'res_3', 'model': 'model_1', 'pdbcode': u'4PJO'}
# res
# {'name': 'ss', 'chain': u'chain_x', 'res': 'res_3', 'model': 'model_1', 'pdbcode': u'4PJO'}
# pdbcode
# {'res': 'res_17', 'model': 'model_1', 'pdbcode': u'4PJO', 'name': 'ss', 'chain': u'chain_2'}
# chain
# {'res': 'res_17', 'model': 'model_1', 'pdbcode': u'4PJO', 'name': 'ss', 'chain': u'chain_2'}
# res
# {'res': 'res_17', 'model': 'model_1', 'pdbcode': u'4PJO', 'name': 'ss', 'chain': u'chain_2'}
# pdbcode
# {'name': 'ss', 'chain': u'chain_2', 'res': 'res_18', 'model': 'model_1', 'pdbcode': u'4PJO'}
# chain
# {'name': 'ss', 'chain': u'chain_2', 'res': 'res_18', 'model': 'model_1', 'pdbcode': u'4PJO'}
# res
# {'name': 'ss', 'chain': u'chain_2', 'res': 'res_18', 'model': 'model_1', 'pdbcode': u'4PJO'}
# pdbcode
# {'name': 'ss', 'chain': u'chain_2', 'res': 'res_19', 'model': 'model_1', 'pdbcode': u'4PJO'}
# chain
# {'name': 'ss', 'chain': u'chain_2', 'res': 'res_19', 'model': 'model_1', 'pdbcode': u'4PJO'}
# res
# {'name': 'ss', 'chain': u'chain_2', 'res': 'res_19', 'model': 'model_1', 'pdbcode': u'4PJO'}
# pdbcode
# {'res': 'res_16', 'model': 'model_1', 'pdbcode': u'4PJO', 'name': 'ss', 'chain': u'chain_3'}
# chain
# {'res': 'res_16', 'model': 'model_1', 'pdbcode': u'4PJO', 'name': 'ss', 'chain': u'chain_3'}
# res
# {'res': 'res_16', 'model': 'model_1', 'pdbcode': u'4PJO', 'name': 'ss', 'chain': u'chain_3'}
# pdbcode
# {'name': 'ss', 'chain': u'chain_3', 'res': 'res_17', 'model': 'model_1', 'pdbcode': u'4PJO'}
# chain
# {'name': 'ss', 'chain': u'chain_3', 'res': 'res_17', 'model': 'model_1', 'pdbcode': u'4PJO'}
# res
# {'name': 'ss', 'chain': u'chain_3', 'res': 'res_17', 'model': 'model_1', 'pdbcode': u'4PJO'}
# pdbcode
# {'name': 'ss', 'chain': u'chain_3', 'res': 'res_18', 'model': 'model_1', 'pdbcode': u'4PJO'}
# chain
# {'name': 'ss', 'chain': u'chain_3', 'res': 'res_18', 'model': 'model_1', 'pdbcode': u'4PJO'}
# res
# {'name': 'ss', 'chain': u'chain_3', 'res': 'res_18', 'model': 'model_1', 'pdbcode': u'4PJO'}
# pdbcode
# {'res': 'res_5', 'model': 'model_1', 'pdbcode': u'4PJO', 'name': 'ss', 'chain': u'chain_x'}
# chain
# {'res': 'res_5', 'model': 'model_1', 'pdbcode': u'4PJO', 'name': 'ss', 'chain': u'chain_x'}
# res
# {'res': 'res_5', 'model': 'model_1', 'pdbcode': u'4PJO', 'name': 'ss', 'chain': u'chain_x'}
# pdbcode
# {'name': 'ss', 'chain': u'chain_x', 'res': 'res_6', 'model': 'model_1', 'pdbcode': u'4PJO'}
# chain
# {'name': 'ss', 'chain': u'chain_x', 'res': 'res_6', 'model': 'model_1', 'pdbcode': u'4PJO'}
# res
# {'name': 'ss', 'chain': u'chain_x', 'res': 'res_6', 'model': 'model_1', 'pdbcode': u'4PJO'}
# pdbcode
# {'name': 'ss', 'chain': u'chain_x', 'res': 'res_7', 'model': 'model_1', 'pdbcode': u'4PJO'}
# chain
# {'name': 'ss', 'chain': u'chain_x', 'res': 'res_7', 'model': 'model_1', 'pdbcode': u'4PJO'}
# res
# {'name': 'ss', 'chain': u'chain_x', 'res': 'res_7', 'model': 'model_1', 'pdbcode': u'4PJO'}
# pdbcode
# {'res': 'res_1', 'model': 'model_1', 'pdbcode': u'4PJO', 'name': 'ss', 'chain': u'chain_Y'}
# chain
# {'res': 'res_1', 'model': 'model_1', 'pdbcode': u'4PJO', 'name': 'ss', 'chain': u'chain_Y'}
# res
# {'res': 'res_1', 'model': 'model_1', 'pdbcode': u'4PJO', 'name': 'ss', 'chain': u'chain_Y'}
# pdbcode
# {'name': 'ss', 'chain': u'chain_Y', 'res': 'res_2', 'model': 'model_1', 'pdbcode': u'4PJO'}
# chain
# {'name': 'ss', 'chain': u'chain_Y', 'res': 'res_2', 'model': 'model_1', 'pdbcode': u'4PJO'}
# res
# {'name': 'ss', 'chain': u'chain_Y', 'res': 'res_2', 'model': 'model_1', 'pdbcode': u'4PJO'}
# pdbcode
# {'name': 'ss', 'chain': u'chain_Y', 'res': 'res_3', 'model': 'model_1', 'pdbcode': u'4PJO'}
# chain
# {'name': 'ss', 'chain': u'chain_Y', 'res': 'res_3', 'model': 'model_1', 'pdbcode': u'4PJO'}
# res
# {'name': 'ss', 'chain': u'chain_Y', 'res': 'res_3', 'model': 'model_1', 'pdbcode': u'4PJO'}
# pdbcode
# {'res': 'res_17', 'model': 'model_1', 'pdbcode': u'4PJO', 'name': 'ss', 'chain': u'chain_3'}
# chain
# {'res': 'res_17', 'model': 'model_1', 'pdbcode': u'4PJO', 'name': 'ss', 'chain': u'chain_3'}
# res
# {'res': 'res_17', 'model': 'model_1', 'pdbcode': u'4PJO', 'name': 'ss', 'chain': u'chain_3'}
# pdbcode
# {'name': 'ss', 'chain': u'chain_3', 'res': 'res_18', 'model': 'model_1', 'pdbcode': u'4PJO'}
# chain
# {'name': 'ss', 'chain': u'chain_3', 'res': 'res_18', 'model': 'model_1', 'pdbcode': u'4PJO'}
# res
# {'name': 'ss', 'chain': u'chain_3', 'res': 'res_18', 'model': 'model_1', 'pdbcode': u'4PJO'}
# pdbcode
# {'name': 'ss', 'chain': u'chain_3', 'res': 'res_19', 'model': 'model_1', 'pdbcode': u'4PJO'}
# chain
# {'name': 'ss', 'chain': u'chain_3', 'res': 'res_19', 'model': 'model_1', 'pdbcode': u'4PJO'}
# res
# {'name': 'ss', 'chain': u'chain_3', 'res': 'res_19', 'model': 'model_1', 'pdbcode': u'4PJO'}
# pdbcode
# {'res': 'res_16', 'model': 'model_1', 'pdbcode': u'4PJO', 'name': 'ss', 'chain': u'chain_4'}
# chain
# {'res': 'res_16', 'model': 'model_1', 'pdbcode': u'4PJO', 'name': 'ss', 'chain': u'chain_4'}
# res
# {'res': 'res_16', 'model': 'model_1', 'pdbcode': u'4PJO', 'name': 'ss', 'chain': u'chain_4'}
# pdbcode
# {'name': 'ss', 'chain': u'chain_4', 'res': 'res_17', 'model': 'model_1', 'pdbcode': u'4PJO'}
# chain
# {'name': 'ss', 'chain': u'chain_4', 'res': 'res_17', 'model': 'model_1', 'pdbcode': u'4PJO'}
# res
# {'name': 'ss', 'chain': u'chain_4', 'res': 'res_17', 'model': 'model_1', 'pdbcode': u'4PJO'}
# pdbcode
# {'name': 'ss', 'chain': u'chain_4', 'res': 'res_18', 'model': 'model_1', 'pdbcode': u'4PJO'}
# chain
# {'name': 'ss', 'chain': u'chain_4', 'res': 'res_18', 'model': 'model_1', 'pdbcode': u'4PJO'}
# res
# {'name': 'ss', 'chain': u'chain_4', 'res': 'res_18', 'model': 'model_1', 'pdbcode': u'4PJO'}
# pdbcode
# {'res': 'res_5', 'model': 'model_1', 'pdbcode': u'4PJO', 'name': 'ss', 'chain': u'chain_Y'}
# chain
# {'res': 'res_5', 'model': 'model_1', 'pdbcode': u'4PJO', 'name': 'ss', 'chain': u'chain_Y'}
# res
# {'res': 'res_5', 'model': 'model_1', 'pdbcode': u'4PJO', 'name': 'ss', 'chain': u'chain_Y'}
# pdbcode
# {'name': 'ss', 'chain': u'chain_Y', 'res': 'res_6', 'model': 'model_1', 'pdbcode': u'4PJO'}
# chain
# {'name': 'ss', 'chain': u'chain_Y', 'res': 'res_6', 'model': 'model_1', 'pdbcode': u'4PJO'}
# res
# {'name': 'ss', 'chain': u'chain_Y', 'res': 'res_6', 'model': 'model_1', 'pdbcode': u'4PJO'}
# pdbcode
# {'name': 'ss', 'chain': u'chain_Y', 'res': 'res_7', 'model': 'model_1', 'pdbcode': u'4PJO'}
# chain
# {'name': 'ss', 'chain': u'chain_Y', 'res': 'res_7', 'model': 'model_1', 'pdbcode': u'4PJO'}
# res
# {'name': 'ss', 'chain': u'chain_Y', 'res': 'res_7', 'model': 'model_1', 'pdbcode': u'4PJO'}

# %%
ss
# Out:
# array([[list([u'L', 2, 9]), list([u'L', 3, 9]), list([u'L', 4, 9])],
#        [list([u'D', 4, 10]), list([u'D', 8, 10]), list([u'D', 6, 10])],
#        [list([u'D', 5, 10]), list([u'D', 10, 10]), list([u'D', 3, 10])],
#        [list([u'D', 3, 16]), list([u'S', 13, 16]), list([u'D', 9, 16])],
#        [list([u'D', 9, 16]), list([u'D', 0, 0]), list([u'L', 2, 4])],
#        [list([u'S', 13, 16]), list([u'D', 9, 16]), list([u'D', 0, 0])],
#        [list([u'S', 12, 14]), list([u'D', 8, 14]), list([u'D', 0, 0])],
#        [list([u'D', 3, 14]), list([u'S', 12, 14]), list([u'D', 8, 14])],
#        [list([u'D', 0, 0]), list([u'L', 2, 9]), list([u'L', 3, 9])],
#        [list([u'D', 8, 14]), list([u'D', 0, 0]), list([u'L', 2, 4])],
#        [list([u'D', 4, 10]), list([u'D', 8, 10]), list([u'D', 6, 10])],
#        [list([u'L', 2, 9]), list([u'L', 3, 9]), list([u'L', 4, 9])],
#        [list([u'D', 0, 0]), list([u'L', 2, 9]), list([u'L', 3, 9])],
#        [list([u'D', 5, 10]), list([u'D', 10, 10]), list([u'D', 3, 10])],
#        [list([u'D', 4, 10]), list([u'D', 8, 10]), list([u'D', 6, 10])],
#        [list([u'L', 2, 9]), list([u'L', 3, 9]), list([u'L', 4, 9])],
#        [list([u'D', 0, 0]), list([u'L', 2, 9]), list([u'L', 3, 9])],
#        [list([u'D', 5, 10]), list([u'D', 10, 10]), list([u'D', 3, 10])],
#        [list([u'D', 4, 10]), list([u'D', 8, 10]), list([u'D', 6, 10])],
#        [list([u'L', 2, 9]), list([u'L', 3, 9]), list([u'L', 4, 9])],
#        [list([u'D', 0, 0]), list([u'L', 2, 9]), list([u'L', 3, 9])],
#        [list([u'D', 5, 10]), list([u'D', 10, 10]), list([u'D', 3, 10])]],
#       dtype=object)

# %%
ss_ph = query(chaindata, chainschema, fragments[ss], contact_parts, "interface_protein", part="ph")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-17-92602677b01a> in <module>()
# ----> 1 ss_ph = query(chaindata, chainschema, fragments[ss], contact_parts, "interface_protein", part="ph")
#
# IndexError: arrays used as indices must be of integer (or boolean) type

# %%
ds_ph = query(chaindata, chainschema, fragments[ds], contact_parts, "interface_protein", part="ph")

# %%
100*sum(ds)/len(fragments)

# %%
100*sum(ds_ph)/sum(ds)

# %%
ss_base = query(chaindata, chainschema, fragments[ss], contact_parts, "interface_protein", part="base")

# %%
ss_sug = query(chaindata, chainschema, fragments[ss], contact_parts, "interface_protein", part="sug")

# %%
counts={}
for part in ["ph","sug", "base"]:
    for statename, state in zip(["ss","ds"],[ss, ds]):
        print(part, statename)
        counts[statename, part] = np.array(query(chaindata, chainschema, fragments[state], contact_parts, "interface_protein", part))

# %%
sum(counts["ss","base"])

# %%
ss_contact = sum([sum(counts["ss",i]) for i in ["sug", "ph", "base"]])

# %%
ds_contact = sum([sum(counts["ds",i]) for i in ["sug", "ph", "base"]])

# %%
def sum_bool(counts, statename):
    mask = counts[statename,"sug"] | counts[statename,"ph"] | counts[statename,"base"]
    print(len(mask))
    return sum(mask)

# %%
ds_all=sum_bool(counts, "ds")
ss_all=sum_bool(counts, "ss")

# %%
ds_all

# %%
ss_all

# %%
100*sum(counts["ss","base"])/ss_all

# %%
100*sum(counts["ds","base"])/ds_all

# %%
100*sum(counts["ss","ph"])/ss_all

# %%
100*sum(counts["ds","ph"])/ds_all

# %%
100*sum(counts["ss","sug"])/ss_all

# %%
100*sum(counts["ds","sug"])/ds_all

# %%
sum(counts["ss","base"])

# %%
ss_all - sum(counts["ss","base"])

# %%
sum(counts["ds","base"])

# %%
ds_all - sum(counts["ds","base"])

# %%
from scipy.stats import fisher_exact
a=[[22043, 7248],[68126, 48909]]
fisher_exact(a)

# %%
p = "ph"
a = sum(counts["ss",p])
b = ss_all - sum(counts["ss",p])
c = sum(counts["ds",p])
d = ds_all - sum(counts["ds",p])
table = [[a,b],[c,d]]
fisher_exact(table)

# %%
stats={ "ph":[100*sum(counts["ss","ph"])/ss_all, 100*sum(counts["ds","ph"])/ds_all],
       "sug":[100*sum(counts["ss","sug"])/ss_all, 100*sum(counts["ds","sug"])/ds_all],
       "base": [100*sum(counts["ss","base"])/ss_all, 100*sum(counts["ds","base"])/ds_all] }

# %%
stats

# %%
frag20=fragments[:10]
frag20

# %%
import pandas as pd
pd.DataFrame.from_records(frag20[""])

# %%
mask1=(fragments["seq"]== b'ACU')
mask2=(fragments["structure"]==b'1OOA')
frag=fragments[mask1&mask2][-1]

# %%
r=query_one_frag(chaindata, chainschema, frag, "interface_protein", "ph")
contact_parts(r)

# %% [markdown]
# # Question 2
# For single-stranded fragments where the middle residue contacts with the phosphate,
#  how many stacking interactions does it make with neighboring bases?

# %%
# Select single-stranded fragments
ss = query(chaindata, chainschema, fragments, is_ss, "ss", part=None)
frag_ss = fragments[ss]

# mask (True or False for every fragment in frag_ss) on frags with central nucl in contact with prot via ph
ss_ph = np.array(query(chaindata, chainschema, frag_ss, contact_parts, "interface_protein", part="ph"))

# %%
frag_ss = fragments[ss]
# mask on frag_ss with central base stacking with base n-1
ss_stackprev = query(chaindata, chainschema, frag_ss, contact_parts, "stacking", pos="n-1")

# %%
# mask on frag_ss with central base stacking with base n+1
ss_stacknext = query(chaindata, chainschema, frag_ss, contact_parts, "stacking", pos="n+1")

# %%
a = sum(ss_stacknext)
b = sum(ss_stackprev)
print(a, b)

# %%
ss_stack = np.array(ss_stackprev,int)+np.array(ss_stacknext,int)

# %%
#number of stack for each frag_ss that bind via ph
stack_ph = ss_stack[ss_ph]

#number of stack for each frag_ss that does not bind via ph
stack_noph = ss_stack[~ss_ph]

# %%
import numpy as np
data1 = np.unique(stack_ph,return_counts=True)
a1 = data1[1][0] + data1[1][1]
b1 = data1[1][2]

# %%
data2 = np.unique(stack_noph,return_counts=True)
a2 = data2[1][0] + data2[1][1]
b2 = data2[1][2]

# %%
len(ss_ph)

# %%
stack_ph

# %%
from scipy.stats import fisher_exact
table = [[a1,b1],  [a2,b2]]
fisher_exact(table)

# %%
# percent of [frag_ss binding by phosphate] that has 2 stackings
print(np.sum(stack_ph==2)/len(stack_ph)*100)
# percent of [frag_ss binding by non-phosphate] that has 2 stackings
print(np.sum(stack_noph==2)/len(stack_noph)*100)

# %%
# percent of frag_ss with 2 stackings
(ss_stack==2).sum()/len(frag_ss)*100

# %%
# percent of binding frag_ss that binds via ph
sum(ss_ph)/len(frag_ss)*100

# %%
# %run query
ss_ph_3p5 = query(chaindata, chainschema, fragments[ss], set_contact_parts(3.5), "interface_protein", part="ph")

# %%
sum(ss_ph_3p5)

# %%
sum(ss_ph)

# %%
# percent of [frag_ss with <3.5 phosphate] that has 2 stackings
print(np.sum(stack_ph==2)/len(stack_ph)*100)
# percent of [frag_ss with >3.5 phosphate] that has 2 stackings
print(np.sum(stack_noph==2)/len(stack_noph)*100)
